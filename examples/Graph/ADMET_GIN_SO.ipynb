# %% [markdown]
# <a href="https://colab.research.google.com/github/yingzibu/MOL2ADMET/blob/main/examples/Graph/ADMET_GIN_SO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install rdkit --quiet
! pip install PyTDC --quiet
! pip install mycolorpy --quiet

! pip install dgllife --quiet
! pip install molvs --quiet
! pip install dgl -f https://data.dgl.ai/wheels/cu118/repo.html --quiet
! pip install dglgo -f https://data.dgl.ai/wheels-test/repo.html --quiet

! pip install DeepPurpose --quiet
! pip install git+https://github.com/bp-kelley/descriptastorus --quiet
! pip install pandas-flavor --quiet

# %%
cd /content/drive/MyDrive/ADMET
# Out:
# /content/drive/MyDrive/ADMET

# %%
from dgllife.model import load_pretrained
from dgl.nn.pytorch.glob import AvgPooling
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from functools import partial
import torch
from dgllife.utils import smiles_to_bigraph, PretrainAtomFeaturizer, PretrainBondFeaturizer

MASK = -100

class GIN_dataset(Dataset):
    def __init__(self, df, names, mask=MASK):
        df = df.fillna(mask)
        self.names = names
        self.df = df
        self.len = len(df)
        self.props = self.df[names]
        self.node_featurizer = PretrainAtomFeaturizer()
        self.edge_featurizer = PretrainBondFeaturizer()
        self.fc = partial(smiles_to_bigraph, add_self_loop=True)
    def __len__(self): return self.len
    def __getitem__(self, idx):
        v_d = self.df.iloc[idx]['Drug']
        v_d = self.fc(smiles=v_d, node_featurizer = self.node_featurizer,
                      edge_featurizer = self.edge_featurizer)
        label = torch.tensor(self.props.iloc[idx], dtype=torch.float32)
        return v_d, label

# %%
import dgl
def get_GIN_dataloader(datasets, loader_params):
    def dgl_collate_func(data):
        x, labels = map(list, zip(*data))
        bg = dgl.batch(x)
        labels = torch.stack(labels, dim=0)
        bg.set_n_initializer(dgl.init.zero_initializer)
        bg.set_e_initializer(dgl.init.zero_initializer)
        return bg, labels
    loader_params['collate_fn'] = dgl_collate_func
    return DataLoader(datasets, **loader_params)

# %%
from dgllife.utils import EarlyStopping, Meter
from tqdm import tqdm

def train_epoch(epoch, model, loader, loss_func, device,
                optimizer=None, names=None, MASK=-100):
    if optimizer==None: model.eval(); train_type='Valid'
    else: model.train(); train_type='Train'
    losses = 0
    y_probs = {}
    y_label = {}
    # for idx, batch in tqdm(enumerate(loader), total=len(loader), desc=f'Epoch {epoch}'):
    for idx, batch in enumerate(loader):
        bg, labels = batch
        bg, labels = bg.to(device), labels.to(device)
        mask = labels == MASK
        pred = model(bg)
        loss = loss_func(pred[~mask], labels[~mask])
        # del mask
        losses += loss.item()
        if optimizer != None:
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        if names != None:
            for j, name in enumerate(names):
                probs = F.sigmoid(pred[:, j][~mask[:, j]])
                label = labels[:, j][~mask[:, j]]
                probs = probs.cpu().detach().numpy().tolist()
                label = label.cpu().detach().numpy().tolist()
                if idx ==0: y_probs[name], y_label[name] = probs, label
                else:
                    y_probs[name] += probs
                    y_label[name] += label

        # if idx % 10 == 0: print(losses)
    total_loss = losses / len(loader.dataset)
    print(f'Epoch:{epoch}, [{train_type}] Loss: {total_loss:.3f}')
    if names == None or train_type == 'train': return total_loss
    else: return total_loss, y_probs, y_label

# %%
import torch.nn.functional as F
from scripts.eval_utils import *
from scripts.preprocess_mols import *
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import roc_auc_score, average_precision_score, f1_score

device = 'cuda'

def eval_dict(y_probs:dict, y_label:dict, names:list, IS_R=False):
    if IS_R == False: # classification task
        for i, name in enumerate(names):
            print('*'*15, name, '*'*15)
            probs = y_probs[name]
            label = y_label[name]
            assert len(probs) == len(label)
            preds = get_preds(0.5, probs)
            # evaluate(label, preds, probs)
            print(f'AUROC: {roc_auc_score(label, probs):.4f}',
                  f'AUPRC: {average_precision_score(label, probs):.4f}',
                  f'F1: {f1_score(label, preds):.4f}')
            evaluate(label, preds, probs)
            print()


def eval_AP(model, IS_R, test_loader, names, device=device):
    # print('Evaluate on test sets')
    # model = model.cpu()
    model.eval()
    total_loss = 0
    y_probs = {}
    y_label = {}
    if IS_R: print('using MSELoss')
    else: print('using BCELOSSwithdigits')
    if IS_R: loss_fn = nn.MSELoss(reduction='sum') # if regression
    else: loss_fn = nn.BCEWithLogitsLoss(reduction='sum') # if classification
    for i, batch_data in tqdm(enumerate(test_loader), total=len(test_loader)):
        bg, labels = batch_data
        bg, labels = bg.to(device), labels.to(device)
        pred = model(bg)
        mask = labels == MASK
        loss = loss_fn(pred[~mask], labels[~mask])
        total_loss += loss.item()
        for j, name in enumerate(names):
            probs = F.sigmoid(pred[:, j][~mask[:, j]])
            label = labels[:, j][~mask[:, j]]
            probs = probs.cpu().detach().numpy().tolist()
            label = label.cpu().detach().numpy().tolist()
            if i ==0: y_probs[name], y_label[name] = probs, label
            else:
                y_probs[name] += probs
                y_label[name] += label

    total_loss /= len(test_loader.dataset)
    print(f'total_loss: {total_loss:.3f}')

    eval_dict(y_probs, y_label, names, IS_R)

    return y_probs, y_label

# %%
class GIN_MOD(nn.Module):
    """
    Reference: https://github.com/kexinhuang12345/DeepPurpose/blob/master/DeepPurpose/encoders.py#L392
    """
	## adapted from https://github.com/awslabs/dgl-lifesci/blob/2fbf5fd6aca92675b709b6f1c3bc3c6ad5434e96/examples/property_prediction/moleculenet/utils.py#L76
    def __init__(self, **config):
        super(GIN_MOD, self).__init__()
        self.gnn = load_pretrained('gin_supervised_contextpred')
        self.readout = AvgPooling()
        self.transform = nn.Linear(300, config['GIN_out_dim'])
        self.dropout = nn.Dropout(config['dropout'])
        self.hidden_dims = config['hid_dims']
        self.out_dim = config['out_dim']
        layer_size = len(self.hidden_dims)
        neurons = [config['GIN_out_dim'], *self.hidden_dims]
        linear_layers = [nn.Linear(neurons[i-1], neurons[i]) \
                         for i in range(1, len(neurons))]
        self.hidden = nn.ModuleList(linear_layers)
        self.final = nn.Linear(self.hidden_dims[-1], self.out_dim)

    def forward(self, bg):
        # bg = bg.to(device)
        node_feats = [
            bg.ndata.pop('atomic_number'),
            bg.ndata.pop('chirality_type')
        ]
        edge_feats = [
            bg.edata.pop('bond_type'),
            bg.edata.pop('bond_direction_type')
        ]

        node_feats = self.gnn(bg, node_feats, edge_feats)
        x = self.readout(bg, node_feats)
        x = self.transform(x)
        for layer in self.hidden: x = F.leaky_relu(layer(x))
        x = self.final(x)
        return self.dropout(x)

# %%
class PRED:
    def __init__(self, **config):
        cuda = torch.cuda.is_available()
        if cuda: self.device = 'cuda'
        else:    self.device = 'cpu'
        self.prop_names = config['prop_names']
        self.model = GIN_MOD(**config).to(self.device)
        self.config = config
        self.IS_R = config['IS_R']
        if self.IS_R: loss_fn = nn.MSELoss(reduction='sum') # if regression
        else: loss_fn = nn.BCEWithLogitsLoss(reduction='sum') # if classification
        self.loss_fn = loss_fn
        self.optimizer = torch.optim.AdamW(self.model.parameters(),
                    lr=config['lr'], weight_decay=config['wd'])
        self.stopper = EarlyStopping(mode='lower', patience=config['patience'])
        self.min_loss = 10000
        self.best_epoch = 0

    def load_model(self, path):
        con = self.config.copy()
        # con['dropout'] = 0
        self.model = GIN_MOD(**con).to(self.device)
        print('load pretrained model from ', path)
        self.model.load_state_dict(torch.load(path, map_location=self.device))

    def eval(self, loader, path=None):
        # self.load_model(path)
        if path != None: self.load_model(path)
        eval_AP(self.model, self.IS_R, loader, self.prop_names)

    def train(self, data_loader, val_loader, test_loader=None, train_epoch=train_epoch):
        if self.best_epoch != 0: self.load_model(self.config['model_path'])

        for epoch in range(500):
            score = train_epoch(epoch, self.model, data_loader, self.loss_fn,
                                self.device, self.optimizer)
            val_score, probs, labels = \
                    train_epoch(epoch, self.model, val_loader, self.loss_fn,
                                self.device, names=self.prop_names)

            early_stop = self.stopper.step(val_score, self.model)
            if val_score < self.min_loss:
                print(f'prev min loss {self.min_loss:.3f}, '
                      f'now loss {val_score:.3f} |',
                      f'save model at epoch: {epoch}')
                self.min_loss = val_score
                torch.save(self.model.state_dict(), self.config['model_path'])
                self.best_epoch = epoch
                eval_dict(probs, labels, self.prop_names, IS_R=self.IS_R)
                # self.eval(val_data_loader, 'ckpt_.pt')
            if early_stop: print('early stop'); break

        print(f"best epoch: {self.best_epoch}, min loss: {self.min_loss:.4f}")
        print()
        if test_loader != None: self.eval(test_loader, self.config['model_path'])

# %%
from scripts.preprocess_mols import collect_data
met_cls_all = ['CYP2C19_Veith', 'CYP2D6_Veith', 'CYP3A4_Veith',
            'CYP1A2_Veith', 'CYP2C9_Veith']
IS_R = False # is regression task

for met_cls in met_cls_all:

    met_cls = [met_cls]
    trains, valids, tests = collect_data(met_cls, IS_R=False)
    batch_size = 128
    loader_params ={'batch_size': batch_size, 'shuffle': True}

    train_loader = get_GIN_dataloader(GIN_dataset(trains, met_cls), loader_params)
    valid_loader = get_GIN_dataloader(GIN_dataset(valids, met_cls), loader_params)
    p = {'batch_size': batch_size, 'shuffle': False}
    test_loader = get_GIN_dataloader(GIN_dataset(tests, met_cls), p)

    IS_R = False
    config = {'GIN_out_dim': 256,
            'hid_dims': [512],
            'out_dim': len(met_cls),
            'prop_names': met_cls,
            'dropout': 0.1,
            'IS_R': IS_R,
            'lr': 1e-4,
            'wd':1e-5,
            'patience': 10,
            'model_path': f'GIN_SO_DR_0.1/ckpt_{met_cls[0]}.pt'}

    models = PRED(**config)
    print("*"*40, met_cls, "*"*40)
    print('---> start training...')
    models.train(train_loader, valid_loader, test_loader)
# Out:
# Epoch:51, [Train] Loss: 0.484
# Epoch:51, [Valid] Loss: 0.359
# prev min loss 0.359, now loss 0.359 | save model at epoch: 51
# *************** CYP2C19_Veith ***************
# AUROC: 0.9274 AUPRC: 0.9133 F1: 0.8536
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.859  &  0.860  &          0.833  &     0.875  &0.845  &0.854 &0.927 &   0.719 &   0.913
#
# Epoch:52, [Train] Loss: 0.485
# Epoch:52, [Valid] Loss: 0.359
# EarlyStopping counter: 1 out of 10
# Epoch:53, [Train] Loss: 0.492
# Epoch:53, [Valid] Loss: 0.366
# EarlyStopping counter: 2 out of 10
# Epoch:54, [Train] Loss: 0.473
# Epoch:54, [Valid] Loss: 0.356
# prev min loss 0.359, now loss 0.356 | save model at epoch: 54
# *************** CYP2C19_Veith ***************
# AUROC: 0.9259 AUPRC: 0.9116 F1: 0.8569
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.862  &  0.863  &          0.832  &     0.884  &0.842  &0.857 &0.926 &   0.725 &   0.912
#
# Epoch:55, [Train] Loss: 0.483
# Epoch:55, [Valid] Loss: 0.361
# EarlyStopping counter: 1 out of 10
# Epoch:56, [Train] Loss: 0.484
# Epoch:56, [Valid] Loss: 0.359
# EarlyStopping counter: 2 out of 10
# Epoch:57, [Train] Loss: 0.470
# Epoch:57, [Valid] Loss: 0.357
# EarlyStopping counter: 3 out of 10
# Epoch:58, [Train] Loss: 0.483
# Epoch:58, [Valid] Loss: 0.358
# EarlyStopping counter: 4 out of 10
# Epoch:59, [Train] Loss: 0.471
# Epoch:59, [Valid] Loss: 0.355
# prev min loss 0.356, now loss 0.355 | save model at epoch: 59
# *************** CYP2C19_Veith ***************
# AUROC: 0.9263 AUPRC: 0.9124 F1: 0.8510
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.858  &  0.858  &          0.836  &     0.867  &0.850  &0.851 &0.926 &   0.716 &   0.912
#
# Epoch:60, [Train] Loss: 0.479
# Epoch:60, [Valid] Loss: 0.357
# EarlyStopping counter: 1 out of 10
# Epoch:61, [Train] Loss: 0.487
# Epoch:61, [Valid] Loss: 0.366
# EarlyStopping counter: 2 out of 10
# Epoch:62, [Train] Loss: 0.487
# Epoch:62, [Valid] Loss: 0.361
# EarlyStopping counter: 3 out of 10
# Epoch:63, [Train] Loss: 0.478
# Epoch:63, [Valid] Loss: 0.362
# EarlyStopping counter: 4 out of 10
# Epoch:64, [Train] Loss: 0.481
# Epoch:64, [Valid] Loss: 0.363
# EarlyStopping counter: 5 out of 10
# Epoch:65, [Train] Loss: 0.481
# Epoch:65, [Valid] Loss: 0.361
# EarlyStopping counter: 6 out of 10
# Epoch:66, [Train] Loss: 0.482
# Epoch:66, [Valid] Loss: 0.362
# EarlyStopping counter: 7 out of 10
# Epoch:67, [Train] Loss: 0.477
# Epoch:67, [Valid] Loss: 0.360
# EarlyStopping counter: 8 out of 10
# Epoch:68, [Train] Loss: 0.486
# Epoch:68, [Valid] Loss: 0.362
# EarlyStopping counter: 9 out of 10
# Epoch:69, [Train] Loss: 0.484
# Epoch:69, [Valid] Loss: 0.364
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 59, min loss: 0.3548
#
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  ckpt_CYP2C19_Veith.pt
# using BCELOSSwithdigits
# 100%|██████████| 20/20 [00:05<00:00,  3.67it/s]
# Found local copy...
# Loading...
# total_loss: 0.351
# *************** CYP2C19_Veith ***************
# AUROC: 0.9281 AUPRC: 0.9143 F1: 0.8508
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.859  &  0.860  &          0.828  &     0.875  &0.845  &0.851 &0.928 &   0.718 &   0.914
#
# *************** CYP2D6_Veith ***************
# Done!
# Cleaning mols: 100%|██████████| 9191/9191 [00:25<00:00, 360.00it/s]
# Cleaning mols: 100%|██████████| 1313/1313 [00:03<00:00, 369.99it/s]
# Cleaning mols: 100%|██████████| 2626/2626 [00:07<00:00, 358.04it/s]
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# **************************************** ['CYP2D6_Veith'] ****************************************
# ---> start training...
# Epoch:0, [Train] Loss: 0.600
# Epoch:0, [Valid] Loss: 0.466
# Epoch:1, [Train] Loss: 0.491
# Epoch:1, [Valid] Loss: 0.387
# Epoch:2, [Train] Loss: 0.465
# Epoch:2, [Valid] Loss: 0.354
# Epoch:3, [Train] Loss: 0.454
# Epoch:3, [Valid] Loss: 0.330
# Epoch:4, [Train] Loss: 0.449
# Epoch:4, [Valid] Loss: 0.316
# prev min loss 10000.000, now loss 0.316 | save model at epoch: 4
# *************** CYP2D6_Veith ***************
# AUROC: 0.9021 AUPRC: 0.7653 F1: 0.6567
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.878  &  0.769  &          0.743  &     0.588  &0.950  &0.657 &0.902 &   0.590 &   0.765
#
# Epoch:5, [Train] Loss: 0.451
# Epoch:5, [Valid] Loss: 0.321
# EarlyStopping counter: 1 out of 10
# Epoch:6, [Train] Loss: 0.440
# Epoch:6, [Valid] Loss: 0.306
# prev min loss 0.316, now loss 0.306 | save model at epoch: 6
# *************** CYP2D6_Veith ***************
# AUROC: 0.9088 AUPRC: 0.7800 F1: 0.6753
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.885  &  0.779  &          0.766  &     0.604  &0.954  &0.675 &0.909 &   0.613 &   0.780
#
# Epoch:7, [Train] Loss: 0.443
# Epoch:7, [Valid] Loss: 0.311
# EarlyStopping counter: 1 out of 10
# Epoch:8, [Train] Loss: 0.445
# Epoch:8, [Valid] Loss: 0.313
# EarlyStopping counter: 2 out of 10
# Epoch:9, [Train] Loss: 0.437
# Epoch:9, [Valid] Loss: 0.318
# EarlyStopping counter: 3 out of 10
# Epoch:10, [Train] Loss: 0.443
# Epoch:10, [Valid] Loss: 0.305
# prev min loss 0.306, now loss 0.305 | save model at epoch: 10
# *************** CYP2D6_Veith ***************
# AUROC: 0.9108 AUPRC: 0.7832 F1: 0.6929
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.887  &  0.795  &          0.752  &     0.642  &0.948  &0.693 &0.911 &   0.627 &   0.783
#
# Epoch:11, [Train] Loss: 0.443
# Epoch:11, [Valid] Loss: 0.307
# EarlyStopping counter: 1 out of 10
# Epoch:12, [Train] Loss: 0.439
# Epoch:12, [Valid] Loss: 0.304
# prev min loss 0.305, now loss 0.304 | save model at epoch: 12
# *************** CYP2D6_Veith ***************
# AUROC: 0.9105 AUPRC: 0.7820 F1: 0.7002
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.891  &  0.797  &          0.770  &     0.642  &0.953  &0.700 &0.911 &   0.638 &   0.782
#
# Epoch:13, [Train] Loss: 0.437
# Epoch:13, [Valid] Loss: 0.304
# EarlyStopping counter: 1 out of 10
# Epoch:14, [Train] Loss: 0.437
# Epoch:14, [Valid] Loss: 0.307
# EarlyStopping counter: 2 out of 10
# Epoch:15, [Train] Loss: 0.438
# Epoch:15, [Valid] Loss: 0.309
# EarlyStopping counter: 3 out of 10
# Epoch:16, [Train] Loss: 0.439
# Epoch:16, [Valid] Loss: 0.309
# EarlyStopping counter: 4 out of 10
# Epoch:17, [Train] Loss: 0.426
# Epoch:17, [Valid] Loss: 0.299
# prev min loss 0.304, now loss 0.299 | save model at epoch: 17
# *************** CYP2D6_Veith ***************
# AUROC: 0.9125 AUPRC: 0.7821 F1: 0.7126
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.892  &  0.811  &          0.752  &     0.677  &0.945  &0.713 &0.913 &   0.648 &   0.782
#
# Epoch:18, [Train] Loss: 0.442
# Epoch:18, [Valid] Loss: 0.297
# prev min loss 0.299, now loss 0.297 | save model at epoch: 18
# *************** CYP2D6_Veith ***************
# AUROC: 0.9122 AUPRC: 0.7828 F1: 0.6866
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.888  &  0.787  &          0.770  &     0.619  &0.954  &0.687 &0.912 &   0.625 &   0.783
#
# Epoch:19, [Train] Loss: 0.440
# Epoch:19, [Valid] Loss: 0.307
# EarlyStopping counter: 1 out of 10
# Epoch:20, [Train] Loss: 0.428
# Epoch:20, [Valid] Loss: 0.303
# EarlyStopping counter: 2 out of 10
# Epoch:21, [Train] Loss: 0.430
# Epoch:21, [Valid] Loss: 0.304
# EarlyStopping counter: 3 out of 10
# Epoch:22, [Train] Loss: 0.429
# Epoch:22, [Valid] Loss: 0.304
# EarlyStopping counter: 4 out of 10
# Epoch:23, [Train] Loss: 0.441
# Epoch:23, [Valid] Loss: 0.305
# EarlyStopping counter: 5 out of 10
# Epoch:24, [Train] Loss: 0.432
# Epoch:24, [Valid] Loss: 0.302
# EarlyStopping counter: 6 out of 10
# Epoch:25, [Train] Loss: 0.436
# Epoch:25, [Valid] Loss: 0.307
# EarlyStopping counter: 7 out of 10
# Epoch:26, [Train] Loss: 0.438
# Epoch:26, [Valid] Loss: 0.310
# EarlyStopping counter: 8 out of 10
# Epoch:27, [Train] Loss: 0.438
# Epoch:27, [Valid] Loss: 0.301
# EarlyStopping counter: 9 out of 10
# Epoch:28, [Train] Loss: 0.431
# Epoch:28, [Valid] Loss: 0.306
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 18, min loss: 0.2971
#
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  ckpt_CYP2D6_Veith.pt
# using BCELOSSwithdigits
# 100%|██████████| 21/21 [00:05<00:00,  3.82it/s]
# Found local copy...
# Loading...
# total_loss: 0.296
# *************** CYP2D6_Veith ***************
# AUROC: 0.9058 AUPRC: 0.7542 F1: 0.6735
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.891  &  0.780  &          0.764  &     0.602  &0.957  &0.674 &0.906 &   0.616 &   0.754
#
# *************** CYP3A4_Veith ***************
# Done!
# Cleaning mols: 100%|██████████| 8629/8629 [00:23<00:00, 361.55it/s]
# Cleaning mols: 100%|██████████| 1233/1233 [00:03<00:00, 357.89it/s]
# Cleaning mols: 100%|██████████| 2466/2466 [00:06<00:00, 361.85it/s]
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# **************************************** ['CYP3A4_Veith'] ****************************************
# ---> start training...
# Epoch:0, [Train] Loss: 0.661
# Epoch:0, [Valid] Loss: 0.585
# Epoch:1, [Train] Loss: 0.580
# Epoch:1, [Valid] Loss: 0.454
# Epoch:2, [Train] Loss: 0.537
# Epoch:2, [Valid] Loss: 0.411
# Epoch:3, [Train] Loss: 0.525
# Epoch:3, [Valid] Loss: 0.397
# Epoch:4, [Train] Loss: 0.527
# Epoch:4, [Valid] Loss: 0.392
# prev min loss 10000.000, now loss 0.392 | save model at epoch: 4
# *************** CYP3A4_Veith ***************
# AUROC: 0.9235 AUPRC: 0.9009 F1: 0.8167
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.836  &  0.841  &          0.768  &     0.872  &0.810  &0.817 &0.924 &   0.674 &   0.901
#
# Epoch:5, [Train] Loss: 0.524
# Epoch:5, [Valid] Loss: 0.387
# prev min loss 0.392, now loss 0.387 | save model at epoch: 5
# *************** CYP3A4_Veith ***************
# AUROC: 0.9238 AUPRC: 0.9021 F1: 0.8149
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.839  &  0.840  &          0.784  &     0.849  &0.831  &0.815 &0.924 &   0.674 &   0.902
#
# Epoch:6, [Train] Loss: 0.522
# Epoch:6, [Valid] Loss: 0.386
# prev min loss 0.387, now loss 0.386 | save model at epoch: 6
# *************** CYP3A4_Veith ***************
# AUROC: 0.9242 AUPRC: 0.9019 F1: 0.8171
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.840  &  0.842  &          0.784  &     0.853  &0.831  &0.817 &0.924 &   0.678 &   0.902
#
# Epoch:7, [Train] Loss: 0.517
# Epoch:7, [Valid] Loss: 0.380
# prev min loss 0.386, now loss 0.380 | save model at epoch: 7
# *************** CYP3A4_Veith ***************
# AUROC: 0.9255 AUPRC: 0.9046 F1: 0.8183
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.839  &  0.843  &          0.777  &     0.864  &0.821  &0.818 &0.926 &   0.678 &   0.905
#
# Epoch:8, [Train] Loss: 0.520
# Epoch:8, [Valid] Loss: 0.379
# prev min loss 0.380, now loss 0.379 | save model at epoch: 8
# *************** CYP3A4_Veith ***************
# AUROC: 0.9253 AUPRC: 0.9040 F1: 0.8155
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.838  &  0.840  &          0.778  &     0.857  &0.824  &0.815 &0.925 &   0.674 &   0.904
#
# Epoch:9, [Train] Loss: 0.514
# Epoch:9, [Valid] Loss: 0.381
# EarlyStopping counter: 1 out of 10
# Epoch:10, [Train] Loss: 0.522
# Epoch:10, [Valid] Loss: 0.387
# EarlyStopping counter: 2 out of 10
# Epoch:11, [Train] Loss: 0.517
# Epoch:11, [Valid] Loss: 0.384
# EarlyStopping counter: 3 out of 10
# Epoch:12, [Train] Loss: 0.520
# Epoch:12, [Valid] Loss: 0.378
# prev min loss 0.379, now loss 0.378 | save model at epoch: 12
# *************** CYP3A4_Veith ***************
# AUROC: 0.9254 AUPRC: 0.9038 F1: 0.8143
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.840  &  0.840  &          0.793  &     0.837  &0.842  &0.814 &0.925 &   0.675 &   0.904
#
# Epoch:13, [Train] Loss: 0.510
# Epoch:13, [Valid] Loss: 0.374
# prev min loss 0.378, now loss 0.374 | save model at epoch: 13
# *************** CYP3A4_Veith ***************
# AUROC: 0.9255 AUPRC: 0.9050 F1: 0.8130
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.836  &  0.838  &          0.778  &     0.851  &0.826  &0.813 &0.926 &   0.670 &   0.905
#
# Epoch:14, [Train] Loss: 0.510
# Epoch:14, [Valid] Loss: 0.377
# EarlyStopping counter: 1 out of 10
# Epoch:15, [Train] Loss: 0.514
# Epoch:15, [Valid] Loss: 0.375
# EarlyStopping counter: 2 out of 10
# Epoch:16, [Train] Loss: 0.511
# Epoch:16, [Valid] Loss: 0.375
# EarlyStopping counter: 3 out of 10
# Epoch:17, [Train] Loss: 0.518
# Epoch:17, [Valid] Loss: 0.382
# EarlyStopping counter: 4 out of 10
# Epoch:18, [Train] Loss: 0.515
# Epoch:18, [Valid] Loss: 0.373
# prev min loss 0.374, now loss 0.373 | save model at epoch: 18
# *************** CYP3A4_Veith ***************
# AUROC: 0.9266 AUPRC: 0.9074 F1: 0.8142
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.839  &  0.839  &          0.786  &     0.845  &0.834  &0.814 &0.927 &   0.673 &   0.907
#
# Epoch:19, [Train] Loss: 0.508
# Epoch:19, [Valid] Loss: 0.375
# EarlyStopping counter: 1 out of 10
# Epoch:20, [Train] Loss: 0.513
# Epoch:20, [Valid] Loss: 0.375
# EarlyStopping counter: 2 out of 10
# Epoch:21, [Train] Loss: 0.508
# Epoch:21, [Valid] Loss: 0.375
# EarlyStopping counter: 3 out of 10
# Epoch:22, [Train] Loss: 0.512
# Epoch:22, [Valid] Loss: 0.376
# EarlyStopping counter: 4 out of 10
# Epoch:23, [Train] Loss: 0.507
# Epoch:23, [Valid] Loss: 0.365
# prev min loss 0.373, now loss 0.365 | save model at epoch: 23
# *************** CYP3A4_Veith ***************
# AUROC: 0.9281 AUPRC: 0.9092 F1: 0.8248
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.851  &  0.849  &          0.811  &     0.839  &0.859  &0.825 &0.928 &   0.695 &   0.909
#
# Epoch:24, [Train] Loss: 0.508
# Epoch:24, [Valid] Loss: 0.365
# prev min loss 0.365, now loss 0.365 | save model at epoch: 24
# *************** CYP3A4_Veith ***************
# AUROC: 0.9285 AUPRC: 0.9102 F1: 0.8285
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.852  &  0.852  &          0.802  &     0.857  &0.848  &0.828 &0.928 &   0.699 &   0.910
#
# Epoch:25, [Train] Loss: 0.517
# Epoch:25, [Valid] Loss: 0.370
# EarlyStopping counter: 1 out of 10
# Epoch:26, [Train] Loss: 0.503
# Epoch:26, [Valid] Loss: 0.372
# EarlyStopping counter: 2 out of 10
# Epoch:27, [Train] Loss: 0.499
# Epoch:27, [Valid] Loss: 0.365
# prev min loss 0.365, now loss 0.365 | save model at epoch: 27
# *************** CYP3A4_Veith ***************
# AUROC: 0.9271 AUPRC: 0.9080 F1: 0.8203
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.845  &  0.845  &          0.797  &     0.845  &0.845  &0.820 &0.927 &   0.685 &   0.908
#
# Epoch:28, [Train] Loss: 0.507
# Epoch:28, [Valid] Loss: 0.363
# prev min loss 0.365, now loss 0.363 | save model at epoch: 28
# *************** CYP3A4_Veith ***************
# AUROC: 0.9290 AUPRC: 0.9111 F1: 0.8174
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.843  &  0.843  &          0.799  &     0.837  &0.848  &0.817 &0.929 &   0.681 &   0.911
#
# Epoch:29, [Train] Loss: 0.502
# Epoch:29, [Valid] Loss: 0.363
# prev min loss 0.363, now loss 0.363 | save model at epoch: 29
# *************** CYP3A4_Veith ***************
# AUROC: 0.9295 AUPRC: 0.9118 F1: 0.8240
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.848  &  0.848  &          0.797  &     0.853  &0.844  &0.824 &0.930 &   0.691 &   0.912
#
# Epoch:30, [Train] Loss: 0.500
# Epoch:30, [Valid] Loss: 0.364
# EarlyStopping counter: 1 out of 10
# Epoch:31, [Train] Loss: 0.501
# Epoch:31, [Valid] Loss: 0.366
# EarlyStopping counter: 2 out of 10
# Epoch:32, [Train] Loss: 0.507
# Epoch:32, [Valid] Loss: 0.361
# prev min loss 0.363, now loss 0.361 | save model at epoch: 32
# *************** CYP3A4_Veith ***************
# AUROC: 0.9313 AUPRC: 0.9150 F1: 0.8286
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.854  &  0.852  &          0.815  &     0.843  &0.862  &0.829 &0.931 &   0.702 &   0.915
#
# Epoch:33, [Train] Loss: 0.505
# Epoch:33, [Valid] Loss: 0.365
# EarlyStopping counter: 1 out of 10
# Epoch:34, [Train] Loss: 0.497
# Epoch:34, [Valid] Loss: 0.359
# prev min loss 0.361, now loss 0.359 | save model at epoch: 34
# *************** CYP3A4_Veith ***************
# AUROC: 0.9312 AUPRC: 0.9142 F1: 0.8286
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.852  &  0.852  &          0.806  &     0.853  &0.852  &0.829 &0.931 &   0.700 &   0.914
#
# Epoch:35, [Train] Loss: 0.502
# Epoch:35, [Valid] Loss: 0.359
# EarlyStopping counter: 1 out of 10
# Epoch:36, [Train] Loss: 0.499
# Epoch:36, [Valid] Loss: 0.359
# prev min loss 0.359, now loss 0.359 | save model at epoch: 36
# *************** CYP3A4_Veith ***************
# AUROC: 0.9320 AUPRC: 0.9154 F1: 0.8288
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.853  &  0.853  &          0.810  &     0.849  &0.856  &0.829 &0.932 &   0.701 &   0.915
#
# Epoch:37, [Train] Loss: 0.492
# Epoch:37, [Valid] Loss: 0.355
# prev min loss 0.359, now loss 0.355 | save model at epoch: 37
# *************** CYP3A4_Veith ***************
# AUROC: 0.9313 AUPRC: 0.9141 F1: 0.8285
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.856  &  0.853  &          0.824  &     0.833  &0.872  &0.829 &0.931 &   0.704 &   0.914
#
# Epoch:38, [Train] Loss: 0.494
# Epoch:38, [Valid] Loss: 0.355
# EarlyStopping counter: 1 out of 10
# Epoch:39, [Train] Loss: 0.499
# Epoch:39, [Valid] Loss: 0.354
# prev min loss 0.355, now loss 0.354 | save model at epoch: 39
# *************** CYP3A4_Veith ***************
# AUROC: 0.9322 AUPRC: 0.9155 F1: 0.8259
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.854  &  0.850  &          0.824  &     0.828  &0.873  &0.826 &0.932 &   0.700 &   0.916
#
# Epoch:40, [Train] Loss: 0.497
# Epoch:40, [Valid] Loss: 0.356
# EarlyStopping counter: 1 out of 10
# Epoch:41, [Train] Loss: 0.496
# Epoch:41, [Valid] Loss: 0.358
# EarlyStopping counter: 2 out of 10
# Epoch:42, [Train] Loss: 0.498
# Epoch:42, [Valid] Loss: 0.357
# EarlyStopping counter: 3 out of 10
# Epoch:43, [Train] Loss: 0.497
# Epoch:43, [Valid] Loss: 0.355
# EarlyStopping counter: 4 out of 10
# Epoch:44, [Train] Loss: 0.496
# Epoch:44, [Valid] Loss: 0.357
# EarlyStopping counter: 5 out of 10
# Epoch:45, [Train] Loss: 0.494
# Epoch:45, [Valid] Loss: 0.353
# prev min loss 0.354, now loss 0.353 | save model at epoch: 45
# *************** CYP3A4_Veith ***************
# AUROC: 0.9326 AUPRC: 0.9166 F1: 0.8254
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.851  &  0.850  &          0.809  &     0.843  &0.856  &0.825 &0.933 &   0.696 &   0.917
#
# Epoch:46, [Train] Loss: 0.496
# Epoch:46, [Valid] Loss: 0.355
# EarlyStopping counter: 1 out of 10
# Epoch:47, [Train] Loss: 0.497
# Epoch:47, [Valid] Loss: 0.355
# EarlyStopping counter: 2 out of 10
# Epoch:48, [Train] Loss: 0.496
# Epoch:48, [Valid] Loss: 0.354
# EarlyStopping counter: 3 out of 10
# Epoch:49, [Train] Loss: 0.494
# Epoch:49, [Valid] Loss: 0.356
# EarlyStopping counter: 4 out of 10
# Epoch:50, [Train] Loss: 0.483
# Epoch:50, [Valid] Loss: 0.349
# prev min loss 0.353, now loss 0.349 | save model at epoch: 50
# *************** CYP3A4_Veith ***************
# AUROC: 0.9323 AUPRC: 0.9160 F1: 0.8196
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.848  &  0.845  &          0.812  &     0.828  &0.862  &0.820 &0.932 &   0.688 &   0.916
#
# Epoch:51, [Train] Loss: 0.485
# Epoch:51, [Valid] Loss: 0.353
# EarlyStopping counter: 1 out of 10
# Epoch:52, [Train] Loss: 0.486
# Epoch:52, [Valid] Loss: 0.351
# EarlyStopping counter: 2 out of 10
# Epoch:53, [Train] Loss: 0.486
# Epoch:53, [Valid] Loss: 0.349
# EarlyStopping counter: 3 out of 10
# Epoch:54, [Train] Loss: 0.489
# Epoch:54, [Valid] Loss: 0.347
# prev min loss 0.349, now loss 0.347 | save model at epoch: 54
# *************** CYP3A4_Veith ***************
# AUROC: 0.9333 AUPRC: 0.9179 F1: 0.8217
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.848  &  0.847  &          0.809  &     0.835  &0.858  &0.822 &0.933 &   0.690 &   0.918
#
# Epoch:55, [Train] Loss: 0.493
# Epoch:55, [Valid] Loss: 0.352
# EarlyStopping counter: 1 out of 10
# Epoch:56, [Train] Loss: 0.481
# Epoch:56, [Valid] Loss: 0.348
# EarlyStopping counter: 2 out of 10
# Epoch:57, [Train] Loss: 0.491
# Epoch:57, [Valid] Loss: 0.353
# EarlyStopping counter: 3 out of 10
# Epoch:58, [Train] Loss: 0.494
# Epoch:58, [Valid] Loss: 0.351
# EarlyStopping counter: 4 out of 10
# Epoch:59, [Train] Loss: 0.488
# Epoch:59, [Valid] Loss: 0.350
# EarlyStopping counter: 5 out of 10
# Epoch:60, [Train] Loss: 0.487
# Epoch:60, [Valid] Loss: 0.350
# EarlyStopping counter: 6 out of 10
# Epoch:61, [Train] Loss: 0.489
# Epoch:61, [Valid] Loss: 0.352
# EarlyStopping counter: 7 out of 10
# Epoch:62, [Train] Loss: 0.484
# Epoch:62, [Valid] Loss: 0.348
# EarlyStopping counter: 8 out of 10
# Epoch:63, [Train] Loss: 0.479
# Epoch:63, [Valid] Loss: 0.352
# EarlyStopping counter: 9 out of 10
# Epoch:64, [Train] Loss: 0.486
# Epoch:64, [Valid] Loss: 0.352
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 54, min loss: 0.3472
#
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  ckpt_CYP3A4_Veith.pt
# using BCELOSSwithdigits
# 100%|██████████| 20/20 [00:05<00:00,  3.91it/s]
# Found local copy...
# Loading...
# total_loss: 0.363
# *************** CYP3A4_Veith ***************
# AUROC: 0.9247 AUPRC: 0.8918 F1: 0.8165
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.846  &  0.844  &          0.804  &     0.829  &0.859  &0.816 &0.925 &   0.685 &   0.892
#
# *************** CYP1A2_Veith ***************
# Done!
# Cleaning mols: 100%|██████████| 8805/8805 [00:24<00:00, 365.82it/s]
# Cleaning mols: 100%|██████████| 1258/1258 [00:03<00:00, 370.34it/s]
# Cleaning mols: 100%|██████████| 2516/2516 [00:06<00:00, 365.49it/s]
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# **************************************** ['CYP1A2_Veith'] ****************************************
# ---> start training...
# Epoch:0, [Train] Loss: 0.663
# Epoch:0, [Valid] Loss: 0.579
# Epoch:1, [Train] Loss: 0.539
# Epoch:1, [Valid] Loss: 0.379
# Epoch:2, [Train] Loss: 0.489
# Epoch:2, [Valid] Loss: 0.346
# Epoch:3, [Train] Loss: 0.484
# Epoch:3, [Valid] Loss: 0.338
# Epoch:4, [Train] Loss: 0.484
# Epoch:4, [Valid] Loss: 0.333
# prev min loss 10000.000, now loss 0.333 | save model at epoch: 4
# *************** CYP1A2_Veith ***************
# AUROC: 0.9463 AUPRC: 0.9426 F1: 0.8696
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.878  &  0.878  &          0.861  &     0.878  &0.879  &0.870 &0.946 &   0.756 &   0.943
#
# Epoch:5, [Train] Loss: 0.479
# Epoch:5, [Valid] Loss: 0.323
# prev min loss 0.333, now loss 0.323 | save model at epoch: 5
# *************** CYP1A2_Veith ***************
# AUROC: 0.9476 AUPRC: 0.9439 F1: 0.8702
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.880  &  0.879  &          0.869  &     0.871  &0.888  &0.870 &0.948 &   0.759 &   0.944
#
# Epoch:6, [Train] Loss: 0.478
# Epoch:6, [Valid] Loss: 0.324
# EarlyStopping counter: 1 out of 10
# Epoch:7, [Train] Loss: 0.480
# Epoch:7, [Valid] Loss: 0.321
# prev min loss 0.323, now loss 0.321 | save model at epoch: 7
# *************** CYP1A2_Veith ***************
# AUROC: 0.9495 AUPRC: 0.9459 F1: 0.8669
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.879  &  0.877  &          0.882  &     0.852  &0.903  &0.867 &0.949 &   0.757 &   0.946
#
# Epoch:8, [Train] Loss: 0.476
# Epoch:8, [Valid] Loss: 0.320
# prev min loss 0.321, now loss 0.320 | save model at epoch: 8
# *************** CYP1A2_Veith ***************
# AUROC: 0.9496 AUPRC: 0.9462 F1: 0.8714
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.883  &  0.881  &          0.886  &     0.857  &0.905  &0.871 &0.950 &   0.765 &   0.946
#
# Epoch:9, [Train] Loss: 0.475
# Epoch:9, [Valid] Loss: 0.317
# prev min loss 0.320, now loss 0.317 | save model at epoch: 9
# *************** CYP1A2_Veith ***************
# AUROC: 0.9498 AUPRC: 0.9464 F1: 0.8740
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.883  &  0.883  &          0.870  &     0.878  &0.888  &0.874 &0.950 &   0.765 &   0.946
#
# Epoch:10, [Train] Loss: 0.472
# Epoch:10, [Valid] Loss: 0.315
# prev min loss 0.317, now loss 0.315 | save model at epoch: 10
# *************** CYP1A2_Veith ***************
# AUROC: 0.9505 AUPRC: 0.9469 F1: 0.8766
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.886  &  0.885  &          0.879  &     0.874  &0.897  &0.877 &0.950 &   0.771 &   0.947
#
# Epoch:11, [Train] Loss: 0.471
# Epoch:11, [Valid] Loss: 0.314
# prev min loss 0.315, now loss 0.314 | save model at epoch: 11
# *************** CYP1A2_Veith ***************
# AUROC: 0.9506 AUPRC: 0.9466 F1: 0.8794
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.890  &  0.888  &          0.886  &     0.873  &0.904  &0.879 &0.951 &   0.778 &   0.947
#
# Epoch:12, [Train] Loss: 0.474
# Epoch:12, [Valid] Loss: 0.315
# EarlyStopping counter: 1 out of 10
# Epoch:13, [Train] Loss: 0.468
# Epoch:13, [Valid] Loss: 0.312
# prev min loss 0.314, now loss 0.312 | save model at epoch: 13
# *************** CYP1A2_Veith ***************
# AUROC: 0.9499 AUPRC: 0.9459 F1: 0.8720
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.882  &  0.881  &          0.877  &     0.867  &0.895  &0.872 &0.950 &   0.763 &   0.946
#
# Epoch:14, [Train] Loss: 0.464
# Epoch:14, [Valid] Loss: 0.311
# prev min loss 0.312, now loss 0.311 | save model at epoch: 14
# *************** CYP1A2_Veith ***************
# AUROC: 0.9503 AUPRC: 0.9460 F1: 0.8654
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.878  &  0.876  &          0.885  &     0.847  &0.905  &0.865 &0.950 &   0.755 &   0.946
#
# Epoch:15, [Train] Loss: 0.470
# Epoch:15, [Valid] Loss: 0.315
# EarlyStopping counter: 1 out of 10
# Epoch:16, [Train] Loss: 0.470
# Epoch:16, [Valid] Loss: 0.313
# EarlyStopping counter: 2 out of 10
# Epoch:17, [Train] Loss: 0.468
# Epoch:17, [Valid] Loss: 0.309
# prev min loss 0.311, now loss 0.309 | save model at epoch: 17
# *************** CYP1A2_Veith ***************
# AUROC: 0.9507 AUPRC: 0.9463 F1: 0.8813
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.890  &  0.889  &          0.875  &     0.888  &0.891  &0.881 &0.951 &   0.778 &   0.946
#
# Epoch:18, [Train] Loss: 0.468
# Epoch:18, [Valid] Loss: 0.315
# EarlyStopping counter: 1 out of 10
# Epoch:19, [Train] Loss: 0.467
# Epoch:19, [Valid] Loss: 0.312
# EarlyStopping counter: 2 out of 10
# Epoch:20, [Train] Loss: 0.463
# Epoch:20, [Valid] Loss: 0.309
# prev min loss 0.309, now loss 0.309 | save model at epoch: 20
# *************** CYP1A2_Veith ***************
# AUROC: 0.9505 AUPRC: 0.9460 F1: 0.8699
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.882  &  0.880  &          0.883  &     0.857  &0.903  &0.870 &0.950 &   0.762 &   0.946
#
# Epoch:21, [Train] Loss: 0.464
# Epoch:21, [Valid] Loss: 0.312
# EarlyStopping counter: 1 out of 10
# Epoch:22, [Train] Loss: 0.464
# Epoch:22, [Valid] Loss: 0.308
# prev min loss 0.309, now loss 0.308 | save model at epoch: 22
# *************** CYP1A2_Veith ***************
# AUROC: 0.9508 AUPRC: 0.9465 F1: 0.8715
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.882  &  0.881  &          0.879  &     0.864  &0.898  &0.872 &0.951 &   0.763 &   0.947
#
# Epoch:23, [Train] Loss: 0.460
# Epoch:23, [Valid] Loss: 0.307
# prev min loss 0.308, now loss 0.307 | save model at epoch: 23
# *************** CYP1A2_Veith ***************
# AUROC: 0.9505 AUPRC: 0.9462 F1: 0.8716
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.883  &  0.881  &          0.885  &     0.859  &0.904  &0.872 &0.950 &   0.765 &   0.946
#
# Epoch:24, [Train] Loss: 0.467
# Epoch:24, [Valid] Loss: 0.310
# EarlyStopping counter: 1 out of 10
# Epoch:25, [Train] Loss: 0.468
# Epoch:25, [Valid] Loss: 0.311
# EarlyStopping counter: 2 out of 10
# Epoch:26, [Train] Loss: 0.461
# Epoch:26, [Valid] Loss: 0.308
# EarlyStopping counter: 3 out of 10
# Epoch:27, [Train] Loss: 0.465
# Epoch:27, [Valid] Loss: 0.312
# EarlyStopping counter: 4 out of 10
# Epoch:28, [Train] Loss: 0.456
# Epoch:28, [Valid] Loss: 0.308
# EarlyStopping counter: 5 out of 10
# Epoch:29, [Train] Loss: 0.460
# Epoch:29, [Valid] Loss: 0.307
# EarlyStopping counter: 6 out of 10
# Epoch:30, [Train] Loss: 0.461
# Epoch:30, [Valid] Loss: 0.308
# EarlyStopping counter: 7 out of 10
# Epoch:31, [Train] Loss: 0.463
# Epoch:31, [Valid] Loss: 0.308
# EarlyStopping counter: 8 out of 10
# Epoch:32, [Train] Loss: 0.460
# Epoch:32, [Valid] Loss: 0.306
# prev min loss 0.307, now loss 0.306 | save model at epoch: 32
# *************** CYP1A2_Veith ***************
# AUROC: 0.9503 AUPRC: 0.9460 F1: 0.8726
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.882  &  0.882  &          0.873  &     0.873  &0.891  &0.873 &0.950 &   0.763 &   0.946
#
# Epoch:33, [Train] Loss: 0.459
# Epoch:33, [Valid] Loss: 0.309
# EarlyStopping counter: 1 out of 10
# Epoch:34, [Train] Loss: 0.456
# Epoch:34, [Valid] Loss: 0.305
# prev min loss 0.306, now loss 0.305 | save model at epoch: 34
# *************** CYP1A2_Veith ***************
# AUROC: 0.9504 AUPRC: 0.9461 F1: 0.8765
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.886  &  0.885  &          0.874  &     0.880  &0.891  &0.877 &0.950 &   0.770 &   0.946
#
# Epoch:35, [Train] Loss: 0.457
# Epoch:35, [Valid] Loss: 0.309
# EarlyStopping counter: 1 out of 10
# Epoch:36, [Train] Loss: 0.462
# Epoch:36, [Valid] Loss: 0.307
# EarlyStopping counter: 2 out of 10
# Epoch:37, [Train] Loss: 0.457
# Epoch:37, [Valid] Loss: 0.305
# EarlyStopping counter: 3 out of 10
# Epoch:38, [Train] Loss: 0.458
# Epoch:38, [Valid] Loss: 0.310
# EarlyStopping counter: 4 out of 10
# Epoch:39, [Train] Loss: 0.461
# Epoch:39, [Valid] Loss: 0.303
# prev min loss 0.305, now loss 0.303 | save model at epoch: 39
# *************** CYP1A2_Veith ***************
# AUROC: 0.9506 AUPRC: 0.9459 F1: 0.8709
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.881  &  0.880  &          0.871  &     0.871  &0.889  &0.871 &0.951 &   0.760 &   0.946
#
# Epoch:40, [Train] Loss: 0.453
# Epoch:40, [Valid] Loss: 0.303
# EarlyStopping counter: 1 out of 10
# Epoch:41, [Train] Loss: 0.453
# Epoch:41, [Valid] Loss: 0.303
# EarlyStopping counter: 2 out of 10
# Epoch:42, [Train] Loss: 0.450
# Epoch:42, [Valid] Loss: 0.302
# prev min loss 0.303, now loss 0.302 | save model at epoch: 42
# *************** CYP1A2_Veith ***************
# AUROC: 0.9511 AUPRC: 0.9461 F1: 0.8727
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.883  &  0.882  &          0.878  &     0.867  &0.897  &0.873 &0.951 &   0.765 &   0.946
#
# Epoch:43, [Train] Loss: 0.456
# Epoch:43, [Valid] Loss: 0.306
# EarlyStopping counter: 1 out of 10
# Epoch:44, [Train] Loss: 0.456
# Epoch:44, [Valid] Loss: 0.305
# EarlyStopping counter: 2 out of 10
# Epoch:45, [Train] Loss: 0.451
# Epoch:45, [Valid] Loss: 0.299
# prev min loss 0.302, now loss 0.299 | save model at epoch: 45
# *************** CYP1A2_Veith ***************
# AUROC: 0.9513 AUPRC: 0.9472 F1: 0.8767
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.886  &  0.885  &          0.872  &     0.881  &0.889  &0.877 &0.951 &   0.770 &   0.947
#
# Epoch:46, [Train] Loss: 0.453
# Epoch:46, [Valid] Loss: 0.303
# EarlyStopping counter: 1 out of 10
# Epoch:47, [Train] Loss: 0.454
# Epoch:47, [Valid] Loss: 0.301
# EarlyStopping counter: 2 out of 10
# Epoch:48, [Train] Loss: 0.453
# Epoch:48, [Valid] Loss: 0.303
# EarlyStopping counter: 3 out of 10
# Epoch:49, [Train] Loss: 0.451
# Epoch:49, [Valid] Loss: 0.301
# EarlyStopping counter: 4 out of 10
# Epoch:50, [Train] Loss: 0.446
# Epoch:50, [Valid] Loss: 0.300
# EarlyStopping counter: 5 out of 10
# Epoch:51, [Train] Loss: 0.447
# Epoch:51, [Valid] Loss: 0.297
# prev min loss 0.299, now loss 0.297 | save model at epoch: 51
# *************** CYP1A2_Veith ***************
# AUROC: 0.9513 AUPRC: 0.9475 F1: 0.8762
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.886  &  0.885  &          0.882  &     0.871  &0.900  &0.876 &0.951 &   0.771 &   0.948
#
# Epoch:52, [Train] Loss: 0.451
# Epoch:52, [Valid] Loss: 0.299
# EarlyStopping counter: 1 out of 10
# Epoch:53, [Train] Loss: 0.450
# Epoch:53, [Valid] Loss: 0.297
# prev min loss 0.297, now loss 0.297 | save model at epoch: 53
# *************** CYP1A2_Veith ***************
# AUROC: 0.9511 AUPRC: 0.9476 F1: 0.8798
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.888  &  0.888  &          0.872  &     0.888  &0.888  &0.880 &0.951 &   0.775 &   0.948
#
# Epoch:54, [Train] Loss: 0.451
# Epoch:54, [Valid] Loss: 0.299
# EarlyStopping counter: 1 out of 10
# Epoch:55, [Train] Loss: 0.455
# Epoch:55, [Valid] Loss: 0.305
# EarlyStopping counter: 2 out of 10
# Epoch:56, [Train] Loss: 0.451
# Epoch:56, [Valid] Loss: 0.299
# EarlyStopping counter: 3 out of 10
# Epoch:57, [Train] Loss: 0.445
# Epoch:57, [Valid] Loss: 0.295
# prev min loss 0.297, now loss 0.295 | save model at epoch: 57
# *************** CYP1A2_Veith ***************
# AUROC: 0.9520 AUPRC: 0.9482 F1: 0.8808
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.890  &  0.889  &          0.884  &     0.878  &0.901  &0.881 &0.952 &   0.779 &   0.948
#
# Epoch:58, [Train] Loss: 0.447
# Epoch:58, [Valid] Loss: 0.301
# EarlyStopping counter: 1 out of 10
# Epoch:59, [Train] Loss: 0.453
# Epoch:59, [Valid] Loss: 0.298
# EarlyStopping counter: 2 out of 10
# Epoch:60, [Train] Loss: 0.449
# Epoch:60, [Valid] Loss: 0.296
# EarlyStopping counter: 3 out of 10
# Epoch:61, [Train] Loss: 0.454
# Epoch:61, [Valid] Loss: 0.301
# EarlyStopping counter: 4 out of 10
# Epoch:62, [Train] Loss: 0.447
# Epoch:62, [Valid] Loss: 0.296
# EarlyStopping counter: 5 out of 10
# Epoch:63, [Train] Loss: 0.455
# Epoch:63, [Valid] Loss: 0.300
# EarlyStopping counter: 6 out of 10
# Epoch:64, [Train] Loss: 0.450
# Epoch:64, [Valid] Loss: 0.299
# EarlyStopping counter: 7 out of 10
# Epoch:65, [Train] Loss: 0.446
# Epoch:65, [Valid] Loss: 0.296
# EarlyStopping counter: 8 out of 10
# Epoch:66, [Train] Loss: 0.445
# Epoch:66, [Valid] Loss: 0.297
# EarlyStopping counter: 9 out of 10
# Epoch:67, [Train] Loss: 0.442
# Epoch:67, [Valid] Loss: 0.297
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 57, min loss: 0.2950
#
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  ckpt_CYP1A2_Veith.pt
# using BCELOSSwithdigits
# 100%|██████████| 20/20 [00:05<00:00,  3.63it/s]
# Found local copy...
# Loading...
# total_loss: 0.298
# *************** CYP1A2_Veith ***************
# AUROC: 0.9510 AUPRC: 0.9477 F1: 0.8756
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.883  &  0.882  &          0.877  &     0.874  &0.891  &0.876 &0.951 &   0.765 &   0.948
#
# *************** CYP2C9_Veith ***************
# Done!
# Cleaning mols: 100%|██████████| 8465/8465 [00:23<00:00, 355.46it/s]
# Cleaning mols: 100%|██████████| 1209/1209 [00:03<00:00, 354.11it/s]
# Cleaning mols: 100%|██████████| 2418/2418 [00:06<00:00, 348.25it/s]
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# **************************************** ['CYP2C9_Veith'] ****************************************
# ---> start training...
# Epoch:0, [Train] Loss: 0.656
# Epoch:0, [Valid] Loss: 0.580
# Epoch:1, [Train] Loss: 0.569
# Epoch:1, [Valid] Loss: 0.450
# Epoch:2, [Train] Loss: 0.522
# Epoch:2, [Valid] Loss: 0.384
# Epoch:3, [Train] Loss: 0.505
# Epoch:3, [Valid] Loss: 0.373
# Epoch:4, [Train] Loss: 0.496
# Epoch:4, [Valid] Loss: 0.360
# prev min loss 10000.000, now loss 0.360 | save model at epoch: 4
# *************** CYP2C9_Veith ***************
# AUROC: 0.9273 AUPRC: 0.8594 F1: 0.7914
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.856  &  0.842  &          0.784  &     0.799  &0.886  &0.791 &0.927 &   0.682 &   0.859
#
# Epoch:5, [Train] Loss: 0.502
# Epoch:5, [Valid] Loss: 0.366
# EarlyStopping counter: 1 out of 10
# Epoch:6, [Train] Loss: 0.498
# Epoch:6, [Valid] Loss: 0.360
# EarlyStopping counter: 2 out of 10
# Epoch:7, [Train] Loss: 0.494
# Epoch:7, [Valid] Loss: 0.353
# prev min loss 0.360, now loss 0.353 | save model at epoch: 7
# *************** CYP2C9_Veith ***************
# AUROC: 0.9302 AUPRC: 0.8627 F1: 0.7990
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.860  &  0.849  &          0.785  &     0.814  &0.884  &0.799 &0.930 &   0.692 &   0.863
#
# Epoch:8, [Train] Loss: 0.492
# Epoch:8, [Valid] Loss: 0.353
# EarlyStopping counter: 1 out of 10
# Epoch:9, [Train] Loss: 0.492
# Epoch:9, [Valid] Loss: 0.352
# prev min loss 0.353, now loss 0.352 | save model at epoch: 9
# *************** CYP2C9_Veith ***************
# AUROC: 0.9309 AUPRC: 0.8643 F1: 0.8019
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.860  &  0.852  &          0.777  &     0.828  &0.877  &0.802 &0.931 &   0.695 &   0.864
#
# Epoch:10, [Train] Loss: 0.492
# Epoch:10, [Valid] Loss: 0.356
# EarlyStopping counter: 1 out of 10
# Epoch:11, [Train] Loss: 0.488
# Epoch:11, [Valid] Loss: 0.354
# EarlyStopping counter: 2 out of 10
# Epoch:12, [Train] Loss: 0.488
# Epoch:12, [Valid] Loss: 0.347
# prev min loss 0.352, now loss 0.347 | save model at epoch: 12
# *************** CYP2C9_Veith ***************
# AUROC: 0.9305 AUPRC: 0.8641 F1: 0.7957
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.859  &  0.845  &          0.790  &     0.801  &0.889  &0.796 &0.930 &   0.689 &   0.864
#
# Epoch:13, [Train] Loss: 0.491
# Epoch:13, [Valid] Loss: 0.349
# EarlyStopping counter: 1 out of 10
# Epoch:14, [Train] Loss: 0.499
# Epoch:14, [Valid] Loss: 0.349
# EarlyStopping counter: 2 out of 10
# Epoch:15, [Train] Loss: 0.494
# Epoch:15, [Valid] Loss: 0.351
# EarlyStopping counter: 3 out of 10
# Epoch:16, [Train] Loss: 0.486
# Epoch:16, [Valid] Loss: 0.346
# prev min loss 0.347, now loss 0.346 | save model at epoch: 16
# *************** CYP2C9_Veith ***************
# AUROC: 0.9301 AUPRC: 0.8642 F1: 0.7986
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.859  &  0.849  &          0.778  &     0.821  &0.878  &0.799 &0.930 &   0.690 &   0.864
#
# Epoch:17, [Train] Loss: 0.483
# Epoch:17, [Valid] Loss: 0.342
# prev min loss 0.346, now loss 0.342 | save model at epoch: 17
# *************** CYP2C9_Veith ***************
# AUROC: 0.9309 AUPRC: 0.8649 F1: 0.7922
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.859  &  0.842  &          0.795  &     0.789  &0.894  &0.792 &0.931 &   0.685 &   0.865
#
# Epoch:18, [Train] Loss: 0.483
# Epoch:18, [Valid] Loss: 0.344
# EarlyStopping counter: 1 out of 10
# Epoch:19, [Train] Loss: 0.495
# Epoch:19, [Valid] Loss: 0.351
# EarlyStopping counter: 2 out of 10
# Epoch:20, [Train] Loss: 0.488
# Epoch:20, [Valid] Loss: 0.344
# EarlyStopping counter: 3 out of 10
# Epoch:21, [Train] Loss: 0.485
# Epoch:21, [Valid] Loss: 0.341
# prev min loss 0.342, now loss 0.341 | save model at epoch: 21
# *************** CYP2C9_Veith ***************
# AUROC: 0.9319 AUPRC: 0.8680 F1: 0.7924
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.856  &  0.844  &          0.781  &     0.804  &0.883  &0.792 &0.932 &   0.682 &   0.868
#
# Epoch:22, [Train] Loss: 0.492
# Epoch:22, [Valid] Loss: 0.344
# EarlyStopping counter: 1 out of 10
# Epoch:23, [Train] Loss: 0.488
# Epoch:23, [Valid] Loss: 0.342
# EarlyStopping counter: 2 out of 10
# Epoch:24, [Train] Loss: 0.485
# Epoch:24, [Valid] Loss: 0.343
# EarlyStopping counter: 3 out of 10
# Epoch:25, [Train] Loss: 0.485
# Epoch:25, [Valid] Loss: 0.343
# EarlyStopping counter: 4 out of 10
# Epoch:26, [Train] Loss: 0.493
# Epoch:26, [Valid] Loss: 0.346
# EarlyStopping counter: 5 out of 10
# Epoch:27, [Train] Loss: 0.489
# Epoch:27, [Valid] Loss: 0.346
# EarlyStopping counter: 6 out of 10
# Epoch:28, [Train] Loss: 0.487
# Epoch:28, [Valid] Loss: 0.344
# EarlyStopping counter: 7 out of 10
# Epoch:29, [Train] Loss: 0.478
# Epoch:29, [Valid] Loss: 0.338
# prev min loss 0.341, now loss 0.338 | save model at epoch: 29
# *************** CYP2C9_Veith ***************
# AUROC: 0.9312 AUPRC: 0.8679 F1: 0.7883
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.856  &  0.839  &          0.792  &     0.785  &0.893  &0.788 &0.931 &   0.679 &   0.868
#
# Epoch:30, [Train] Loss: 0.483
# Epoch:30, [Valid] Loss: 0.343
# EarlyStopping counter: 1 out of 10
# Epoch:31, [Train] Loss: 0.491
# Epoch:31, [Valid] Loss: 0.347
# EarlyStopping counter: 2 out of 10
# Epoch:32, [Train] Loss: 0.489
# Epoch:32, [Valid] Loss: 0.344
# EarlyStopping counter: 3 out of 10
# Epoch:33, [Train] Loss: 0.483
# Epoch:33, [Valid] Loss: 0.341
# EarlyStopping counter: 4 out of 10
# Epoch:34, [Train] Loss: 0.489
# Epoch:34, [Valid] Loss: 0.343
# EarlyStopping counter: 5 out of 10
# Epoch:35, [Train] Loss: 0.479
# Epoch:35, [Valid] Loss: 0.343
# EarlyStopping counter: 6 out of 10
# Epoch:36, [Train] Loss: 0.484
# Epoch:36, [Valid] Loss: 0.340
# EarlyStopping counter: 7 out of 10
# Epoch:37, [Train] Loss: 0.486
# Epoch:37, [Valid] Loss: 0.343
# EarlyStopping counter: 8 out of 10
# Epoch:38, [Train] Loss: 0.475
# Epoch:38, [Valid] Loss: 0.337
# prev min loss 0.338, now loss 0.337 | save model at epoch: 38
# *************** CYP2C9_Veith ***************
# AUROC: 0.9318 AUPRC: 0.8694 F1: 0.7943
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.857  &  0.845  &          0.780  &     0.809  &0.882  &0.794 &0.932 &   0.685 &   0.869
#
# Epoch:39, [Train] Loss: 0.482
# Epoch:39, [Valid] Loss: 0.339
# EarlyStopping counter: 1 out of 10
# Epoch:40, [Train] Loss: 0.480
# Epoch:40, [Valid] Loss: 0.336
# prev min loss 0.337, now loss 0.336 | save model at epoch: 40
# *************** CYP2C9_Veith ***************
# AUROC: 0.9327 AUPRC: 0.8720 F1: 0.8005
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.862  &  0.850  &          0.790  &     0.811  &0.888  &0.800 &0.933 &   0.695 &   0.872
#
# Epoch:41, [Train] Loss: 0.477
# Epoch:41, [Valid] Loss: 0.339
# EarlyStopping counter: 1 out of 10
# Epoch:42, [Train] Loss: 0.483
# Epoch:42, [Valid] Loss: 0.336
# EarlyStopping counter: 2 out of 10
# Epoch:43, [Train] Loss: 0.476
# Epoch:43, [Valid] Loss: 0.334
# prev min loss 0.336, now loss 0.334 | save model at epoch: 43
# *************** CYP2C9_Veith ***************
# AUROC: 0.9317 AUPRC: 0.8699 F1: 0.7900
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.854  &  0.842  &          0.779  &     0.801  &0.882  &0.790 &0.932 &   0.679 &   0.870
#
# Epoch:44, [Train] Loss: 0.485
# Epoch:44, [Valid] Loss: 0.335
# EarlyStopping counter: 1 out of 10
# Epoch:45, [Train] Loss: 0.479
# Epoch:45, [Valid] Loss: 0.338
# EarlyStopping counter: 2 out of 10
# Epoch:46, [Train] Loss: 0.479
# Epoch:46, [Valid] Loss: 0.334
# EarlyStopping counter: 3 out of 10
# Epoch:47, [Train] Loss: 0.482
# Epoch:47, [Valid] Loss: 0.340
# EarlyStopping counter: 4 out of 10
# Epoch:48, [Train] Loss: 0.476
# Epoch:48, [Valid] Loss: 0.334
# EarlyStopping counter: 5 out of 10
# Epoch:49, [Train] Loss: 0.481
# Epoch:49, [Valid] Loss: 0.338
# EarlyStopping counter: 6 out of 10
# Epoch:50, [Train] Loss: 0.484
# Epoch:50, [Valid] Loss: 0.338
# EarlyStopping counter: 7 out of 10
# Epoch:51, [Train] Loss: 0.474
# Epoch:51, [Valid] Loss: 0.338
# EarlyStopping counter: 8 out of 10
# Epoch:52, [Train] Loss: 0.477
# Epoch:52, [Valid] Loss: 0.333
# prev min loss 0.334, now loss 0.333 | save model at epoch: 52
# *************** CYP2C9_Veith ***************
# AUROC: 0.9329 AUPRC: 0.8709 F1: 0.7879
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.855  &  0.839  &          0.789  &     0.787  &0.891  &0.788 &0.933 &   0.678 &   0.871
#
# Epoch:53, [Train] Loss: 0.471
# Epoch:53, [Valid] Loss: 0.333
# EarlyStopping counter: 1 out of 10
# Epoch:54, [Train] Loss: 0.474
# Epoch:54, [Valid] Loss: 0.331
# prev min loss 0.333, now loss 0.331 | save model at epoch: 54
# *************** CYP2C9_Veith ***************
# AUROC: 0.9338 AUPRC: 0.8739 F1: 0.7976
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.860  &  0.847  &          0.789  &     0.806  &0.888  &0.798 &0.934 &   0.691 &   0.874
#
# Epoch:55, [Train] Loss: 0.478
# Epoch:55, [Valid] Loss: 0.334
# EarlyStopping counter: 1 out of 10
# Epoch:56, [Train] Loss: 0.472
# Epoch:56, [Valid] Loss: 0.328
# prev min loss 0.331, now loss 0.328 | save model at epoch: 56
# *************** CYP2C9_Veith ***************
# AUROC: 0.9338 AUPRC: 0.8737 F1: 0.7995
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.863  &  0.848  &          0.798  &     0.801  &0.894  &0.800 &0.934 &   0.695 &   0.874
#
# Epoch:57, [Train] Loss: 0.477
# Epoch:57, [Valid] Loss: 0.332
# EarlyStopping counter: 1 out of 10
# Epoch:58, [Train] Loss: 0.475
# Epoch:58, [Valid] Loss: 0.334
# EarlyStopping counter: 2 out of 10
# Epoch:59, [Train] Loss: 0.469
# Epoch:59, [Valid] Loss: 0.331
# EarlyStopping counter: 3 out of 10
# Epoch:60, [Train] Loss: 0.470
# Epoch:60, [Valid] Loss: 0.331
# EarlyStopping counter: 4 out of 10
# Epoch:61, [Train] Loss: 0.472
# Epoch:61, [Valid] Loss: 0.330
# EarlyStopping counter: 5 out of 10
# Epoch:62, [Train] Loss: 0.465
# Epoch:62, [Valid] Loss: 0.326
# prev min loss 0.328, now loss 0.326 | save model at epoch: 62
# *************** CYP2C9_Veith ***************
# AUROC: 0.9326 AUPRC: 0.8690 F1: 0.7995
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.862  &  0.848  &          0.793  &     0.806  &0.891  &0.800 &0.933 &   0.694 &   0.869
#
# Epoch:63, [Train] Loss: 0.479
# Epoch:63, [Valid] Loss: 0.333
# EarlyStopping counter: 1 out of 10
# Epoch:64, [Train] Loss: 0.472
# Epoch:64, [Valid] Loss: 0.331
# EarlyStopping counter: 2 out of 10
# Epoch:65, [Train] Loss: 0.474
# Epoch:65, [Valid] Loss: 0.335
# EarlyStopping counter: 3 out of 10
# Epoch:66, [Train] Loss: 0.475
# Epoch:66, [Valid] Loss: 0.330
# EarlyStopping counter: 4 out of 10
# Epoch:67, [Train] Loss: 0.463
# Epoch:67, [Valid] Loss: 0.328
# EarlyStopping counter: 5 out of 10
# Epoch:68, [Train] Loss: 0.466
# Epoch:68, [Valid] Loss: 0.330
# EarlyStopping counter: 6 out of 10
# Epoch:69, [Train] Loss: 0.464
# Epoch:69, [Valid] Loss: 0.327
# EarlyStopping counter: 7 out of 10
# Epoch:70, [Train] Loss: 0.471
# Epoch:70, [Valid] Loss: 0.330
# EarlyStopping counter: 8 out of 10
# Epoch:71, [Train] Loss: 0.461
# Epoch:71, [Valid] Loss: 0.323
# prev min loss 0.326, now loss 0.323 | save model at epoch: 71
# *************** CYP2C9_Veith ***************
# AUROC: 0.9332 AUPRC: 0.8712 F1: 0.7937
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.859  &  0.843  &          0.796  &     0.792  &0.894  &0.794 &0.933 &   0.687 &   0.871
#
# Epoch:72, [Train] Loss: 0.459
# Epoch:72, [Valid] Loss: 0.330
# EarlyStopping counter: 1 out of 10
# Epoch:73, [Train] Loss: 0.464
# Epoch:73, [Valid] Loss: 0.325
# EarlyStopping counter: 2 out of 10
# Epoch:74, [Train] Loss: 0.472
# Epoch:74, [Valid] Loss: 0.328
# EarlyStopping counter: 3 out of 10
# Epoch:75, [Train] Loss: 0.460
# Epoch:75, [Valid] Loss: 0.326
# EarlyStopping counter: 4 out of 10
# Epoch:76, [Train] Loss: 0.470
# Epoch:76, [Valid] Loss: 0.329
# EarlyStopping counter: 5 out of 10
# Epoch:77, [Train] Loss: 0.469
# Epoch:77, [Valid] Loss: 0.327
# EarlyStopping counter: 6 out of 10
# Epoch:78, [Train] Loss: 0.468
# Epoch:78, [Valid] Loss: 0.329
# EarlyStopping counter: 7 out of 10
# Epoch:79, [Train] Loss: 0.467
# Epoch:79, [Valid] Loss: 0.326
# EarlyStopping counter: 8 out of 10
# Epoch:80, [Train] Loss: 0.459
# Epoch:80, [Valid] Loss: 0.325
# EarlyStopping counter: 9 out of 10
# Epoch:81, [Train] Loss: 0.466
# Epoch:81, [Valid] Loss: 0.326
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 71, min loss: 0.3231
#
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  ckpt_CYP2C9_Veith.pt
# using BCELOSSwithdigits
# 100%|██████████| 19/19 [00:05<00:00,  3.66it/s]
# total_loss: 0.315
# *************** CYP2C9_Veith ***************
# AUROC: 0.9387 AUPRC: 0.8746 F1: 0.8080
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.873  &  0.852  &          0.828  &     0.789  &0.916  &0.808 &0.939 &   0.714 &   0.875

# %%
# from os import walk
# import os
# files = next(walk('/content/drive/MyDrive/ADMET/'), (None, None, []))[2]
# for file in files:
#     if isinstance(file, str):
#         file_type = file.split('.')[-1]
#         # print(file_type)
#         if file_type == 'bin' or file_type == 'pth':
#             os.remove(file)

# %%
dropout = 0.3
/content/drive/MyDrive/ADMET/


IS_R = False
    config = {'GIN_out_dim': 256,
            'hid_dims': [512],
            'out_dim': len(met_cls),
            'prop_names': met_cls,
            'dropout': 0.3,
            'IS_R': IS_R,
            'lr': 1e-4,
            'wd':1e-5,
            'patience': 10,
            'model_path': f'ckpt_{met_cls[0]}.pt'}

*************** CYP2C19_Veith ***************
AUROC: 0.9281 AUPRC: 0.9143 F1: 0.8508
Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
& 0.859  &  0.860  &          0.828  &     0.875  &0.845  &0.851 &0.928 &   0.718 &   0.914

*************** CYP2D6_Veith ***************
AUROC: 0.9058 AUPRC: 0.7542 F1: 0.6735
Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
& 0.891  &  0.780  &          0.764  &     0.602  &0.957  &0.674 &0.906 &   0.616 &   0.754

*************** CYP3A4_Veith ***************
AUROC: 0.9247 AUPRC: 0.8918 F1: 0.8165
Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
& 0.846  &  0.844  &          0.804  &     0.829  &0.859  &0.816 &0.925 &   0.685 &   0.892

*************** CYP1A2_Veith ***************
AUROC: 0.9510 AUPRC: 0.9477 F1: 0.8756
Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
& 0.883  &  0.882  &          0.877  &     0.874  &0.891  &0.876 &0.951 &   0.765 &   0.948

*************** CYP2C9_Veith ***************
AUROC: 0.9387 AUPRC: 0.8746 F1: 0.8080
Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
& 0.873  &  0.852  &          0.828  &     0.789  &0.916  &0.808 &0.939 &   0.714 &   0.875

# %%
from scripts.preprocess_mols import collect_data
met_cls_all = ['CYP2C19_Veith', 'CYP2D6_Veith', 'CYP3A4_Veith',
            'CYP1A2_Veith', 'CYP2C9_Veith']
IS_R = False # is regression task

for met_cls in met_cls_all:

    met_cls = [met_cls]
    trains, valids, tests = collect_data(met_cls, IS_R=False)
    batch_size = 128
    loader_params ={'batch_size': batch_size, 'shuffle': True}

    train_loader = get_GIN_dataloader(GIN_dataset(trains, met_cls), loader_params)
    valid_loader = get_GIN_dataloader(GIN_dataset(valids, met_cls), loader_params)
    p = {'batch_size': batch_size, 'shuffle': False}
    test_loader = get_GIN_dataloader(GIN_dataset(tests, met_cls), p)

    IS_R = False
    config = {'GIN_out_dim': 256,
            'hid_dims': [512],
            'out_dim': len(met_cls),
            'prop_names': met_cls,
            'dropout': 0.1,
            'IS_R': IS_R,
            'lr': 1e-4,
            'wd':1e-5,
            'patience': 10,
            'model_path': f'GIN_SO_DR_0.1/ckpt_{met_cls[0]}.pt'}

    models = PRED(**config)
    print("*"*40, met_cls, "*"*40)
    print('---> start training...')
    models.train(train_loader, valid_loader, test_loader)
# Out:
# Found local copy...
# Loading...
# Done!
# *************** CYP2C19_Veith ***************
# Cleaning mols: 100%|██████████| 8866/8866 [00:24<00:00, 356.81it/s]
# Cleaning mols: 100%|██████████| 1266/1266 [00:03<00:00, 357.01it/s]
# Cleaning mols: 100%|██████████| 2533/2533 [00:07<00:00, 342.30it/s]
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# **************************************** ['CYP2C19_Veith'] ****************************************
# ---> start training...
# Epoch:0, [Train] Loss: 0.656
# Epoch:0, [Valid] Loss: 0.561
# Epoch:1, [Train] Loss: 0.515
# Epoch:1, [Valid] Loss: 0.396
# Epoch:2, [Train] Loss: 0.468
# Epoch:2, [Valid] Loss: 0.373
# Epoch:3, [Train] Loss: 0.461
# Epoch:3, [Valid] Loss: 0.359
# Epoch:4, [Train] Loss: 0.459
# Epoch:4, [Valid] Loss: 0.359
# EarlyStopping counter: 1 out of 10
# prev min loss 10000.000, now loss 0.359 | save model at epoch: 4
# *************** CYP2C19_Veith ***************
# AUROC: 0.9247 AUPRC: 0.9132 F1: 0.8506
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.856  &  0.857  &          0.829  &     0.874  &0.841  &0.851 &0.925 &   0.713 &   0.913
#
# Epoch:5, [Train] Loss: 0.456
# Epoch:5, [Valid] Loss: 0.354
# prev min loss 0.359, now loss 0.354 | save model at epoch: 5
# *************** CYP2C19_Veith ***************
# AUROC: 0.9259 AUPRC: 0.9141 F1: 0.8515
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.857  &  0.858  &          0.829  &     0.875  &0.841  &0.852 &0.926 &   0.715 &   0.914
#
# Epoch:6, [Train] Loss: 0.455
# Epoch:6, [Valid] Loss: 0.354
# prev min loss 0.354, now loss 0.354 | save model at epoch: 6
# *************** CYP2C19_Veith ***************
# AUROC: 0.9269 AUPRC: 0.9145 F1: 0.8548
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.859  &  0.860  &          0.823  &     0.889  &0.832  &0.855 &0.927 &   0.719 &   0.915
#
# Epoch:7, [Train] Loss: 0.450
# Epoch:7, [Valid] Loss: 0.350
# prev min loss 0.354, now loss 0.350 | save model at epoch: 7
# *************** CYP2C19_Veith ***************
# AUROC: 0.9279 AUPRC: 0.9162 F1: 0.8533
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.863  &  0.862  &          0.853  &     0.853  &0.871  &0.853 &0.928 &   0.724 &   0.916
#
# Epoch:8, [Train] Loss: 0.446
# Epoch:8, [Valid] Loss: 0.349
# prev min loss 0.350, now loss 0.349 | save model at epoch: 8
# *************** CYP2C19_Veith ***************
# AUROC: 0.9273 AUPRC: 0.9153 F1: 0.8548
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.862  &  0.862  &          0.842  &     0.868  &0.856  &0.855 &0.927 &   0.723 &   0.915
#
# Epoch:9, [Train] Loss: 0.443
# Epoch:9, [Valid] Loss: 0.348
# prev min loss 0.349, now loss 0.348 | save model at epoch: 9
# *************** CYP2C19_Veith ***************
# AUROC: 0.9275 AUPRC: 0.9151 F1: 0.8569
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.863  &  0.864  &          0.836  &     0.879  &0.848  &0.857 &0.927 &   0.726 &   0.915
#
# Epoch:10, [Train] Loss: 0.441
# Epoch:10, [Valid] Loss: 0.349
# EarlyStopping counter: 1 out of 10
# Epoch:11, [Train] Loss: 0.443
# Epoch:11, [Valid] Loss: 0.347
# prev min loss 0.348, now loss 0.347 | save model at epoch: 11
# *************** CYP2C19_Veith ***************
# AUROC: 0.9281 AUPRC: 0.9152 F1: 0.8534
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.860  &  0.861  &          0.839  &     0.868  &0.853  &0.853 &0.928 &   0.720 &   0.915
#
# Epoch:12, [Train] Loss: 0.445
# Epoch:12, [Valid] Loss: 0.348
# EarlyStopping counter: 1 out of 10
# Epoch:13, [Train] Loss: 0.436
# Epoch:13, [Valid] Loss: 0.348
# EarlyStopping counter: 2 out of 10
# Epoch:14, [Train] Loss: 0.444
# Epoch:14, [Valid] Loss: 0.348
# EarlyStopping counter: 3 out of 10
# Epoch:15, [Train] Loss: 0.441
# Epoch:15, [Valid] Loss: 0.348
# EarlyStopping counter: 4 out of 10
# Epoch:16, [Train] Loss: 0.441
# Epoch:16, [Valid] Loss: 0.350
# EarlyStopping counter: 5 out of 10
# Epoch:17, [Train] Loss: 0.443
# Epoch:17, [Valid] Loss: 0.347
# EarlyStopping counter: 6 out of 10
# Epoch:18, [Train] Loss: 0.443
# Epoch:18, [Valid] Loss: 0.352
# EarlyStopping counter: 7 out of 10
# Epoch:19, [Train] Loss: 0.440
# Epoch:19, [Valid] Loss: 0.348
# EarlyStopping counter: 8 out of 10
# Epoch:20, [Train] Loss: 0.437
# Epoch:20, [Valid] Loss: 0.346
# prev min loss 0.347, now loss 0.346 | save model at epoch: 20
# *************** CYP2C19_Veith ***************
# AUROC: 0.9274 AUPRC: 0.9140 F1: 0.8560
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.862  &  0.863  &          0.836  &     0.877  &0.848  &0.856 &0.927 &   0.724 &   0.914
#
# Epoch:21, [Train] Loss: 0.437
# Epoch:21, [Valid] Loss: 0.347
# EarlyStopping counter: 1 out of 10
# Epoch:22, [Train] Loss: 0.438
# Epoch:22, [Valid] Loss: 0.349
# EarlyStopping counter: 2 out of 10
# Epoch:23, [Train] Loss: 0.435
# Epoch:23, [Valid] Loss: 0.352
# EarlyStopping counter: 3 out of 10
# Epoch:24, [Train] Loss: 0.441
# Epoch:24, [Valid] Loss: 0.349
# EarlyStopping counter: 4 out of 10
# Epoch:25, [Train] Loss: 0.437
# Epoch:25, [Valid] Loss: 0.352
# EarlyStopping counter: 5 out of 10
# Epoch:26, [Train] Loss: 0.431
# Epoch:26, [Valid] Loss: 0.349
# EarlyStopping counter: 6 out of 10
# Epoch:27, [Train] Loss: 0.434
# Epoch:27, [Valid] Loss: 0.349
# EarlyStopping counter: 7 out of 10
# Epoch:28, [Train] Loss: 0.435
# Epoch:28, [Valid] Loss: 0.348
# EarlyStopping counter: 8 out of 10
# Epoch:29, [Train] Loss: 0.437
# Epoch:29, [Valid] Loss: 0.350
# EarlyStopping counter: 9 out of 10
# Epoch:30, [Train] Loss: 0.429
# Epoch:30, [Valid] Loss: 0.349
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 20, min loss: 0.3464
#
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  GIN_SO_DR_0.1/ckpt_CYP2C19_Veith.pt
# using BCELOSSwithdigits
# 100%|██████████| 20/20 [00:05<00:00,  3.65it/s]
# Found local copy...
# Loading...
# Done!
# total_loss: 0.340
# *************** CYP2C19_Veith ***************
# AUROC: 0.9299 AUPRC: 0.9149 F1: 0.8537
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.861  &  0.863  &          0.826  &     0.883  &0.842  &0.854 &0.930 &   0.723 &   0.915
#
# *************** CYP2D6_Veith ***************
# Cleaning mols: 100%|██████████| 9191/9191 [00:25<00:00, 359.11it/s]
# Cleaning mols: 100%|██████████| 1313/1313 [00:03<00:00, 353.50it/s]
# Cleaning mols: 100%|██████████| 2626/2626 [00:07<00:00, 363.75it/s]
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# **************************************** ['CYP2D6_Veith'] ****************************************
# ---> start training...
# Epoch:0, [Train] Loss: 0.594
# Epoch:0, [Valid] Loss: 0.445
# Epoch:1, [Train] Loss: 0.442
# Epoch:1, [Valid] Loss: 0.367
# Epoch:2, [Train] Loss: 0.402
# Epoch:2, [Valid] Loss: 0.330
# Epoch:3, [Train] Loss: 0.388
# Epoch:3, [Valid] Loss: 0.310
# Epoch:4, [Train] Loss: 0.376
# Epoch:4, [Valid] Loss: 0.300
# prev min loss 10000.000, now loss 0.300 | save model at epoch: 4
# *************** CYP2D6_Veith ***************
# AUROC: 0.9035 AUPRC: 0.7688 F1: 0.6625
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.877  &  0.776  &          0.728  &     0.608  &0.944  &0.662 &0.903 &   0.592 &   0.769
#
# Epoch:5, [Train] Loss: 0.382
# Epoch:5, [Valid] Loss: 0.296
# prev min loss 0.300, now loss 0.296 | save model at epoch: 5
# *************** CYP2D6_Veith ***************
# AUROC: 0.9062 AUPRC: 0.7736 F1: 0.6722
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.880  &  0.783  &          0.730  &     0.623  &0.943  &0.672 &0.906 &   0.602 &   0.774
#
# Epoch:6, [Train] Loss: 0.370
# Epoch:6, [Valid] Loss: 0.295
# prev min loss 0.296, now loss 0.295 | save model at epoch: 6
# *************** CYP2D6_Veith ***************
# AUROC: 0.9084 AUPRC: 0.7778 F1: 0.6747
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.877  &  0.790  &          0.706  &     0.646  &0.934  &0.675 &0.908 &   0.600 &   0.778
#
# Epoch:7, [Train] Loss: 0.376
# Epoch:7, [Valid] Loss: 0.289
# prev min loss 0.295, now loss 0.289 | save model at epoch: 7
# *************** CYP2D6_Veith ***************
# AUROC: 0.9094 AUPRC: 0.7799 F1: 0.6848
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.885  &  0.789  &          0.749  &     0.631  &0.948  &0.685 &0.909 &   0.618 &   0.780
#
# Epoch:8, [Train] Loss: 0.369
# Epoch:8, [Valid] Loss: 0.284
# prev min loss 0.289, now loss 0.284 | save model at epoch: 8
# *************** CYP2D6_Veith ***************
# AUROC: 0.9108 AUPRC: 0.7830 F1: 0.6807
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.884  &  0.786  &          0.750  &     0.623  &0.949  &0.681 &0.911 &   0.615 &   0.783
#
# Epoch:9, [Train] Loss: 0.369
# Epoch:9, [Valid] Loss: 0.287
# EarlyStopping counter: 1 out of 10
# Epoch:10, [Train] Loss: 0.367
# Epoch:10, [Valid] Loss: 0.284
# prev min loss 0.284, now loss 0.284 | save model at epoch: 10
# *************** CYP2D6_Veith ***************
# AUROC: 0.9124 AUPRC: 0.7839 F1: 0.6901
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.886  &  0.794  &          0.746  &     0.642  &0.946  &0.690 &0.912 &   0.623 &   0.784
#
# Epoch:11, [Train] Loss: 0.373
# Epoch:11, [Valid] Loss: 0.286
# EarlyStopping counter: 1 out of 10
# Epoch:12, [Train] Loss: 0.365
# Epoch:12, [Valid] Loss: 0.282
# prev min loss 0.284, now loss 0.282 | save model at epoch: 12
# *************** CYP2D6_Veith ***************
# AUROC: 0.9124 AUPRC: 0.7836 F1: 0.7012
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.890  &  0.800  &          0.761  &     0.650  &0.950  &0.701 &0.912 &   0.638 &   0.784
#
# Epoch:13, [Train] Loss: 0.362
# Epoch:13, [Valid] Loss: 0.284
# EarlyStopping counter: 1 out of 10
# Epoch:14, [Train] Loss: 0.361
# Epoch:14, [Valid] Loss: 0.283
# EarlyStopping counter: 2 out of 10
# Epoch:15, [Train] Loss: 0.369
# Epoch:15, [Valid] Loss: 0.286
# EarlyStopping counter: 3 out of 10
# Epoch:16, [Train] Loss: 0.361
# Epoch:16, [Valid] Loss: 0.284
# EarlyStopping counter: 4 out of 10
# Epoch:17, [Train] Loss: 0.366
# Epoch:17, [Valid] Loss: 0.285
# EarlyStopping counter: 5 out of 10
# Epoch:18, [Train] Loss: 0.359
# Epoch:18, [Valid] Loss: 0.282
# EarlyStopping counter: 6 out of 10
# Epoch:19, [Train] Loss: 0.364
# Epoch:19, [Valid] Loss: 0.279
# prev min loss 0.282, now loss 0.279 | save model at epoch: 19
# *************** CYP2D6_Veith ***************
# AUROC: 0.9129 AUPRC: 0.7822 F1: 0.7054
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.892  &  0.802  &          0.766  &     0.654  &0.951  &0.705 &0.913 &   0.643 &   0.782
#
# Epoch:20, [Train] Loss: 0.361
# Epoch:20, [Valid] Loss: 0.284
# EarlyStopping counter: 1 out of 10
# Epoch:21, [Train] Loss: 0.362
# Epoch:21, [Valid] Loss: 0.280
# EarlyStopping counter: 2 out of 10
# Epoch:22, [Train] Loss: 0.356
# Epoch:22, [Valid] Loss: 0.282
# EarlyStopping counter: 3 out of 10
# Epoch:23, [Train] Loss: 0.364
# Epoch:23, [Valid] Loss: 0.286
# EarlyStopping counter: 4 out of 10
# Epoch:24, [Train] Loss: 0.357
# Epoch:24, [Valid] Loss: 0.288
# EarlyStopping counter: 5 out of 10
# Epoch:25, [Train] Loss: 0.359
# Epoch:25, [Valid] Loss: 0.285
# EarlyStopping counter: 6 out of 10
# Epoch:26, [Train] Loss: 0.357
# Epoch:26, [Valid] Loss: 0.289
# EarlyStopping counter: 7 out of 10
# Epoch:27, [Train] Loss: 0.355
# Epoch:27, [Valid] Loss: 0.282
# EarlyStopping counter: 8 out of 10
# Epoch:28, [Train] Loss: 0.350
# Epoch:28, [Valid] Loss: 0.281
# EarlyStopping counter: 9 out of 10
# Epoch:29, [Train] Loss: 0.357
# Epoch:29, [Valid] Loss: 0.283
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 19, min loss: 0.2789
#
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  GIN_SO_DR_0.1/ckpt_CYP2D6_Veith.pt
# using BCELOSSwithdigits
# 100%|██████████| 21/21 [00:05<00:00,  3.80it/s]
# Found local copy...
# Loading...
# Done!
# total_loss: 0.279
# *************** CYP2D6_Veith ***************
# AUROC: 0.9051 AUPRC: 0.7556 F1: 0.6757
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.890  &  0.784  &          0.750  &     0.615  &0.953  &0.676 &0.905 &   0.615 &   0.756
#
# *************** CYP3A4_Veith ***************
# Cleaning mols: 100%|██████████| 8629/8629 [00:24<00:00, 358.89it/s]
# Cleaning mols: 100%|██████████| 1233/1233 [00:03<00:00, 360.55it/s]
# Cleaning mols: 100%|██████████| 2466/2466 [00:06<00:00, 364.87it/s]
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# **************************************** ['CYP3A4_Veith'] ****************************************
# ---> start training...
# Epoch:0, [Train] Loss: 0.660
# Epoch:0, [Valid] Loss: 0.579
# Epoch:1, [Train] Loss: 0.555
# Epoch:1, [Valid] Loss: 0.429
# Epoch:2, [Train] Loss: 0.494
# Epoch:2, [Valid] Loss: 0.381
# Epoch:3, [Train] Loss: 0.483
# Epoch:3, [Valid] Loss: 0.368
# Epoch:4, [Train] Loss: 0.477
# Epoch:4, [Valid] Loss: 0.361
# prev min loss 10000.000, now loss 0.361 | save model at epoch: 4
# *************** CYP3A4_Veith ***************
# AUROC: 0.9239 AUPRC: 0.9020 F1: 0.8197
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.846  &  0.845  &          0.803  &     0.837  &0.852  &0.820 &0.924 &   0.686 &   0.902
#
# Epoch:5, [Train] Loss: 0.472
# Epoch:5, [Valid] Loss: 0.364
# EarlyStopping counter: 1 out of 10
# Epoch:6, [Train] Loss: 0.467
# Epoch:6, [Valid] Loss: 0.362
# EarlyStopping counter: 2 out of 10
# Epoch:7, [Train] Loss: 0.472
# Epoch:7, [Valid] Loss: 0.360
# prev min loss 0.361, now loss 0.360 | save model at epoch: 7
# *************** CYP3A4_Veith ***************
# AUROC: 0.9245 AUPRC: 0.9025 F1: 0.8141
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.838  &  0.839  &          0.782  &     0.849  &0.830  &0.814 &0.924 &   0.672 &   0.903
#
# Epoch:8, [Train] Loss: 0.465
# Epoch:8, [Valid] Loss: 0.356
# prev min loss 0.360, now loss 0.356 | save model at epoch: 8
# *************** CYP3A4_Veith ***************
# AUROC: 0.9258 AUPRC: 0.9054 F1: 0.8126
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.835  &  0.838  &          0.776  &     0.853  &0.823  &0.813 &0.926 &   0.669 &   0.905
#
# Epoch:9, [Train] Loss: 0.455
# Epoch:9, [Valid] Loss: 0.356
# prev min loss 0.356, now loss 0.356 | save model at epoch: 9
# *************** CYP3A4_Veith ***************
# AUROC: 0.9258 AUPRC: 0.9050 F1: 0.8095
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.831  &  0.835  &          0.767  &     0.857  &0.813  &0.810 &0.926 &   0.662 &   0.905
#
# Epoch:10, [Train] Loss: 0.462
# Epoch:10, [Valid] Loss: 0.366
# EarlyStopping counter: 1 out of 10
# Epoch:11, [Train] Loss: 0.464
# Epoch:11, [Valid] Loss: 0.355
# prev min loss 0.356, now loss 0.355 | save model at epoch: 11
# *************** CYP3A4_Veith ***************
# AUROC: 0.9263 AUPRC: 0.9059 F1: 0.8143
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.836  &  0.839  &          0.774  &     0.859  &0.820  &0.814 &0.926 &   0.671 &   0.906
#
# Epoch:12, [Train] Loss: 0.465
# Epoch:12, [Valid] Loss: 0.360
# EarlyStopping counter: 1 out of 10
# Epoch:13, [Train] Loss: 0.458
# Epoch:13, [Valid] Loss: 0.355
# prev min loss 0.355, now loss 0.355 | save model at epoch: 13
# *************** CYP3A4_Veith ***************
# AUROC: 0.9262 AUPRC: 0.9061 F1: 0.8167
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.839  &  0.842  &          0.782  &     0.855  &0.828  &0.817 &0.926 &   0.676 &   0.906
#
# Epoch:14, [Train] Loss: 0.457
# Epoch:14, [Valid] Loss: 0.353
# prev min loss 0.355, now loss 0.353 | save model at epoch: 14
# *************** CYP3A4_Veith ***************
# AUROC: 0.9253 AUPRC: 0.9045 F1: 0.8109
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.836  &  0.837  &          0.784  &     0.839  &0.834  &0.811 &0.925 &   0.668 &   0.905
#
# Epoch:15, [Train] Loss: 0.455
# Epoch:15, [Valid] Loss: 0.350
# prev min loss 0.353, now loss 0.350 | save model at epoch: 15
# *************** CYP3A4_Veith ***************
# AUROC: 0.9264 AUPRC: 0.9067 F1: 0.8161
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.841  &  0.841  &          0.791  &     0.843  &0.840  &0.816 &0.926 &   0.677 &   0.907
#
# Epoch:16, [Train] Loss: 0.459
# Epoch:16, [Valid] Loss: 0.352
# EarlyStopping counter: 1 out of 10
# Epoch:17, [Train] Loss: 0.452
# Epoch:17, [Valid] Loss: 0.356
# EarlyStopping counter: 2 out of 10
# Epoch:18, [Train] Loss: 0.457
# Epoch:18, [Valid] Loss: 0.355
# EarlyStopping counter: 3 out of 10
# Epoch:19, [Train] Loss: 0.454
# Epoch:19, [Valid] Loss: 0.353
# EarlyStopping counter: 4 out of 10
# Epoch:20, [Train] Loss: 0.455
# Epoch:20, [Valid] Loss: 0.352
# EarlyStopping counter: 5 out of 10
# Epoch:21, [Train] Loss: 0.458
# Epoch:21, [Valid] Loss: 0.352
# EarlyStopping counter: 6 out of 10
# Epoch:22, [Train] Loss: 0.448
# Epoch:22, [Valid] Loss: 0.349
# prev min loss 0.350, now loss 0.349 | save model at epoch: 22
# *************** CYP3A4_Veith ***************
# AUROC: 0.9256 AUPRC: 0.9056 F1: 0.8123
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.837  &  0.838  &          0.784  &     0.843  &0.833  &0.812 &0.926 &   0.670 &   0.906
#
# Epoch:23, [Train] Loss: 0.457
# Epoch:23, [Valid] Loss: 0.350
# EarlyStopping counter: 1 out of 10
# Epoch:24, [Train] Loss: 0.455
# Epoch:24, [Valid] Loss: 0.348
# prev min loss 0.349, now loss 0.348 | save model at epoch: 24
# *************** CYP3A4_Veith ***************
# AUROC: 0.9266 AUPRC: 0.9079 F1: 0.8209
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.847  &  0.846  &          0.803  &     0.839  &0.852  &0.821 &0.927 &   0.688 &   0.908
#
# Epoch:25, [Train] Loss: 0.449
# Epoch:25, [Valid] Loss: 0.350
# EarlyStopping counter: 1 out of 10
# Epoch:26, [Train] Loss: 0.461
# Epoch:26, [Valid] Loss: 0.351
# EarlyStopping counter: 2 out of 10
# Epoch:27, [Train] Loss: 0.451
# Epoch:27, [Valid] Loss: 0.347
# prev min loss 0.348, now loss 0.347 | save model at epoch: 27
# *************** CYP3A4_Veith ***************
# AUROC: 0.9276 AUPRC: 0.9098 F1: 0.8156
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.839  &  0.841  &          0.785  &     0.849  &0.833  &0.816 &0.928 &   0.675 &   0.910
#
# Epoch:28, [Train] Loss: 0.448
# Epoch:28, [Valid] Loss: 0.344
# prev min loss 0.347, now loss 0.344 | save model at epoch: 28
# *************** CYP3A4_Veith ***************
# AUROC: 0.9279 AUPRC: 0.9101 F1: 0.8148
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.842  &  0.840  &          0.799  &     0.831  &0.849  &0.815 &0.928 &   0.677 &   0.910
#
# Epoch:29, [Train] Loss: 0.447
# Epoch:29, [Valid] Loss: 0.346
# EarlyStopping counter: 1 out of 10
# Epoch:30, [Train] Loss: 0.446
# Epoch:30, [Valid] Loss: 0.351
# EarlyStopping counter: 2 out of 10
# Epoch:31, [Train] Loss: 0.451
# Epoch:31, [Valid] Loss: 0.347
# EarlyStopping counter: 3 out of 10
# Epoch:32, [Train] Loss: 0.445
# Epoch:32, [Valid] Loss: 0.348
# EarlyStopping counter: 4 out of 10
# Epoch:33, [Train] Loss: 0.445
# Epoch:33, [Valid] Loss: 0.350
# EarlyStopping counter: 5 out of 10
# Epoch:34, [Train] Loss: 0.453
# Epoch:34, [Valid] Loss: 0.351
# EarlyStopping counter: 6 out of 10
# Epoch:35, [Train] Loss: 0.443
# Epoch:35, [Valid] Loss: 0.347
# EarlyStopping counter: 7 out of 10
# Epoch:36, [Train] Loss: 0.443
# Epoch:36, [Valid] Loss: 0.345
# EarlyStopping counter: 8 out of 10
# Epoch:37, [Train] Loss: 0.439
# Epoch:37, [Valid] Loss: 0.344
# prev min loss 0.344, now loss 0.344 | save model at epoch: 37
# *************** CYP3A4_Veith ***************
# AUROC: 0.9299 AUPRC: 0.9131 F1: 0.8285
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.850  &  0.852  &          0.794  &     0.866  &0.838  &0.829 &0.930 &   0.698 &   0.913
#
# Epoch:38, [Train] Loss: 0.448
# Epoch:38, [Valid] Loss: 0.346
# EarlyStopping counter: 1 out of 10
# Epoch:39, [Train] Loss: 0.436
# Epoch:39, [Valid] Loss: 0.339
# prev min loss 0.344, now loss 0.339 | save model at epoch: 39
# *************** CYP3A4_Veith ***************
# AUROC: 0.9305 AUPRC: 0.9136 F1: 0.8272
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.852  &  0.851  &          0.807  &     0.849  &0.854  &0.827 &0.931 &   0.698 &   0.914
#
# Epoch:40, [Train] Loss: 0.439
# Epoch:40, [Valid] Loss: 0.341
# EarlyStopping counter: 1 out of 10
# Epoch:41, [Train] Loss: 0.441
# Epoch:41, [Valid] Loss: 0.343
# EarlyStopping counter: 2 out of 10
# Epoch:42, [Train] Loss: 0.439
# Epoch:42, [Valid] Loss: 0.342
# EarlyStopping counter: 3 out of 10
# Epoch:43, [Train] Loss: 0.436
# Epoch:43, [Valid] Loss: 0.337
# prev min loss 0.339, now loss 0.337 | save model at epoch: 43
# *************** CYP3A4_Veith ***************
# AUROC: 0.9309 AUPRC: 0.9143 F1: 0.8196
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.845  &  0.845  &          0.799  &     0.841  &0.848  &0.820 &0.931 &   0.685 &   0.914
#
# Epoch:44, [Train] Loss: 0.440
# Epoch:44, [Valid] Loss: 0.337
# prev min loss 0.337, now loss 0.337 | save model at epoch: 44
# *************** CYP3A4_Veith ***************
# AUROC: 0.9314 AUPRC: 0.9147 F1: 0.8193
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.845  &  0.844  &          0.800  &     0.839  &0.849  &0.819 &0.931 &   0.684 &   0.915
#
# Epoch:45, [Train] Loss: 0.427
# Epoch:45, [Valid] Loss: 0.337
# EarlyStopping counter: 1 out of 10
# Epoch:46, [Train] Loss: 0.441
# Epoch:46, [Valid] Loss: 0.338
# EarlyStopping counter: 2 out of 10
# Epoch:47, [Train] Loss: 0.433
# Epoch:47, [Valid] Loss: 0.340
# EarlyStopping counter: 3 out of 10
# Epoch:48, [Train] Loss: 0.434
# Epoch:48, [Valid] Loss: 0.338
# EarlyStopping counter: 4 out of 10
# Epoch:49, [Train] Loss: 0.430
# Epoch:49, [Valid] Loss: 0.333
# prev min loss 0.337, now loss 0.333 | save model at epoch: 49
# *************** CYP3A4_Veith ***************
# AUROC: 0.9328 AUPRC: 0.9169 F1: 0.8225
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.849  &  0.847  &          0.810  &     0.835  &0.859  &0.823 &0.933 &   0.692 &   0.917
#
# Epoch:50, [Train] Loss: 0.433
# Epoch:50, [Valid] Loss: 0.333
# EarlyStopping counter: 1 out of 10
# Epoch:51, [Train] Loss: 0.432
# Epoch:51, [Valid] Loss: 0.332
# prev min loss 0.333, now loss 0.332 | save model at epoch: 51
# *************** CYP3A4_Veith ***************
# AUROC: 0.9327 AUPRC: 0.9169 F1: 0.8211
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.848  &  0.846  &          0.811  &     0.831  &0.861  &0.821 &0.933 &   0.690 &   0.917
#
# Epoch:52, [Train] Loss: 0.433
# Epoch:52, [Valid] Loss: 0.332
# EarlyStopping counter: 1 out of 10
# Epoch:53, [Train] Loss: 0.434
# Epoch:53, [Valid] Loss: 0.337
# EarlyStopping counter: 2 out of 10
# Epoch:54, [Train] Loss: 0.433
# Epoch:54, [Valid] Loss: 0.336
# EarlyStopping counter: 3 out of 10
# Epoch:55, [Train] Loss: 0.431
# Epoch:55, [Valid] Loss: 0.334
# EarlyStopping counter: 4 out of 10
# Epoch:56, [Train] Loss: 0.427
# Epoch:56, [Valid] Loss: 0.337
# EarlyStopping counter: 5 out of 10
# Epoch:57, [Train] Loss: 0.430
# Epoch:57, [Valid] Loss: 0.333
# EarlyStopping counter: 6 out of 10
# Epoch:58, [Train] Loss: 0.426
# Epoch:58, [Valid] Loss: 0.332
# EarlyStopping counter: 7 out of 10
# Epoch:59, [Train] Loss: 0.428
# Epoch:59, [Valid] Loss: 0.333
# EarlyStopping counter: 8 out of 10
# Epoch:60, [Train] Loss: 0.425
# Epoch:60, [Valid] Loss: 0.333
# EarlyStopping counter: 9 out of 10
# Epoch:61, [Train] Loss: 0.433
# Epoch:61, [Valid] Loss: 0.336
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 51, min loss: 0.3318
#
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  GIN_SO_DR_0.1/ckpt_CYP3A4_Veith.pt
# using BCELOSSwithdigits
# 100%|██████████| 20/20 [00:05<00:00,  3.72it/s]
# Found local copy...
# Loading...
# Done!
# total_loss: 0.354
# *************** CYP3A4_Veith ***************
# AUROC: 0.9232 AUPRC: 0.8895 F1: 0.8216
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.851  &  0.848  &          0.812  &     0.831  &0.865  &0.822 &0.923 &   0.694 &   0.890
#
# *************** CYP1A2_Veith ***************
# Cleaning mols: 100%|██████████| 8805/8805 [00:24<00:00, 360.18it/s]
# Cleaning mols: 100%|██████████| 1258/1258 [00:03<00:00, 365.17it/s]
# Cleaning mols: 100%|██████████| 2516/2516 [00:06<00:00, 359.52it/s]
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# **************************************** ['CYP1A2_Veith'] ****************************************
# ---> start training...
# Epoch:0, [Train] Loss: 0.659
# Epoch:0, [Valid] Loss: 0.565
# Epoch:1, [Train] Loss: 0.500
# Epoch:1, [Valid] Loss: 0.355
# Epoch:2, [Train] Loss: 0.432
# Epoch:2, [Valid] Loss: 0.326
# Epoch:3, [Train] Loss: 0.421
# Epoch:3, [Valid] Loss: 0.313
# Epoch:4, [Train] Loss: 0.420
# Epoch:4, [Valid] Loss: 0.305
# prev min loss 10000.000, now loss 0.305 | save model at epoch: 4
# *************** CYP1A2_Veith ***************
# AUROC: 0.9463 AUPRC: 0.9419 F1: 0.8661
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.878  &  0.876  &          0.875  &     0.857  &0.895  &0.866 &0.946 &   0.754 &   0.942
#
# Epoch:5, [Train] Loss: 0.414
# Epoch:5, [Valid] Loss: 0.301
# prev min loss 0.305, now loss 0.301 | save model at epoch: 5
# *************** CYP1A2_Veith ***************
# AUROC: 0.9476 AUPRC: 0.9432 F1: 0.8728
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.882  &  0.881  &          0.866  &     0.880  &0.883  &0.873 &0.948 &   0.762 &   0.943
#
# Epoch:6, [Train] Loss: 0.416
# Epoch:6, [Valid] Loss: 0.300
# prev min loss 0.301, now loss 0.300 | save model at epoch: 6
# *************** CYP1A2_Veith ***************
# AUROC: 0.9484 AUPRC: 0.9444 F1: 0.8713
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.880  &  0.880  &          0.863  &     0.880  &0.880  &0.871 &0.948 &   0.759 &   0.944
#
# Epoch:7, [Train] Loss: 0.411
# Epoch:7, [Valid] Loss: 0.298
# prev min loss 0.300, now loss 0.298 | save model at epoch: 7
# *************** CYP1A2_Veith ***************
# AUROC: 0.9487 AUPRC: 0.9447 F1: 0.8736
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.882  &  0.882  &          0.861  &     0.886  &0.877  &0.874 &0.949 &   0.763 &   0.945
#
# Epoch:8, [Train] Loss: 0.413
# Epoch:8, [Valid] Loss: 0.295
# prev min loss 0.298, now loss 0.295 | save model at epoch: 8
# *************** CYP1A2_Veith ***************
# AUROC: 0.9495 AUPRC: 0.9454 F1: 0.8729
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.882  &  0.882  &          0.871  &     0.874  &0.889  &0.873 &0.950 &   0.763 &   0.945
#
# Epoch:9, [Train] Loss: 0.404
# Epoch:9, [Valid] Loss: 0.292
# prev min loss 0.295, now loss 0.292 | save model at epoch: 9
# *************** CYP1A2_Veith ***************
# AUROC: 0.9496 AUPRC: 0.9453 F1: 0.8733
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.884  &  0.883  &          0.881  &     0.866  &0.900  &0.873 &0.950 &   0.766 &   0.945
#
# Epoch:10, [Train] Loss: 0.403
# Epoch:10, [Valid] Loss: 0.291
# prev min loss 0.292, now loss 0.291 | save model at epoch: 10
# *************** CYP1A2_Veith ***************
# AUROC: 0.9500 AUPRC: 0.9453 F1: 0.8736
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.885  &  0.883  &          0.885  &     0.862  &0.904  &0.874 &0.950 &   0.768 &   0.945
#
# Epoch:11, [Train] Loss: 0.408
# Epoch:11, [Valid] Loss: 0.291
# EarlyStopping counter: 1 out of 10
# Epoch:12, [Train] Loss: 0.409
# Epoch:12, [Valid] Loss: 0.290
# prev min loss 0.291, now loss 0.290 | save model at epoch: 12
# *************** CYP1A2_Veith ***************
# AUROC: 0.9510 AUPRC: 0.9474 F1: 0.8770
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.886  &  0.886  &          0.876  &     0.878  &0.894  &0.877 &0.951 &   0.771 &   0.947
#
# Epoch:13, [Train] Loss: 0.400
# Epoch:13, [Valid] Loss: 0.289
# prev min loss 0.290, now loss 0.289 | save model at epoch: 13
# *************** CYP1A2_Veith ***************
# AUROC: 0.9501 AUPRC: 0.9464 F1: 0.8715
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.882  &  0.881  &          0.879  &     0.864  &0.898  &0.872 &0.950 &   0.763 &   0.946
#
# Epoch:14, [Train] Loss: 0.403
# Epoch:14, [Valid] Loss: 0.288
# prev min loss 0.289, now loss 0.288 | save model at epoch: 14
# *************** CYP1A2_Veith ***************
# AUROC: 0.9511 AUPRC: 0.9474 F1: 0.8753
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.885  &  0.884  &          0.875  &     0.876  &0.892  &0.875 &0.951 &   0.768 &   0.947
#
# Epoch:15, [Train] Loss: 0.408
# Epoch:15, [Valid] Loss: 0.289
# EarlyStopping counter: 1 out of 10
# Epoch:16, [Train] Loss: 0.400
# Epoch:16, [Valid] Loss: 0.291
# EarlyStopping counter: 2 out of 10
# Epoch:17, [Train] Loss: 0.402
# Epoch:17, [Valid] Loss: 0.289
# EarlyStopping counter: 3 out of 10
# Epoch:18, [Train] Loss: 0.406
# Epoch:18, [Valid] Loss: 0.290
# EarlyStopping counter: 4 out of 10
# Epoch:19, [Train] Loss: 0.398
# Epoch:19, [Valid] Loss: 0.287
# prev min loss 0.288, now loss 0.287 | save model at epoch: 19
# *************** CYP1A2_Veith ***************
# AUROC: 0.9519 AUPRC: 0.9476 F1: 0.8755
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.886  &  0.885  &          0.886  &     0.866  &0.904  &0.876 &0.952 &   0.771 &   0.948
#
# Epoch:20, [Train] Loss: 0.399
# Epoch:20, [Valid] Loss: 0.287
# prev min loss 0.287, now loss 0.287 | save model at epoch: 20
# *************** CYP1A2_Veith ***************
# AUROC: 0.9509 AUPRC: 0.9464 F1: 0.8759
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.886  &  0.885  &          0.877  &     0.874  &0.895  &0.876 &0.951 &   0.770 &   0.946
#
# Epoch:21, [Train] Loss: 0.399
# Epoch:21, [Valid] Loss: 0.288
# EarlyStopping counter: 1 out of 10
# Epoch:22, [Train] Loss: 0.398
# Epoch:22, [Valid] Loss: 0.289
# EarlyStopping counter: 2 out of 10
# Epoch:23, [Train] Loss: 0.398
# Epoch:23, [Valid] Loss: 0.287
# prev min loss 0.287, now loss 0.287 | save model at epoch: 23
# *************** CYP1A2_Veith ***************
# AUROC: 0.9515 AUPRC: 0.9469 F1: 0.8777
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.886  &  0.886  &          0.872  &     0.883  &0.889  &0.878 &0.951 &   0.772 &   0.947
#
# Epoch:24, [Train] Loss: 0.398
# Epoch:24, [Valid] Loss: 0.288
# EarlyStopping counter: 1 out of 10
# Epoch:25, [Train] Loss: 0.392
# Epoch:25, [Valid] Loss: 0.286
# prev min loss 0.287, now loss 0.286 | save model at epoch: 25
# *************** CYP1A2_Veith ***************
# AUROC: 0.9515 AUPRC: 0.9466 F1: 0.8782
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.887  &  0.887  &          0.875  &     0.881  &0.892  &0.878 &0.951 &   0.773 &   0.947
#
# Epoch:26, [Train] Loss: 0.389
# Epoch:26, [Valid] Loss: 0.286
# EarlyStopping counter: 1 out of 10
# Epoch:27, [Train] Loss: 0.395
# Epoch:27, [Valid] Loss: 0.287
# EarlyStopping counter: 2 out of 10
# Epoch:28, [Train] Loss: 0.393
# Epoch:28, [Valid] Loss: 0.287
# EarlyStopping counter: 3 out of 10
# Epoch:29, [Train] Loss: 0.395
# Epoch:29, [Valid] Loss: 0.289
# EarlyStopping counter: 4 out of 10
# Epoch:30, [Train] Loss: 0.393
# Epoch:30, [Valid] Loss: 0.284
# prev min loss 0.286, now loss 0.284 | save model at epoch: 30
# *************** CYP1A2_Veith ***************
# AUROC: 0.9518 AUPRC: 0.9471 F1: 0.8748
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.884  &  0.884  &          0.872  &     0.878  &0.889  &0.875 &0.952 &   0.767 &   0.947
#
# Epoch:31, [Train] Loss: 0.390
# Epoch:31, [Valid] Loss: 0.286
# EarlyStopping counter: 1 out of 10
# Epoch:32, [Train] Loss: 0.389
# Epoch:32, [Valid] Loss: 0.286
# EarlyStopping counter: 2 out of 10
# Epoch:33, [Train] Loss: 0.386
# Epoch:33, [Valid] Loss: 0.286
# EarlyStopping counter: 3 out of 10
# Epoch:34, [Train] Loss: 0.390
# Epoch:34, [Valid] Loss: 0.285
# EarlyStopping counter: 4 out of 10
# Epoch:35, [Train] Loss: 0.393
# Epoch:35, [Valid] Loss: 0.286
# EarlyStopping counter: 5 out of 10
# Epoch:36, [Train] Loss: 0.390
# Epoch:36, [Valid] Loss: 0.286
# EarlyStopping counter: 6 out of 10
# Epoch:37, [Train] Loss: 0.393
# Epoch:37, [Valid] Loss: 0.289
# EarlyStopping counter: 7 out of 10
# Epoch:38, [Train] Loss: 0.388
# Epoch:38, [Valid] Loss: 0.286
# EarlyStopping counter: 8 out of 10
# Epoch:39, [Train] Loss: 0.391
# Epoch:39, [Valid] Loss: 0.286
# EarlyStopping counter: 9 out of 10
# Epoch:40, [Train] Loss: 0.381
# Epoch:40, [Valid] Loss: 0.286
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 30, min loss: 0.2840
#
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  GIN_SO_DR_0.1/ckpt_CYP1A2_Veith.pt
# using BCELOSSwithdigits
# 100%|██████████| 20/20 [00:05<00:00,  3.74it/s]
# Found local copy...
# Loading...
# Done!
# total_loss: 0.287
# *************** CYP1A2_Veith ***************
# AUROC: 0.9509 AUPRC: 0.9478 F1: 0.8793
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.886  &  0.885  &          0.876  &     0.883  &0.888  &0.879 &0.951 &   0.770 &   0.948
#
# *************** CYP2C9_Veith ***************
# Cleaning mols: 100%|██████████| 8465/8465 [00:23<00:00, 361.42it/s]
# Cleaning mols: 100%|██████████| 1209/1209 [00:03<00:00, 363.11it/s]
# Cleaning mols: 100%|██████████| 2418/2418 [00:06<00:00, 364.68it/s]
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# **************************************** ['CYP2C9_Veith'] ****************************************
# ---> start training...
# Epoch:0, [Train] Loss: 0.649
# Epoch:0, [Valid] Loss: 0.569
# Epoch:1, [Train] Loss: 0.534
# Epoch:1, [Valid] Loss: 0.429
# Epoch:2, [Train] Loss: 0.467
# Epoch:2, [Valid] Loss: 0.365
# Epoch:3, [Train] Loss: 0.448
# Epoch:3, [Valid] Loss: 0.347
# Epoch:4, [Train] Loss: 0.451
# Epoch:4, [Valid] Loss: 0.342
# prev min loss 10000.000, now loss 0.342 | save model at epoch: 4
# *************** CYP2C9_Veith ***************
# AUROC: 0.9273 AUPRC: 0.8575 F1: 0.8052
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.864  &  0.854  &          0.790  &     0.821  &0.887  &0.805 &0.927 &   0.702 &   0.858
#
# Epoch:5, [Train] Loss: 0.445
# Epoch:5, [Valid] Loss: 0.337
# prev min loss 0.342, now loss 0.337 | save model at epoch: 5
# *************** CYP2C9_Veith ***************
# AUROC: 0.9285 AUPRC: 0.8591 F1: 0.8005
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.861  &  0.850  &          0.786  &     0.816  &0.884  &0.800 &0.928 &   0.694 &   0.859
#
# Epoch:6, [Train] Loss: 0.436
# Epoch:6, [Valid] Loss: 0.332
# prev min loss 0.337, now loss 0.332 | save model at epoch: 6
# *************** CYP2C9_Veith ***************
# AUROC: 0.9302 AUPRC: 0.8641 F1: 0.8042
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.860  &  0.855  &          0.771  &     0.840  &0.871  &0.804 &0.930 &   0.697 &   0.864
#
# Epoch:7, [Train] Loss: 0.439
# Epoch:7, [Valid] Loss: 0.330
# prev min loss 0.332, now loss 0.330 | save model at epoch: 7
# *************** CYP2C9_Veith ***************
# AUROC: 0.9312 AUPRC: 0.8641 F1: 0.7986
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.860  &  0.848  &          0.786  &     0.811  &0.886  &0.799 &0.931 &   0.692 &   0.864
#
# Epoch:8, [Train] Loss: 0.433
# Epoch:8, [Valid] Loss: 0.328
# prev min loss 0.330, now loss 0.328 | save model at epoch: 8
# *************** CYP2C9_Veith ***************
# AUROC: 0.9317 AUPRC: 0.8660 F1: 0.8056
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.863  &  0.856  &          0.780  &     0.833  &0.878  &0.806 &0.932 &   0.701 &   0.866
#
# Epoch:9, [Train] Loss: 0.434
# Epoch:9, [Valid] Loss: 0.325
# prev min loss 0.328, now loss 0.325 | save model at epoch: 9
# *************** CYP2C9_Veith ***************
# AUROC: 0.9320 AUPRC: 0.8669 F1: 0.8000
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.861  &  0.850  &          0.787  &     0.814  &0.886  &0.800 &0.932 &   0.694 &   0.867
#
# Epoch:10, [Train] Loss: 0.429
# Epoch:10, [Valid] Loss: 0.324
# prev min loss 0.325, now loss 0.324 | save model at epoch: 10
# *************** CYP2C9_Veith ***************
# AUROC: 0.9315 AUPRC: 0.8666 F1: 0.7926
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.860  &  0.841  &          0.803  &     0.782  &0.901  &0.793 &0.932 &   0.687 &   0.867
#
# Epoch:11, [Train] Loss: 0.437
# Epoch:11, [Valid] Loss: 0.325
# EarlyStopping counter: 1 out of 10
# Epoch:12, [Train] Loss: 0.433
# Epoch:12, [Valid] Loss: 0.325
# EarlyStopping counter: 2 out of 10
# Epoch:13, [Train] Loss: 0.422
# Epoch:13, [Valid] Loss: 0.323
# prev min loss 0.324, now loss 0.323 | save model at epoch: 13
# *************** CYP2C9_Veith ***************
# AUROC: 0.9309 AUPRC: 0.8666 F1: 0.7882
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.857  &  0.838  &          0.797  &     0.780  &0.897  &0.788 &0.931 &   0.680 &   0.867
#
# Epoch:14, [Train] Loss: 0.432
# Epoch:14, [Valid] Loss: 0.325
# EarlyStopping counter: 1 out of 10
# Epoch:15, [Train] Loss: 0.434
# Epoch:15, [Valid] Loss: 0.326
# EarlyStopping counter: 2 out of 10
# Epoch:16, [Train] Loss: 0.428
# Epoch:16, [Valid] Loss: 0.324
# EarlyStopping counter: 3 out of 10
# Epoch:17, [Train] Loss: 0.424
# Epoch:17, [Valid] Loss: 0.322
# prev min loss 0.323, now loss 0.322 | save model at epoch: 17
# *************** CYP2C9_Veith ***************
# AUROC: 0.9315 AUPRC: 0.8689 F1: 0.7957
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.859  &  0.845  &          0.790  &     0.801  &0.889  &0.796 &0.931 &   0.689 &   0.869
#
# Epoch:18, [Train] Loss: 0.427
# Epoch:18, [Valid] Loss: 0.326
# EarlyStopping counter: 1 out of 10
# Epoch:19, [Train] Loss: 0.439
# Epoch:19, [Valid] Loss: 0.327
# EarlyStopping counter: 2 out of 10
# Epoch:20, [Train] Loss: 0.426
# Epoch:20, [Valid] Loss: 0.324
# EarlyStopping counter: 3 out of 10
# Epoch:21, [Train] Loss: 0.425
# Epoch:21, [Valid] Loss: 0.325
# EarlyStopping counter: 4 out of 10
# Epoch:22, [Train] Loss: 0.430
# Epoch:22, [Valid] Loss: 0.324
# EarlyStopping counter: 5 out of 10
# Epoch:23, [Train] Loss: 0.423
# Epoch:23, [Valid] Loss: 0.322
# prev min loss 0.322, now loss 0.322 | save model at epoch: 23
# *************** CYP2C9_Veith ***************
# AUROC: 0.9316 AUPRC: 0.8684 F1: 0.7966
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.860  &  0.846  &          0.792  &     0.801  &0.891  &0.797 &0.932 &   0.690 &   0.868
#
# Epoch:24, [Train] Loss: 0.430
# Epoch:24, [Valid] Loss: 0.325
# EarlyStopping counter: 1 out of 10
# Epoch:25, [Train] Loss: 0.429
# Epoch:25, [Valid] Loss: 0.324
# EarlyStopping counter: 2 out of 10
# Epoch:26, [Train] Loss: 0.429
# Epoch:26, [Valid] Loss: 0.324
# EarlyStopping counter: 3 out of 10
# Epoch:27, [Train] Loss: 0.423
# Epoch:27, [Valid] Loss: 0.322
# EarlyStopping counter: 4 out of 10
# Epoch:28, [Train] Loss: 0.428
# Epoch:28, [Valid] Loss: 0.325
# EarlyStopping counter: 5 out of 10
# Epoch:29, [Train] Loss: 0.430
# Epoch:29, [Valid] Loss: 0.323
# EarlyStopping counter: 6 out of 10
# Epoch:30, [Train] Loss: 0.424
# Epoch:30, [Valid] Loss: 0.322
# EarlyStopping counter: 7 out of 10
# Epoch:31, [Train] Loss: 0.427
# Epoch:31, [Valid] Loss: 0.323
# EarlyStopping counter: 8 out of 10
# Epoch:32, [Train] Loss: 0.419
# Epoch:32, [Valid] Loss: 0.320
# prev min loss 0.322, now loss 0.320 | save model at epoch: 32
# *************** CYP2C9_Veith ***************
# AUROC: 0.9313 AUPRC: 0.8691 F1: 0.7947
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.858  &  0.845  &          0.784  &     0.806  &0.884  &0.795 &0.931 &   0.686 &   0.869
#
# Epoch:33, [Train] Loss: 0.417
# Epoch:33, [Valid] Loss: 0.319
# prev min loss 0.320, now loss 0.319 | save model at epoch: 33
# *************** CYP2C9_Veith ***************
# AUROC: 0.9317 AUPRC: 0.8707 F1: 0.7801
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.850  &  0.833  &          0.783  &     0.777  &0.888  &0.780 &0.932 &   0.667 &   0.871
#
# Epoch:34, [Train] Loss: 0.415
# Epoch:34, [Valid] Loss: 0.321
# EarlyStopping counter: 1 out of 10
# Epoch:35, [Train] Loss: 0.416
# Epoch:35, [Valid] Loss: 0.320
# EarlyStopping counter: 2 out of 10
# Epoch:36, [Train] Loss: 0.423
# Epoch:36, [Valid] Loss: 0.322
# EarlyStopping counter: 3 out of 10
# Epoch:37, [Train] Loss: 0.420
# Epoch:37, [Valid] Loss: 0.321
# EarlyStopping counter: 4 out of 10
# Epoch:38, [Train] Loss: 0.419
# Epoch:38, [Valid] Loss: 0.321
# EarlyStopping counter: 5 out of 10
# Epoch:39, [Train] Loss: 0.417
# Epoch:39, [Valid] Loss: 0.319
# EarlyStopping counter: 6 out of 10
# Epoch:40, [Train] Loss: 0.416
# Epoch:40, [Valid] Loss: 0.319
# prev min loss 0.319, now loss 0.319 | save model at epoch: 40
# *************** CYP2C9_Veith ***************
# AUROC: 0.9322 AUPRC: 0.8721 F1: 0.8005
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.862  &  0.850  &          0.790  &     0.811  &0.888  &0.800 &0.932 &   0.695 &   0.872
#
# Epoch:41, [Train] Loss: 0.416
# Epoch:41, [Valid] Loss: 0.317
# prev min loss 0.319, now loss 0.317 | save model at epoch: 41
# *************** CYP2C9_Veith ***************
# AUROC: 0.9325 AUPRC: 0.8721 F1: 0.7917
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.859  &  0.841  &          0.797  &     0.787  &0.896  &0.792 &0.933 &   0.685 &   0.872
#
# Epoch:42, [Train] Loss: 0.418
# Epoch:42, [Valid] Loss: 0.317
# prev min loss 0.317, now loss 0.317 | save model at epoch: 42
# *************** CYP2C9_Veith ***************
# AUROC: 0.9326 AUPRC: 0.8732 F1: 0.8014
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.863  &  0.850  &          0.792  &     0.811  &0.889  &0.801 &0.933 &   0.697 &   0.873
#
# Epoch:43, [Train] Loss: 0.413
# Epoch:43, [Valid] Loss: 0.318
# EarlyStopping counter: 1 out of 10
# Epoch:44, [Train] Loss: 0.418
# Epoch:44, [Valid] Loss: 0.319
# EarlyStopping counter: 2 out of 10
# Epoch:45, [Train] Loss: 0.414
# Epoch:45, [Valid] Loss: 0.316
# prev min loss 0.317, now loss 0.316 | save model at epoch: 45
# *************** CYP2C9_Veith ***************
# AUROC: 0.9328 AUPRC: 0.8741 F1: 0.7990
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.861  &  0.848  &          0.790  &     0.809  &0.888  &0.799 &0.933 &   0.693 &   0.874
#
# Epoch:46, [Train] Loss: 0.415
# Epoch:46, [Valid] Loss: 0.316
# EarlyStopping counter: 1 out of 10
# Epoch:47, [Train] Loss: 0.419
# Epoch:47, [Valid] Loss: 0.316
# prev min loss 0.316, now loss 0.316 | save model at epoch: 47
# *************** CYP2C9_Veith ***************
# AUROC: 0.9326 AUPRC: 0.8744 F1: 0.7904
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.856  &  0.841  &          0.787  &     0.794  &0.888  &0.790 &0.933 &   0.681 &   0.874
#
# Epoch:48, [Train] Loss: 0.404
# Epoch:48, [Valid] Loss: 0.315
# prev min loss 0.316, now loss 0.315 | save model at epoch: 48
# *************** CYP2C9_Veith ***************
# AUROC: 0.9329 AUPRC: 0.8746 F1: 0.8019
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.860  &  0.852  &          0.777  &     0.828  &0.877  &0.802 &0.933 &   0.695 &   0.875
#
# Epoch:49, [Train] Loss: 0.415
# Epoch:49, [Valid] Loss: 0.316
# EarlyStopping counter: 1 out of 10
# Epoch:50, [Train] Loss: 0.420
# Epoch:50, [Valid] Loss: 0.316
# EarlyStopping counter: 2 out of 10
# Epoch:51, [Train] Loss: 0.413
# Epoch:51, [Valid] Loss: 0.316
# EarlyStopping counter: 3 out of 10
# Epoch:52, [Train] Loss: 0.410
# Epoch:52, [Valid] Loss: 0.316
# EarlyStopping counter: 4 out of 10
# Epoch:53, [Train] Loss: 0.411
# Epoch:53, [Valid] Loss: 0.315
# prev min loss 0.315, now loss 0.315 | save model at epoch: 53
# *************** CYP2C9_Veith ***************
# AUROC: 0.9333 AUPRC: 0.8747 F1: 0.8019
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.863  &  0.851  &          0.791  &     0.814  &0.888  &0.802 &0.933 &   0.697 &   0.875
#
# Epoch:54, [Train] Loss: 0.411
# Epoch:54, [Valid] Loss: 0.315
# prev min loss 0.315, now loss 0.315 | save model at epoch: 54
# *************** CYP2C9_Veith ***************
# AUROC: 0.9336 AUPRC: 0.8753 F1: 0.7971
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.859  &  0.847  &          0.786  &     0.809  &0.886  &0.797 &0.934 &   0.690 &   0.875
#
# Epoch:55, [Train] Loss: 0.411
# Epoch:55, [Valid] Loss: 0.315
# EarlyStopping counter: 1 out of 10
# Epoch:56, [Train] Loss: 0.404
# Epoch:56, [Valid] Loss: 0.314
# prev min loss 0.315, now loss 0.314 | save model at epoch: 56
# *************** CYP2C9_Veith ***************
# AUROC: 0.9332 AUPRC: 0.8739 F1: 0.7966
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.861  &  0.846  &          0.797  &     0.797  &0.894  &0.797 &0.933 &   0.691 &   0.874
#
# Epoch:57, [Train] Loss: 0.416
# Epoch:57, [Valid] Loss: 0.313
# prev min loss 0.314, now loss 0.313 | save model at epoch: 57
# *************** CYP2C9_Veith ***************
# AUROC: 0.9334 AUPRC: 0.8735 F1: 0.7986
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.861  &  0.848  &          0.791  &     0.806  &0.889  &0.799 &0.933 &   0.693 &   0.874
#
# Epoch:58, [Train] Loss: 0.403
# Epoch:58, [Valid] Loss: 0.313
# prev min loss 0.313, now loss 0.313 | save model at epoch: 58
# *************** CYP2C9_Veith ***************
# AUROC: 0.9335 AUPRC: 0.8743 F1: 0.7921
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.860  &  0.841  &          0.805  &     0.780  &0.902  &0.792 &0.933 &   0.687 &   0.874
#
# Epoch:59, [Train] Loss: 0.404
# Epoch:59, [Valid] Loss: 0.313
# EarlyStopping counter: 1 out of 10
# Epoch:60, [Train] Loss: 0.414
# Epoch:60, [Valid] Loss: 0.314
# EarlyStopping counter: 2 out of 10
# Epoch:61, [Train] Loss: 0.408
# Epoch:61, [Valid] Loss: 0.313
# EarlyStopping counter: 3 out of 10
# Epoch:62, [Train] Loss: 0.405
# Epoch:62, [Valid] Loss: 0.313
# EarlyStopping counter: 4 out of 10
# Epoch:63, [Train] Loss: 0.402
# Epoch:63, [Valid] Loss: 0.313
# EarlyStopping counter: 5 out of 10
# Epoch:64, [Train] Loss: 0.401
# Epoch:64, [Valid] Loss: 0.311
# prev min loss 0.313, now loss 0.311 | save model at epoch: 64
# *************** CYP2C9_Veith ***************
# AUROC: 0.9340 AUPRC: 0.8751 F1: 0.7943
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.858  &  0.845  &          0.785  &     0.804  &0.886  &0.794 &0.934 &   0.686 &   0.875
#
# Epoch:65, [Train] Loss: 0.410
# Epoch:65, [Valid] Loss: 0.311
# EarlyStopping counter: 1 out of 10
# Epoch:66, [Train] Loss: 0.408
# Epoch:66, [Valid] Loss: 0.312
# EarlyStopping counter: 2 out of 10
# Epoch:67, [Train] Loss: 0.410
# Epoch:67, [Valid] Loss: 0.312
# EarlyStopping counter: 3 out of 10
# Epoch:68, [Train] Loss: 0.402
# Epoch:68, [Valid] Loss: 0.315
# EarlyStopping counter: 4 out of 10
# Epoch:69, [Train] Loss: 0.407
# Epoch:69, [Valid] Loss: 0.313
# EarlyStopping counter: 5 out of 10
# Epoch:70, [Train] Loss: 0.408
# Epoch:70, [Valid] Loss: 0.312
# EarlyStopping counter: 6 out of 10
# Epoch:71, [Train] Loss: 0.405
# Epoch:71, [Valid] Loss: 0.313
# EarlyStopping counter: 7 out of 10
# Epoch:72, [Train] Loss: 0.396
# Epoch:72, [Valid] Loss: 0.314
# EarlyStopping counter: 8 out of 10
# Epoch:73, [Train] Loss: 0.407
# Epoch:73, [Valid] Loss: 0.312
# EarlyStopping counter: 9 out of 10
# Epoch:74, [Train] Loss: 0.399
# Epoch:74, [Valid] Loss: 0.311
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 64, min loss: 0.3108
#
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  GIN_SO_DR_0.1/ckpt_CYP2C9_Veith.pt
# using BCELOSSwithdigits
# 100%|██████████| 19/19 [00:05<00:00,  3.50it/s]
# total_loss: 0.303
# *************** CYP2C9_Veith ***************
# AUROC: 0.9383 AUPRC: 0.8730 F1: 0.8100
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.872  &  0.856  &          0.813  &     0.807  &0.905  &0.810 &0.938 &   0.713 &   0.873

# %%
*************** CYP2C19_Veith ***************
AUROC: 0.9299 AUPRC: 0.9149 F1: 0.8537
Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
& 0.861  &  0.863  &          0.826  &     0.883  &0.842  &0.854 &0.930 &   0.723 &   0.915

*************** CYP2D6_Veith ***************
AUROC: 0.9051 AUPRC: 0.7556 F1: 0.6757
Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
& 0.890  &  0.784  &          0.750  &     0.615  &0.953  &0.676 &0.905 &   0.615 &   0.756

*************** CYP3A4_Veith ***************
AUROC: 0.9232 AUPRC: 0.8895 F1: 0.8216
Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
& 0.851  &  0.848  &          0.812  &     0.831  &0.865  &0.822 &0.923 &   0.694 &   0.890

*************** CYP1A2_Veith ***************
AUROC: 0.9509 AUPRC: 0.9478 F1: 0.8793
Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
& 0.886  &  0.885  &          0.876  &     0.883  &0.888  &0.879 &0.951 &   0.770 &   0.948

*************** CYP2C9_Veith ***************
AUROC: 0.9383 AUPRC: 0.8730 F1: 0.8100
Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
& 0.872  &  0.856  &          0.813  &     0.807  &0.905  &0.810 &0.938 &   0.713 &   0.873
