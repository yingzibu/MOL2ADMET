# %% [markdown]
# <a href="https://colab.research.google.com/github/yingzibu/MOL2ADMET/blob/main/examples/experiments/ADMET_MLP_AT_GIN_10_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install rdkit --quiet
! pip install PyTDC --quiet
! pip install mycolorpy --quiet

! pip install dgllife --quiet
! pip install molvs --quiet
! pip install dgl -f https://data.dgl.ai/wheels/cu118/repo.html --quiet
! pip install dglgo -f https://data.dgl.ai/wheels-test/repo.html --quiet

! pip install DeepPurpose --quiet
! pip install git+https://github.com/bp-kelley/descriptastorus --quiet
! pip install pandas-flavor --quiet

# %%
cd /content/drive/MyDrive/ADMET
# Out:
# /content/drive/MyDrive/ADMET

# %%
from os import walk
import os
files = next(walk('/content/drive/MyDrive/ADMET/'), (None, None, []))[2]
for file in files:
    if isinstance(file, str):
        file_type = file.split('.')[-1]
        # print(file_type)
        if file_type == 'bin' or file_type == 'pth':
            os.remove(file)

# %% [markdown]
# # Evaluation Functions
# #### classification already writen in scripts eval_utils
#
# #### regression: here:

# %%
from scripts.eval_utils import *
from scripts.preprocess_mols import *
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import roc_auc_score, average_precision_score, f1_score

device = 'cuda'
import sklearn.metrics as metrics

import numpy as np

def reg_evaluate(label_clean, preds_clean):
    mae = metrics.mean_absolute_error(label_clean, preds_clean)
    mse = metrics.mean_squared_error(label_clean, preds_clean)
    rmse = np.sqrt(mse) #mse**(0.5)
    r2 = metrics.r2_score(label_clean, preds_clean)

    print('MAE,      MSE,      RMSE,      R2')
    print("& %5.3f" % (mae), " &%5.3f" % (mse), " &%5.3f" % (rmse),
      " &%5.3f" % (r2))

    eval_result_r2 =   f'R2:     {r2:.3f}'
    eval_result_mae =  f'MAE:   {mae:.3f}'
    eval_result_rmse = f'RMSE: {rmse:.3f}'

    return eval_result_r2, eval_result_mae, eval_result_rmse

from mycolorpy import colorlist as mcp
import matplotlib.pyplot as plt

def eval_dict(y_probs:dict, y_label:dict, names:list, IS_R, draw_fig=False):
    if isinstance(IS_R, list): task_list = IS_R
    else: task_list = [IS_R] * len(names)
    for i, (name, IS_R) in enumerate(zip(names, task_list)):
        # IS_R = task_list[i]
        print('*'*15, name, '*'*15)
        # print('Regression task', IS_R)

        probs = y_probs[name]
        label = y_label[name]
        assert len(probs) == len(label)
        if IS_R == False: # classification task
            preds = get_preds(0.5, probs)
            evaluate(label, preds, probs)

        else: # regression task
            r2, mae, rmse = reg_evaluate(label, probs)
            if draw_fig:
                color = mcp.gen_color_normalized(cmap='viridis',
                                                data_arr=label)
                plt.scatter(label, probs, cmap='viridis', marker='.',
                            s=10, alpha=0.5, edgecolors='none', c=color)
                plt.xlabel(f'True {name}')
                plt.ylabel(f'Predicted {name}')
                plt.title(f'{name} prediction on test set')

                x0, xmax = plt.xlim()
                y0, ymax = plt.ylim()
                data_width = xmax - x0
                data_height = ymax - y0
                # print(x0, xmax, y0, ymax, data_width, data_height)
                plt.text(x0 + 0.1*data_width, y0 + data_height * 0.8/0.95, r2)
                plt.text(x0 + 0.1*data_width, y0 + data_height * 0.8,  mae)
                plt.text(x0 + 0.1*data_width, y0 + data_height * 0.8*0.95, rmse)

                plt.show()
                plt.cla()
                plt.clf()
                plt.close()
        print()

# %% [markdown]
# # Models architecture
#
# #### Classifier: MLP
#
# #### AttentiveFP

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class Classifier(nn.Module):
    def __init__(self, **config):
        super(Classifier, self).__init__()
        dims = [config['in_dim'], config['hid_dims'], config['out_dim']]
        self.dims = dims
        neurons = [config['in_dim'], *config['hid_dims']]
        linear_layers = [nn.Linear(neurons[i-1], neurons[i]) \
                         for i in range(1, len(neurons))]
        self.hidden = nn.ModuleList(linear_layers)
        self.final = nn.Linear(config['hid_dims'][-1], config['out_dim'])
        self.dropout = nn.Dropout(config['dropout'])

    def forward(self, x):
        for layer in self.hidden: x = F.relu(layer(x))
        x = self.final(x)
        return self.dropout(x)

    def get_dim(self): return self.dims

# %%
import time
import pandas as pd
import dgl
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from dgllife.model import model_zoo
from dgllife.utils import smiles_to_bigraph
from dgllife.utils import EarlyStopping, Meter
from dgllife.utils import AttentiveFPAtomFeaturizer
from dgllife.utils import AttentiveFPBondFeaturizer
from dgllife.data import MoleculeCSVDataset



def get_model_AT_10_17(names, n_layers, graph_feat_size, dropout):
    atom_featurizer = AttentiveFPAtomFeaturizer(atom_data_field='hv')
    bond_featurizer = AttentiveFPBondFeaturizer(bond_data_field='he')
    n_feats_num = atom_featurizer.feat_size('hv')
    e_feats_num = bond_featurizer.feat_size('he')

    model = model_zoo.AttentiveFPPredictor(
            node_feat_size=n_feats_num, edge_feat_size=e_feats_num,
            num_layers=n_layers, num_timesteps=1,
            graph_feat_size=graph_feat_size,
            n_tasks=len(names), dropout=dropout)
    return model

# %%
def AttentiveFP(**config):
    return get_model_AT_10_17(config['prop_names'], config['n_layers'],
                                    config['in_dim'], config['dropout'])

# AttentiveFP(**config_AttentiveFP)

# %% [markdown]
# GIN

# %%
# https://lifesci.dgl.ai/_modules/dgllife/model/pretrain.html

class GIN_MOD(nn.Module):
    """
    Reference: https://github.com/kexinhuang12345/DeepPurpose/blob/master/DeepPurpose/encoders.py#L392
    """
	## adapted from https://github.com/awslabs/dgl-lifesci/blob/2fbf5fd6aca92675b709b6f1c3bc3c6ad5434e96/examples/property_prediction/moleculenet/utils.py#L76
    def __init__(self, **config):
        super(GIN_MOD, self).__init__()
        self.gnn = load_pretrained('gin_supervised_contextpred')
        self.readout = AvgPooling()
        self.transform = nn.Linear(300, config['in_dim'])
        self.dropout = nn.Dropout(config['dropout'])
        self.hidden_dims = config['hid_dims']
        self.out_dim = config['out_dim']
        layer_size = len(self.hidden_dims)
        neurons = [config['in_dim'], *self.hidden_dims]
        linear_layers = [nn.Linear(neurons[i-1], neurons[i]) \
                         for i in range(1, len(neurons))]
        self.hidden = nn.ModuleList(linear_layers)
        self.final = nn.Linear(self.hidden_dims[-1], self.out_dim)

    def forward(self, bg):
        # bg = bg.to(device)
        node_feats = [
            bg.ndata.pop('atomic_number'),
            bg.ndata.pop('chirality_type')
        ]
        edge_feats = [
            bg.edata.pop('bond_type'),
            bg.edata.pop('bond_direction_type')
        ]

        node_feats = self.gnn(bg, node_feats, edge_feats)
        x = self.readout(bg, node_feats)
        x = self.transform(x)
        for layer in self.hidden: x = F.leaky_relu(layer(x))
        x = self.final(x)
        return self.dropout(x)

# %% [markdown]
# # Train eval test functions

# %%
def train_epoch_MLP(model, loader, IS_R, names, device, epoch=None,
                    optimizer=None, MASK=-100, scale_dict=None):
    if optimizer==None: # no optimizer, either validation or test
        model.eval()    # model evaluation for either valid or test
        if epoch != None: train_type='Valid' # if epoch is inputted, its valid
        else: train_type = 'Test' # if no epoch information, its test
    else: model.train(); train_type='Train' # if optimizer inputted, its train

    if isinstance(IS_R, list): IS_R_list = IS_R
    else: IS_R_list = [IS_R] * len(names)
    losses = 0
    y_probs = {}
    y_label = {}
    for idx, batch_data in enumerate(loader):
        """
        len(batch_data) could determine which algorithm
        len(batch_data) == 2: MLP, GIN
        len(batch_data) == 4: AttentiveFP
        """
        if len(batch_data) == 2:  # MLP or GIN
            fp, labels = batch_data
            fp, labels = fp.to(device), labels.to(device)
            mask = labels == MASK
            pred = model(fp)
        elif len(batch_data) == 4: # attentiveFP
            smiles, bg, labels, masks = batch_data
            bg, labels, masks = bg.to(device), labels.to(device), masks.to(device)
            n_feats = bg.ndata.pop('hv').to(device)
            e_feats = bg.edata.pop('he').to(device)
            pred = model(bg, n_feats, e_feats)
            mask = masks < 1

        for j, (name, IS_R) in enumerate(zip(names, IS_R_list)):
            loss_func = get_loss_fn(IS_R)
            probs = pred[:, j][~mask[:, j]]
            label = labels[:, j][~mask[:, j]]
            if j == 0: loss = loss_func(probs, label)
            else: loss += loss_func(probs, label)
            if IS_R == False: probs = F.sigmoid(probs)

            if train_type != 'Train': # validation
                probs = probs.cpu().detach().numpy().tolist()
                label = label.cpu().detach().numpy().tolist()
                if scale_dict != None:
                    min_here = scale_dict[name][0]
                    max_here = scale_dict[name][1]
                    del_here = max_here - min_here
                    label = [l * del_here + min_here for l in label]
                    probs = [p * del_here + min_here for p in probs]

                if idx ==0: y_probs[name], y_label[name] = probs, label
                else:
                    y_probs[name] += probs
                    y_label[name] += label

        losses += loss.item()
        if optimizer != None: optimizer.zero_grad(); loss.backward(); optimizer.step()

    total_loss = losses / len(loader.dataset)
    if epoch != None: # train or valid
        print(f'Epoch:{epoch}, [{train_type}] Loss: {total_loss:.3f}')
    else: # test
        print(f'[{train_type}] Loss: {total_loss:.3f}')
        eval_dict(y_probs, y_label, names, IS_R_list, draw_fig=True)

    if train_type == 'train': return total_loss
    else: return total_loss, y_probs, y_label

# %% [markdown]
# # dataset and dataloader functions

# %%
from torch.utils.data import DataLoader, Dataset

import pandas as pd
import rdkit
from rdkit import Chem
from rdkit.Chem.MACCSkeys import GenMACCSKeys
import torch.nn.functional as F

m = Chem.MolFromSmiles
header = ['bit' + str(i) for i in range(167)]

def smile_list_to_MACCS(smi_list:list):
    MACCS_list = []
    for smi in smi_list:
        maccs = [float(i) for i in list(GenMACCSKeys(m(smi)).ToBitString())]
        MACCS_list.append(maccs)
    return MACCS_list

import torch
def process(data):

    # data = convert_with_qed_sa(data)
    print('---> converting SMILES to MACCS...')
    MACCS_list = smile_list_to_MACCS(data['Drug'].tolist())
    data[header] = pd.DataFrame(MACCS_list)
    print('---> FINISHED')
    return data

MASK = -100

class nn_dataset(Dataset):
    def __init__(self, df, prop_names, mask=MASK):
        super(nn_dataset, self).__init__()
        df = process(df)
        df = df.fillna(mask)
        self.df = df
        self.len = len(df)
        self.fp = self.df[header]
        if isinstance(prop_names, str): prop_names = [prop_names]
        self.props = self.df[prop_names]

    def __getitem__(self, idx):
        fp = torch.tensor(self.fp.iloc[idx], dtype=torch.float32)
        label = torch.tensor(self.props.iloc[idx], dtype=torch.float32)
        return fp, label

    def __len__(self): return self.len

    def get_df(self): return self.df

# %% [markdown]
# AttentiveFP

# %%
def collate_molgraphs(data):
    assert len(data[0]) in [3, 4], \
        'Expect the tuple to be of length 3 or 4, got {:d}'.format(len(data[0]))
    if len(data[0]) == 3:
        smiles, graphs, labels = map(list, zip(*data))
        masks = None
    else:
        smiles, graphs, labels, masks = map(list, zip(*data))

    bg = dgl.batch(graphs)
    bg.set_n_initializer(dgl.init.zero_initializer)
    bg.set_e_initializer(dgl.init.zero_initializer)
    labels = torch.stack(labels, dim=0)

    if masks is None:
        masks = torch.ones(labels.shape)
    else:
        masks = torch.stack(masks, dim=0)
        # masks = (labels == MASK).long()
    return smiles, bg, labels, masks

def get_AttentiveFP_dataset(df, name):
    atom_featurizer = AttentiveFPAtomFeaturizer(atom_data_field='hv')
    bond_featurizer = AttentiveFPBondFeaturizer(bond_data_field='he')
    time_string = time.strftime("%m_%d_%Y_%H:%M:%S", time.localtime())

    params = {'smiles_to_graph': smiles_to_bigraph,
            'node_featurizer': atom_featurizer,
            'edge_featurizer': bond_featurizer,
            'smiles_column': 'Drug',
            'cache_file_path': time_string+'.bin',
            'task_names': name, 'load': True, 'n_jobs': len(name)*2}
    graph_dataset = MoleculeCSVDataset(df, **params)
    return graph_dataset

def get_AttentiveFP_loader(df, name, **loader_params):
    dataset = get_AttentiveFP_dataset(df, name)
    loader_params['collate_fn'] = collate_molgraphs
    loader = DataLoader(dataset, **loader_params)
    return loader

# %% [markdown]
# GIN data set and data loader

# %%
from dgllife.model import load_pretrained
from dgl.nn.pytorch.glob import AvgPooling
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from functools import partial
import torch
from dgllife.utils import smiles_to_bigraph, PretrainAtomFeaturizer, PretrainBondFeaturizer

MASK = -100

class GIN_dataset(Dataset):
    def __init__(self, df, names, mask=MASK):
        df = df.fillna(mask)
        self.names = names
        self.df = df
        self.len = len(df)
        self.props = self.df[names]
        self.node_featurizer = PretrainAtomFeaturizer()
        self.edge_featurizer = PretrainBondFeaturizer()
        self.fc = partial(smiles_to_bigraph, add_self_loop=True)
    def __len__(self): return self.len
    def __getitem__(self, idx):
        v_d = self.df.iloc[idx]['Drug']
        v_d = self.fc(smiles=v_d, node_featurizer = self.node_featurizer,
                      edge_featurizer = self.edge_featurizer)
        label = torch.tensor(self.props.iloc[idx], dtype=torch.float32)
        return v_d, label

import dgl
def get_GIN_dataloader(datasets, **loader_params):
    def dgl_collate_func(data):
        x, labels = map(list, zip(*data))
        bg = dgl.batch(x)
        labels = torch.stack(labels, dim=0)
        bg.set_n_initializer(dgl.init.zero_initializer)
        bg.set_e_initializer(dgl.init.zero_initializer)
        return bg, labels
    loader_params['collate_fn'] = dgl_collate_func
    return DataLoader(datasets, **loader_params)

# %%
def init_model(**config):
    """need incorporate all models here! """
    if config['model_type'] == 'MLP':
        model = Classifier(**config)
    elif config['model_type'] == 'GIN':
        model = GIN_MOD(**config) # need work config GIN out_dim
    elif config['model_type'] == 'AttentiveFP':
        model = AttentiveFP(**config)
    elif config['model_type'] == 'RNN': pass
    return model

def get_loss_fn(IS_R):
    if IS_R: return nn.MSELoss(reduction='sum')
    else: return nn.BCEWithLogitsLoss(reduction='sum')

def get_train_fn(model_type):
    if model_type == 'MLP': return train_epoch_MLP

    elif model_type == 'GIN': return train_epoch_MLP
    elif model_type == 'AttentiveFP': return train_epoch_MLP
    elif model_type == 'RNN': pass

def get_eval_fn(model_type):
    if model_type == 'MLP': return train_epoch_MLP

    elif model_type == 'GIN': return train_epoch_MLP
    elif model_type == 'AttentiveFP': return train_epoch_MLP
    elif model_type == 'RNN': pass


def get_loader(df, names, params, model_type):
    print('--> preparing data loader for model type ', model_type)
    if model_type == 'MLP': return DataLoader(nn_dataset(df, names), **params)

    elif model_type == 'GIN':
        return get_GIN_dataloader(GIN_dataset(df, names), **params)

    elif model_type == 'AttentiveFP':
        return get_AttentiveFP_loader(df, names, **params)

    elif model_type == 'RNN': pass

# %%
from scripts.preprocess_mols import preprocess, rename_cols, clean_mol, scal
from tdc.single_pred import ADME
from tdc.single_pred import Tox
from tdc.utils import retrieve_label_name_list
label_list = retrieve_label_name_list('herg_central')

def collect_data_10_17(names:list, clean_mol_=False):
    for i, name in enumerate(names):
        print('*'*15, name, '*'*15)
        if name in label_list:
            data = Tox(name='herg_central', label_name=name)
        else:
            try: data = ADME(name=name)
            except:
                try: data = Tox(name=name)
                except: print('cannot read data!'); break
            # data.label_distribution()
        split = data.get_split()
        train, valid, test = split['train'], split['valid'], split['test']
        if clean_mol_:
            train, valid, test = clean_mol(train), clean_mol(valid), clean_mol(test)

        train = rename_cols(train[['Drug', 'Y']], name)
        valid = rename_cols(valid[['Drug', 'Y']], name)
        test  = rename_cols(test[['Drug', 'Y']],  name)

        if i == 0: trains, valids, tests = train, valid, test
        else:
            trains = trains.merge(train, how='outer')
            valids = valids.merge(valid, how='outer')
            tests = tests.merge(test, how='outer')

    return trains, valids, tests

# %%
from dgllife.utils import EarlyStopping, Meter
from tqdm import tqdm

class PRED:
    def __init__(self, **config):
        cuda = torch.cuda.is_available()
        if cuda: self.device = 'cuda'
        else:    self.device = 'cpu'
        self.prop_names = config['prop_names']
        self.config = config
        if 'scale_dict' in config:
            self.scale_dict = config['scale_dict']
        else: self.scale_dict = None
        self.model_type = config['model_type']
        print('model type: ', self.model_type)
        self.model_path = config['model_path']

        self.eval_fn = get_eval_fn(self.model_type)
        self.train_fn = get_train_fn(self.model_type)

        self.model = init_model(**config).to(self.device)

        self.IS_R = config['IS_R'] # could be list, could be true/false
        self.optimizer = torch.optim.AdamW(self.model.parameters(),
                        lr=config['lr'], weight_decay=config['wd'])
        self.stopper = EarlyStopping(mode='lower', patience=config['patience'])

        self.min_loss = np.inf
        self.best_epoch = 0

    def load_model(self, path):
        con = self.config.copy()
        con['dropout'] = 0
        self.model = init_model(**con).to(self.device)
        print('load pretrained model from ', path)
        self.model.load_state_dict(torch.load(path, map_location=self.device))

    def eval(self, loader, path=None):
        if path != None: self.load_model(path)
        self.eval_fn(self.model, loader, self.IS_R, self.prop_names, self.device,
               epoch=None, optimizer=None, MASK=-100, scale_dict=self.scale_dict)

    def train(self, data_loader, val_loader, test_loader=None):
        if self.best_epoch != 0: self.load_model(self.model_path)

        for epoch in range(500):
            score = self.train_fn(self.model, data_loader, self.IS_R,
                                  self.prop_names, self.device, epoch,
                                  self.optimizer, scale_dict=self.scale_dict)
            val_score, probs, labels = self.train_fn(self.model, val_loader,
                                       self.IS_R, self.prop_names, self.device,
                                       epoch, scale_dict=self.scale_dict)

            early_stop = self.stopper.step(val_score, self.model)
            if val_score < self.min_loss:
                print(f'prev min loss {self.min_loss:.3f}, '
                      f'now loss {val_score:.3f} |',
                      f'save model at epoch: {epoch}')
                self.min_loss = val_score
                torch.save(self.model.state_dict(), self.model_path)
                self.best_epoch = epoch
                eval_dict(probs, labels, self.prop_names, IS_R=self.IS_R)

            if early_stop: print('early stop'); break

        print(f"best epoch: {self.best_epoch}, min loss: {self.min_loss:.4f}")
        print()
        if test_loader != None: self.eval(test_loader, self.model_path)

# %% [markdown]
# # TEST MLP MO

# %%
names = ['CYP2C19_Veith', 'CYP2D6_Veith', 'CYP3A4_Veith',
         'CYP1A2_Veith', 'CYP2C9_Veith']

IS_R = [False] * len(names)

trains, valids, tests = collect_data_10_17(names)

# %%
import pandas as pd
def count_(df:pd.DataFrame):
    for col in df.columns:
        if col != 'Drug':
            try:
                ones = df[col].value_counts()[1]
                zero = df[col].value_counts()[0]
            except: ones = 'Nan'; zero = 'Nan'
            print(col, f'\t 0: {zero} | 1: {ones}')
    print()

count_(trains), count_(valids), count_(tests)
# Out:
# CYP2C19_Veith 	 0: 4803 | 1: 4063
# CYP2D6_Veith 	 0: 7425 | 1: 1766
# CYP3A4_Veith 	 0: 5052 | 1: 3577
# CYP1A2_Veith 	 0: 4745 | 1: 4060
# CYP2C9_Veith 	 0: 5652 | 1: 2813
#
# CYP2C19_Veith 	 0: 673 | 1: 593
# CYP2D6_Veith 	 0: 1053 | 1: 260
# CYP3A4_Veith 	 0: 717 | 1: 516
# CYP1A2_Veith 	 0: 677 | 1: 581
# CYP2C9_Veith 	 0: 796 | 1: 413
#
# CYP2C19_Veith 	 0: 1370 | 1: 1163
# CYP2D6_Veith 	 0: 2138 | 1: 488
# CYP3A4_Veith 	 0: 1449 | 1: 1017
# CYP1A2_Veith 	 0: 1328 | 1: 1188
# CYP2C9_Veith 	 0: 1599 | 1: 819
# (None, None, None)

# %%
batch_size = 64
loader_params = {'batch_size': batch_size, 'shuffle': True}
train_loader = get_loader(trains, names, loader_params, 'MLP')
valid_loader = get_loader(valids, names, loader_params, 'MLP')

test_params = {'batch_size': batch_size, 'shuffle': False}
test_loader  = get_loader(tests,  names,  test_params,  'MLP')

# %%
in_dim = 167
hid_dims = [256]
dropout = 0.1
lr = 3e-4
wd = 1e-5
patience = 10

config = {'model_type': 'MLP',
          'in_dim': in_dim,
          'hid_dims': hid_dims,
          'out_dim': len(names),
          'prop_names': names,
          'dropout': dropout,
          'IS_R': IS_R,
          'lr': lr,
          'wd': wd,
          'patience': patience,
          'model_path': 'ckpt.pt'}
print(config)
models = PRED(**config)
models.train(train_loader, valid_loader)

# %%
models.eval(test_loader, config['model_path'])
# Out:
# load pretrained model from  ckpt.pt
# [Test] Loss: 0.550
# *************** CYP2C19_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.803  &  0.802  &          0.782  &     0.791  &0.812  &0.786 &0.879 &   0.603 &   0.850
#
# *************** CYP2D6_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.869  &  0.722  &          0.715  &     0.488  &0.956  &0.580 &0.852 &   0.518 &   0.659
#
# *************** CYP3A4_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.777  &  0.761  &          0.764  &     0.667  &0.855  &0.712 &0.860 &   0.535 &   0.806
#
# *************** CYP1A2_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.836  &  0.837  &          0.812  &     0.848  &0.825  &0.830 &0.914 &   0.672 &   0.903
#
# *************** CYP2C9_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.812  &  0.787  &          0.729  &     0.709  &0.865  &0.719 &0.880 &   0.578 &   0.766

# %% [markdown]
# # TEST ATTENTIVEFP MO

# %%
loader_params = {'batch_size': batch_size, 'shuffle': True}
train_loader = get_loader(trains, names, loader_params, 'AttentiveFP')
valid_loader = get_loader(valids, names, loader_params, 'AttentiveFP')

test_params = {'batch_size': batch_size, 'shuffle': False}
test_loader  = get_loader(tests,  names,  test_params,  'AttentiveFP')

# %%
n_layers = 5
graph_feat_size = 300
config_AT = {'model_type': 'AttentiveFP',
          'in_dim': graph_feat_size,
          'n_layers': n_layers,
          'out_dim': len(names),
          'prop_names': names,
          'dropout': dropout,
          'IS_R': IS_R,
          'lr': lr,
          'wd': wd,
          'patience': patience,
          'model_path': 'ckpt_AT.pt'}

print(config_AT)
models = PRED(**config_AT)
models.train(train_loader, valid_loader)

# %%
models.eval(test_loader, config_AT['model_path'])
# Out:
# load pretrained model from  ckpt_AT.pt
# [Test] Loss: 0.480
# *************** CYP2C19_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.835  &  0.837  &          0.801  &     0.853  &0.820  &0.826 &0.909 &   0.671 &   0.889
#
# *************** CYP2D6_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.887  &  0.771  &          0.753  &     0.586  &0.956  &0.659 &0.887 &   0.599 &   0.726
#
# *************** CYP3A4_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.822  &  0.814  &          0.794  &     0.767  &0.861  &0.780 &0.909 &   0.631 &   0.867
#
# *************** CYP1A2_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.878  &  0.876  &          0.895  &     0.840  &0.912  &0.867 &0.944 &   0.756 &   0.941
#
# *************** CYP2C9_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.848  &  0.830  &          0.778  &     0.773  &0.887  &0.775 &0.919 &   0.661 &   0.838

# %% [markdown]
# # Train GIN

# %%
loader_params = {'batch_size': batch_size, 'shuffle': True}
train_loader = get_loader(trains, names, loader_params, 'GIN')
valid_loader = get_loader(valids, names, loader_params, 'GIN')

test_params = {'batch_size': batch_size, 'shuffle': False}
test_loader  = get_loader(tests,  names,  test_params,  'GIN')
# Out:
# --> preparing data loader for model type  GIN
# --> preparing data loader for model type  GIN
# --> preparing data loader for model type  GIN

# %%
config_GIN = {'model_type': 'GIN',
          'in_dim': in_dim,
          'hid_dims': hid_dims,
          'out_dim': len(names),
          'prop_names': names,
          'dropout': dropout,
          'IS_R': IS_R,
          'lr': lr,
          'wd': wd,
          'patience': patience,
          'model_path': 'ckpt_GIN.pt'}

print(config_GIN)
models = PRED(**config_GIN)
models.train(train_loader, valid_loader)
# Out:
# Epoch:27, [Train] Loss: 1.079
# Epoch:27, [Valid] Loss: 0.363
# EarlyStopping counter: 8 out of 10
# Epoch:28, [Train] Loss: 1.083
# Epoch:28, [Valid] Loss: 0.366
# EarlyStopping counter: 9 out of 10
# Epoch:29, [Train] Loss: 1.075
# Epoch:29, [Valid] Loss: 0.364
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 19, min loss: 0.3622

# %%
models.eval(test_loader, config_GIN['model_path'])
# Out:
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  ckpt_GIN.pt
# [Test] Loss: 0.427
# *************** CYP2C19_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.856  &  0.856  &          0.836  &     0.854  &0.858  &0.845 &0.929 &   0.710 &   0.915
#
# *************** CYP2D6_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.888  &  0.783  &          0.741  &     0.615  &0.951  &0.672 &0.904 &   0.609 &   0.760
#
# *************** CYP3A4_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.837  &  0.833  &          0.801  &     0.806  &0.859  &0.804 &0.920 &   0.665 &   0.886
#
# *************** CYP1A2_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.885  &  0.885  &          0.866  &     0.894  &0.877  &0.880 &0.950 &   0.770 &   0.945
#
# *************** CYP2C9_Veith ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.871  &  0.849  &          0.828  &     0.781  &0.917  &0.804 &0.937 &   0.709 &   0.871

# %% [markdown]
# # Regression task test

# %%
names = ['Lipophilicity_AstraZeneca', 'Solubility_AqSolDB']
# 'Caco2_Wang',  always R2 <0 do not know why 'HydrationFreeEnergy_FreeSolv'
# names = ['Caco2_Wang', 'Lipophilicity_AstraZeneca'] + names # ,'Lipophilicity_AstraZeneca'
IS_R = [True] * len(names)
trains, valids, tests = collect_data_10_17(names)

len(trains), len(valids), len(tests), trains

# %%
def scale(trains, valids, tests):
    print('scaling train valid test data set for regression task ')
    dict_scale = {}
    for col in trains.columns:
        if col == 'Drug': pass
        else:
            # print(col)
            min_here = min(trains[col].min(), valids[col].min(), tests[col].min())
            max_here = max(trains[col].max(), valids[col].max(), tests[col].max())
            dict_scale[col] = [min_here, max_here]
            delta_here = max_here - min_here
            trains[col] = (trains[col] - min_here) / delta_here
            valids[col] = (valids[col] - min_here) / delta_here
            tests[col]  = (tests[col]  - min_here) / delta_here

    return trains, valids, tests, dict_scale


# t, v, te = collect_data_10_17(names)
trains, valids, tests, dict_scale = scale(trains, valids, tests)

trains
# Out:
# scaling train valid test data set for regression task
#                                                    Drug  \
# 0               Cn1c(CN2CCN(c3ccc(Cl)cc3)CC2)nc2ccccc21
# 1     COc1cc(OC)c(S(=O)(=O)N2c3ccccc3CCC2C)cc1NC(=O)...
# 2                 COC(=O)[C@H](c1ccccc1Cl)N1CCc2sccc2C1
# 3                 OC1(C#Cc2ccc(-c3ccccc3)cc2)CN2CCC1CC2
# 4     CS(=O)(=O)c1ccc(Oc2ccc(C#C[C@]3(O)CN4CCC3CC4)c...
# ...                                                 ...
# 9816                      CC(C)NCC(O)COc1cccc2[nH]ccc12
# 9817  O=C(O)c1cn(-c2ccc(F)cc2)c2cc(N3CCNCC3)c(F)cc2c1=O
# 9818  C[C@H]1CN(c2c(F)c(N)c3c(=O)c(C(=O)O)cn(C4CC4)c...
# 9819    CC1=C(CC(=O)O)c2cc(F)ccc2/C1=C/c1ccc(S(C)=O)cc1
# 9820                                Cc1ccc(C(C)C)c(O)c1
#
#       Lipophilicity_AstraZeneca  Solubility_AqSolDB
# 0                      0.840000                 NaN
# 1                      0.053333                 NaN
# 2                      0.865000                 NaN
# 3                      0.773333                 NaN
# 4                      0.501667                 NaN
# ...                         ...                 ...
# 9816                        NaN            0.612812
# 9817                        NaN            0.655923
# 9818                        NaN            0.640246
# 9819                        NaN            0.566436
# 9820                        NaN            0.717322
#
# [9821 rows x 3 columns]

# %%
dict_scale
# Out:
# {'Lipophilicity_AstraZeneca': [-1.5, 4.5],
#  'Solubility_AqSolDB': [-13.1719, 2.1376816201]}

# %% [markdown]
# ### MLP

# %%
batch_size = 64
loader_params = {'batch_size': batch_size, 'shuffle': True}
train_loader = get_loader(trains, names, loader_params, 'MLP')
valid_loader = get_loader(valids, names, loader_params, 'MLP')

test_params = {'batch_size': batch_size, 'shuffle': False}
test_loader  = get_loader(tests,  names,  test_params,  'MLP')
# Out:
# --> preparing data loader for model type  MLP
# ---> converting SMILES to MACCS...
# ---> FINISHED
# --> preparing data loader for model type  MLP
# ---> converting SMILES to MACCS...
# ---> FINISHED
# --> preparing data loader for model type  MLP
# ---> converting SMILES to MACCS...
# ---> FINISHED

# %%
in_dim = 167
hid_dims = [256, 32]
dropout = 0
lr = 3e-4
wd = 1e-5
patience = 10

config = {'model_type': 'MLP',
          'in_dim': in_dim,
          'hid_dims': hid_dims,
          'out_dim': len(names),
          'prop_names': names,
          'dropout': dropout,
          'IS_R': IS_R,
          'lr': lr,
          'wd': wd,
          'patience': patience,
          'model_path': 'ckpt.pt',
          'scale_dict': dict_scale}
print(config)
models = PRED(**config)
models.train(train_loader, valid_loader)

# %%
models.eval(test_loader, config['model_path'])
# Out:
# load pretrained model from  ckpt.pt
# [Test] Loss: 0.011
# *************** Lipophilicity_AstraZeneca ***************
# MAE,      MSE,      RMSE,      R2
# & 0.662  &0.737  &0.858  &0.501
# *************** Solubility_AqSolDB ***************
# MAE,      MSE,      RMSE,      R2
# & 0.949  &1.639  &1.280  &0.698

# %% [markdown]
# AttentiveFP MO regression task

# %%
batch_size = 128
loader_params = {'batch_size': batch_size, 'shuffle': True,
                 'drop_last': False, 'num_workers':0}
train_loader = get_loader(trains, names, loader_params, 'AttentiveFP')
valid_loader = get_loader(valids, names, loader_params, 'AttentiveFP')

test_params = {'batch_size': batch_size, 'shuffle': False,
               'drop_last': False, 'num_workers':0}
test_loader  = get_loader(tests,  names,  test_params,  'AttentiveFP')

# %%
n_layers = 5
graph_feat_size = 300
dropout = 0.1
config_AT = {'model_type': 'AttentiveFP',
          'in_dim': graph_feat_size,
          'n_layers': n_layers,
          'out_dim': len(names),
          'prop_names': names,
          'dropout': dropout,
          'IS_R': IS_R,
          'lr': lr,
          'wd': wd,
          'patience': patience,
          'model_path': 'ckpt_AT.pt',
          'scale_dict': dict_scale}

print(config_AT)
models = PRED(**config_AT)
models.train(train_loader, valid_loader)

# %%
models.eval(test_loader, config_AT['model_path'])
# Out:
# load pretrained model from  ckpt_AT.pt
# [Test] Loss: 0.006
# *************** Lipophilicity_AstraZeneca ***************
# MAE,      MSE,      RMSE,      R2
# & 0.453  &0.379  &0.615  &0.744
# *************** Solubility_AqSolDB ***************
# MAE,      MSE,      RMSE,      R2
# & 0.692  &1.012  &1.006  &0.813

# %% [markdown]
# # GIN regression task

# %%
loader_params = {'batch_size': batch_size, 'shuffle': True,
                 'drop_last': False, 'num_workers':0}
train_loader = get_loader(trains, names, loader_params, 'GIN')
valid_loader = get_loader(valids, names, loader_params, 'GIN')

test_params = {'batch_size': batch_size, 'shuffle': False,
               'drop_last': False, 'num_workers':0}
test_loader  = get_loader(tests,  names,  test_params,  'GIN')

config_GIN = {'model_type': 'GIN',
          'in_dim': in_dim,
          'hid_dims': hid_dims,
          'out_dim': len(names),
          'prop_names': names,
          'dropout': dropout,
          'IS_R': IS_R,
          'lr': lr,
          'wd': wd,
          'patience': patience,
          'model_path': 'ckpt_GIN.pt',
          'scale_dict': dict_scale}

print(config_GIN)
models = PRED(**config_GIN)
models.train(train_loader, valid_loader)
# Out:
# Epoch:49, [Train] Loss: 0.057
# Epoch:49, [Valid] Loss: 0.013
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 39, min loss: 0.0109

# %%
models.eval(test_loader, config_GIN['model_path'])
# Out:
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  ckpt_GIN.pt
# [Test] Loss: 0.011
# *************** Lipophilicity_AstraZeneca ***************
# MAE,      MSE,      RMSE,      R2
# & 0.630  &0.626  &0.791  &0.576
# *************** Solubility_AqSolDB ***************
# MAE,      MSE,      RMSE,      R2
# & 1.069  &1.857  &1.363  &0.658

# %% [markdown]
# BBB F, Pgp HIA PAMPA

# %%
names = ['BBB_Martins', 'Bioavailability_Ma', 'Pgp_Broccatelli', 'HIA_Hou','PAMPA_NCATS']

names = ['BBB_Martins', 'Pgp_Broccatelli', 'HIA_Hou']
IS_R = [False] * len(names)
trains, valids, tests = collect_data_10_17(names)

# %%
import pandas as pd
def count_(df:pd.DataFrame):
    for col in df.columns:
        if col != 'Drug':
            try:
                ones = df[col].value_counts()[1]
                zero = df[col].value_counts()[0]
            except: ones = 'Nan'; zero = 'Nan'
            print(col, f'\t 0: {zero} | 1: {ones}')
    print()

count_(trains), count_(valids), count_(tests)
# Out:
# BBB_Martins 	 0: 325 | 1: 1096
# Pgp_Broccatelli 	 0: 392 | 1: 461
# HIA_Hou 	 0: 53 | 1: 353
#
# BBB_Martins 	 0: 51 | 1: 152
# Pgp_Broccatelli 	 0: 56 | 1: 66
# HIA_Hou 	 0: 6 | 1: 52
#
# BBB_Martins 	 0: 103 | 1: 303
# Pgp_Broccatelli 	 0: 121 | 1: 123
# HIA_Hou 	 0: 19 | 1: 97
# (None, None, None)

# %%
batch_size = 64
loader_params = {'batch_size': batch_size, 'shuffle': True,
                 'drop_last':False, 'num_workers': 0}
train_loader = get_loader(trains, names, loader_params, 'MLP')
valid_loader = get_loader(valids, names, loader_params, 'MLP')

test_params = {'batch_size': batch_size, 'shuffle': False,
               'drop_last':False, 'num_workers': 0}
test_loader  = get_loader(tests,  names,  test_params,  'MLP')

# %%
in_dim = 167
hid_dims = [256, 64]
dropout = 0.
lr = 5e-4
wd = 1e-5
patience = 10

config = {'model_type': 'MLP',
          'in_dim': in_dim,
          'hid_dims': hid_dims,
          'out_dim': len(names),
          'prop_names': names,
          'dropout': dropout,
          'IS_R': IS_R,
          'lr': lr,
          'wd': wd,
          'patience': patience,
          'model_path': 'ckpt.pt'}
print(config)
models = PRED(**config)
models.train(train_loader, valid_loader)

# %%
models.eval(test_loader, config['model_path'])
# Out:
# load pretrained model from  ckpt.pt
# [Test] Loss: 0.393
# *************** BBB_Martins ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.855  &  0.755  &          0.863  &     0.957  &0.553  &0.908 &0.881 &   0.588 &   0.945
#
# *************** Pgp_Broccatelli ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.783  &  0.783  &          0.769  &     0.813  &0.752  &0.791 &0.852 &   0.566 &   0.876
#
# *************** HIA_Hou ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.931  &  0.811  &          0.932  &     0.990  &0.632  &0.960 &0.965 &   0.729 &   0.993

# %% [markdown]
# AttentiveFP

# %%
train_loader = get_loader(trains, names, loader_params, 'AttentiveFP')
valid_loader = get_loader(valids, names, loader_params, 'AttentiveFP')
test_loader  = get_loader(tests,  names,  test_params,  'AttentiveFP')

# %%
n_layers = 5
graph_feat_size = 300
lr = 5e-4
wd = 1e-5
config_AT = {'model_type': 'AttentiveFP',
          'in_dim': graph_feat_size,
          'n_layers': n_layers,
          'out_dim': len(names),
          'prop_names': names,
          'dropout': dropout,
          'IS_R': IS_R,
          'lr': lr,
          'wd': wd,
          'patience': patience,
          'model_path': 'ckpt_AT.pt'}

print(config_AT)
models = PRED(**config_AT)
models.train(train_loader, valid_loader)

# %%
models.eval(test_loader, config_AT['model_path'])
# Out:
# load pretrained model from  ckpt_AT.pt
# [Test] Loss: 0.295
# *************** BBB_Martins ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.892  &  0.849  &          0.922  &     0.934  &0.765  &0.928 &0.905 &   0.708 &   0.956
#
# *************** Pgp_Broccatelli ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.869  &  0.868  &          0.879  &     0.879  &0.857  &0.879 &0.929 &   0.736 &   0.912
#
# *************** HIA_Hou ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.948  &  0.824  &          0.962  &     0.981  &0.667  &0.971 &0.994 &   0.703 &   0.999

# %% [markdown]
# # GIN

# %%
train_loader = get_loader(trains, names, loader_params, 'GIN')
valid_loader = get_loader(valids, names, loader_params, 'GIN')
test_loader  = get_loader(tests,  names,  test_params,  'GIN')

dropout = 0.3

config_GIN = {'model_type': 'GIN',
          'in_dim': in_dim,
          'hid_dims': hid_dims,
          'out_dim': len(names),
          'prop_names': names,
          'dropout': dropout,
          'IS_R': IS_R,
          'lr': lr,
          'wd': wd,
          'patience': patience,
          'model_path': 'ckpt_GIN.pt'}

print(config_GIN)
models = PRED(**config_GIN)
models.train(train_loader, valid_loader)

# %%
models.eval(test_loader, config_GIN['model_path'])
# Out:
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  ckpt_GIN.pt
# [Test] Loss: 0.358
# *************** BBB_Martins ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.867  &  0.786  &          0.881  &     0.950  &0.621  &0.914 &0.919 &   0.629 &   0.969
#
# *************** Pgp_Broccatelli ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.795  &  0.795  &          0.807  &     0.780  &0.810  &0.793 &0.889 &   0.591 &   0.910
#
# *************** HIA_Hou ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.948  &  0.863  &          0.950  &     0.990  &0.737  &0.970 &0.967 &   0.801 &   0.993

# %%
models.eval(test_loader, config_GIN['model_path'])
# Out:
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  ckpt_GIN.pt
# [Test] Loss: 0.380
# *************** BBB_Martins ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.867  &  0.789  &          0.883  &     0.947  &0.631  &0.914 &0.910 &   0.630 &   0.963
#
# *************** Pgp_Broccatelli ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.820  &  0.820  &          0.826  &     0.813  &0.826  &0.820 &0.892 &   0.639 &   0.911
#
# *************** HIA_Hou ***************
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.948  &  0.884  &          0.960  &     0.979  &0.789  &0.969 &0.984 &   0.805 &   0.997

# %% [markdown]
# # MIX regression and classification

# %%
names = ['LD50_Zhu', 'hERG_Karim', 'AMES']
IS_R = [True, False, False]
trains, valids, tests = collect_data_10_17(names)
trains, valids, tests, dict_scale = scale(trains, valids, tests)

trains
# Out:
# ['lipophilicity_astrazeneca', 'solubility_aqsoldb', 'hydrationfreeenergy_freesolv', 'caco2_wang', 'pampa_ncats', 'approved_pampa_ncats', 'hia_hou', 'pgp_broccatelli', 'bioavailability_ma', 'vdss_lombardo', 'cyp2c19_veith', 'cyp2d6_veith', 'cyp3a4_veith', 'cyp1a2_veith', 'cyp2c9_veith', 'cyp2c9_substrate_carbonmangels', 'cyp2d6_substrate_carbonmangels', 'cyp3a4_substrate_carbonmangels', 'bbb_martins', 'ppbr_az', 'half_life_obach', 'clearance_hepatocyte_az', 'clearance_microsome_az']
# Found local copy...
# Loading...
# Done!
# ['lipophilicity_astrazeneca', 'solubility_aqsoldb', 'hydrationfreeenergy_freesolv', 'caco2_wang', 'pampa_ncats', 'approved_pampa_ncats', 'hia_hou', 'pgp_broccatelli', 'bioavailability_ma', 'vdss_lombardo', 'cyp2c19_veith', 'cyp2d6_veith', 'cyp3a4_veith', 'cyp1a2_veith', 'cyp2c9_veith', 'cyp2c9_substrate_carbonmangels', 'cyp2d6_substrate_carbonmangels', 'cyp3a4_substrate_carbonmangels', 'bbb_martins', 'ppbr_az', 'half_life_obach', 'clearance_hepatocyte_az', 'clearance_microsome_az']
# Found local copy...
# Loading...
# Done!
# ['lipophilicity_astrazeneca', 'solubility_aqsoldb', 'hydrationfreeenergy_freesolv', 'caco2_wang', 'pampa_ncats', 'approved_pampa_ncats', 'hia_hou', 'pgp_broccatelli', 'bioavailability_ma', 'vdss_lombardo', 'cyp2c19_veith', 'cyp2d6_veith', 'cyp3a4_veith', 'cyp1a2_veith', 'cyp2c9_veith', 'cyp2c9_substrate_carbonmangels', 'cyp2d6_substrate_carbonmangels', 'cyp3a4_substrate_carbonmangels', 'bbb_martins', 'ppbr_az', 'half_life_obach', 'clearance_hepatocyte_az', 'clearance_microsome_az']
# Found local copy...
# Loading...
# Done!
# *************** LD50_Zhu ***************
# *************** hERG_Karim ***************
# *************** AMES ***************
# scaling train valid test data set for regression task
#                                                     Drug  LD50_Zhu  \
# 0                                              BrC(Br)Br  0.254597
# 1                                                  C=CBr  0.253365
# 2                  Brc1ccc(-c2ccc(Br)c(Br)c2Br)c(Br)c1Br  0.171374
# 3                                      S=C=Nc1ccc(Br)cc1  0.291185
# 4                                             Brc1ccccc1  0.199810
# ...                                                  ...       ...
# 18923  CCN(CC)c1ccc2c(c1)Oc1cc(N(CC)CC)ccc1C2c1ccccc1...       NaN
# 18924  CCC(CCC(C)C1CCC2C3CC=C4CC(O)CCC4(C)C3CCC12C)C(C)C       NaN
# 18925                                   CCCCCCCCCCCCOCCO       NaN
# 18926                        C=C(C)C1CC=C(C)C(OC(C)=O)C1       NaN
# 18927  CC/N=c1\cc2oc3cc(NCC)c(C)cc3c(-c3ccccc3C(=O)OC...       NaN
#
#        hERG_Karim  AMES
# 0             NaN   NaN
# 1             NaN   1.0
# 2             NaN   NaN
# 3             NaN   NaN
# 4             NaN   0.0
# ...           ...   ...
# 18923         NaN   1.0
# 18924         NaN   0.0
# 18925         NaN   0.0
# 18926         NaN   0.0
# 18927         NaN   0.0
#
# [18928 rows x 4 columns]

# %%
batch_size = 64
loader_params = {'batch_size': batch_size, 'shuffle': True,
                 'drop_last': False, 'num_workers': 0}
train_loader = get_loader(trains, names, loader_params, 'MLP')
valid_loader = get_loader(valids, names, loader_params, 'MLP')

test_params = {'batch_size': batch_size, 'shuffle': False,
               'drop_last': False, 'num_workers': 0}
test_loader  = get_loader(tests,  names,  test_params,  'MLP')

# %%
in_dim = 167
hid_dims = [256]
dropout = 0.1
lr = 3e-4
wd = 1e-5
patience = 10

config = {'model_type': 'MLP',
          'in_dim': in_dim,
          'hid_dims': hid_dims,
          'out_dim': len(names),
          'prop_names': names,
          'dropout': dropout,
          'IS_R': IS_R,
          'lr': lr,
          'wd': wd,
          'patience': patience,
          'model_path': 'ckpt.pt',
          'scale_dict': None}
print(config)
models = PRED(**config)
models.train(train_loader, valid_loader)

# %%
models.eval(test_loader, config['model_path'])
# Out:
# load pretrained model from  ckpt.pt
# [Test] Loss: 0.448
# *************** LD50_Zhu ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.483  &0.420  &0.648  &0.530
# *************** hERG_Karim ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.785  &  0.785  &          0.813  &     0.740  &0.831  &0.775 &0.870 &   0.573 &   0.877
#
# *************** AMES ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.812  &  0.805  &          0.797  &     0.883  &0.726  &0.838 &0.883 &   0.622 &   0.893

# %%
models.eval(test_loader, config['model_path'])
# Out:
# load pretrained model from  ckpt.pt
# [Test] Loss: 0.327
# *************** LD50_Zhu ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.528  &0.500  &0.707  &0.441
# *************** hERG_Karim ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.799  &  0.799  &          0.785  &     0.824  &0.775  &0.804 &0.878 &   0.599 &   0.886
#
# *************** AMES ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.816  &  0.812  &          0.819  &     0.852  &0.772  &0.835 &0.887 &   0.627 &   0.895

# %% [markdown]
# # MIX TASK AttentiveFP

# %%
train_loader = get_loader(trains, names, loader_params, 'AttentiveFP')
valid_loader = get_loader(valids, names, loader_params, 'AttentiveFP')
test_loader  = get_loader(tests,  names,  test_params,  'AttentiveFP')
# Out:
# [Parallel(n_jobs=6)]: Done 4468 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=6)]: Done 5551 out of 5551 | elapsed:    6.3s finished

# %%
n_layers = 5
graph_feat_size = 300
dropout = 0.3
config_AT = {'model_type': 'AttentiveFP',
          'in_dim': graph_feat_size,
          'n_layers': n_layers,
          'out_dim': len(names),
          'prop_names': names,
          'dropout': dropout,
          'IS_R': IS_R,
          'lr': lr,
          'wd': wd,
          'patience': patience,
          'model_path': 'ckpt_AT.pt',
          'scale_dict': None}

print(config_AT)
models = PRED(**config_AT)
models.train(train_loader, valid_loader)
# Out:
# Epoch:37, [Train] Loss: 0.323
# Epoch:37, [Valid] Loss: 0.422
# EarlyStopping counter: 9 out of 10
# Epoch:38, [Train] Loss: 0.320
# Epoch:38, [Valid] Loss: 0.425
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 28, min loss: 0.4198

# %%
# No scale result
models.eval(test_loader, config_AT['model_path'])
# Out:
# load pretrained model from  ckpt_AT.pt
# [Test] Loss: 0.424
# *************** LD50_Zhu ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.442  &0.369  &0.607  &0.587
# *************** hERG_Karim ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.794  &  0.794  &          0.843  &     0.721  &0.866  &0.777 &0.885 &   0.593 &   0.885
#
# *************** AMES ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.814  &  0.807  &          0.802  &     0.877  &0.737  &0.838 &0.886 &   0.624 &   0.897

# %%
models.eval(test_loader, config_AT['model_path'])
# Out:
# load pretrained model from  ckpt_AT.pt
# [Test] Loss: 0.336
# *************** LD50_Zhu ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.543  &0.505  &0.711  &0.435
# *************** hERG_Karim ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.794  &  0.794  &          0.837  &     0.730  &0.858  &0.780 &0.884 &   0.593 &   0.881
#
# *************** AMES ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.809  &  0.808  &          0.829  &     0.821  &0.795  &0.825 &0.877 &   0.615 &   0.889

# %% [markdown]
# # GIN mixed task

# %%
train_loader = get_loader(trains, names, loader_params, 'GIN')
valid_loader = get_loader(valids, names, loader_params, 'GIN')
test_loader  = get_loader(tests,  names,  test_params,  'GIN')
# Out:
# --> preparing data loader for model type  GIN
# --> preparing data loader for model type  GIN
# --> preparing data loader for model type  GIN

# %%
config_GIN = {'model_type': 'GIN',
          'in_dim': in_dim,
          'hid_dims': hid_dims,
          'out_dim': len(names),
          'prop_names': names,
          'dropout': dropout,
          'IS_R': IS_R,
          'lr': lr,
          'wd': wd,
          'patience': patience,
          'model_path': 'ckpt_GIN.pt',
          'scale_dict': dict_scale}

print(config_GIN)
models = PRED(**config_GIN)
models.train(train_loader, valid_loader)

# %%
# scaling
models.eval(test_loader, config_GIN['model_path'])
# Out:
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  ckpt_GIN.pt
# [Test] Loss: 0.311
# *************** LD50_Zhu ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.903  &1.302  &1.141  &-0.457
# *************** hERG_Karim ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.809  &  0.809  &          0.814  &     0.801  &0.817  &0.808 &0.893 &   0.619 &   0.898
#
# *************** AMES ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.832  &  0.832  &          0.858  &     0.831  &0.833  &0.844 &0.896 &   0.662 &   0.912

# %%
# no scaling
models.eval(test_loader, config_GIN['model_path'])
# Out:
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  ckpt_GIN.pt
# [Test] Loss: 0.563
# *************** LD50_Zhu ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.723  &0.837  &0.915  &0.063
# *************** hERG_Karim ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.783  &  0.783  &          0.788  &     0.773  &0.793  &0.780 &0.870 &   0.566 &   0.873
#
# *************** AMES ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.810  &  0.807  &          0.821  &     0.835  &0.780  &0.828 &0.885 &   0.615 &   0.902

# %%
ls
# Out:
# drive/  sample_data/

# %%
name_reg = ['Half_Life_Obach', 'Clearance_Hepatocyte_AZ', 'VDss_Lombardo',
         'PPBR_AZ', 'Caco2_Wang', 'Lipophilicity_AstraZeneca',
         'HydrationFreeEnergy_FreeSolv', 'Solubility_AqSolDB']


name_cls = ['BBB_Martins', 'Bioavailability_Ma', 'Pgp_Broccatelli',
             'HIA_Hou', 'PAMPA_NCATS']

name_met_cls = ['CYP2C19_Veith', 'CYP2D6_Veith', 'CYP3A4_Veith',
                       'CYP1A2_Veith', 'CYP2C9_Veith',
                       'CYP2C9_Substrate_CarbonMangels',
                       'CYP2D6_Substrate_CarbonMangels',
                       'CYP3A4_Substrate_CarbonMangels']

name_tox_reg = ['LD50_Zhu']

name_tox_cls = ['hERG_Karim', 'AMES']

# %%
names_reg = name_reg + name_tox_reg
names_cls = name_cls + name_met_cls + name_tox_cls
names_cls
# Out:
# ['BBB_Martins',
#  'Bioavailability_Ma',
#  'Pgp_Broccatelli',
#  'HIA_Hou',
#  'PAMPA_NCATS',
#  'CYP2C19_Veith',
#  'CYP2D6_Veith',
#  'CYP3A4_Veith',
#  'CYP1A2_Veith',
#  'CYP2C9_Veith',
#  'CYP2C9_Substrate_CarbonMangels',
#  'CYP2D6_Substrate_CarbonMangels',
#  'CYP3A4_Substrate_CarbonMangels',
#  'hERG_Karim',
#  'AMES']

# %%
model_type = 'GIN'
dropout = 0.3
for name in names_reg[4:]:
    names = [name]
    IS_R = True
    trains, valids, tests = collect_data_10_17(names)
    trains, valids, tests, dict_scale = scale(trains, valids, tests)
    train_loader = get_loader(trains, names, loader_params, model_type)
    valid_loader = get_loader(valids, names, loader_params, model_type)

    model_name = f'{name}_{model_type}.pt'
    # print(model_name)
    config = {'model_type': model_type, 'scale_dict': dict_scale,
              'in_dim': 256, 'hid_dims': [128, 64], 'out_dim': len(names),
              'prop_names': names, 'dropout': dropout, 'IS_R': IS_R,
              'lr': 3e-4, 'wd': 1e-5, 'patience': 10, 'model_path': model_name}

    models = PRED(**config)
    models.train(train_loader, valid_loader)
# Out:
# Found local copy...
# Loading...
# Done!
# *************** Caco2_Wang ***************
# scaling train valid test data set for regression task
# --> preparing data loader for model type  GIN
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Epoch:0, [Train] Loss: 0.298
# Epoch:0, [Valid] Loss: 0.266
# prev min loss inf, now loss 0.266 | save model at epoch: 0
# *************** Caco2_Wang ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 2.089  &4.812  &2.194  &-9.335
#
# Epoch:1, [Train] Loss: 0.217
# Epoch:1, [Valid] Loss: 0.164
# prev min loss 0.266, now loss 0.164 | save model at epoch: 1
# *************** Caco2_Wang ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 1.600  &2.957  &1.720  &-5.350
#
# Epoch:2, [Train] Loss: 0.157
# Epoch:2, [Valid] Loss: 0.058
# prev min loss 0.164, now loss 0.058 | save model at epoch: 2
# *************** Caco2_Wang ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.896  &1.049  &1.024  &-1.253
#
# Epoch:3, [Train] Loss: 0.129
# Epoch:3, [Valid] Loss: 0.068
# EarlyStopping counter: 1 out of 10
# Epoch:4, [Train] Loss: 0.118
# Epoch:4, [Valid] Loss: 0.073
# EarlyStopping counter: 2 out of 10
# Epoch:5, [Train] Loss: 0.130
# Epoch:5, [Valid] Loss: 0.057
# prev min loss 0.058, now loss 0.057 | save model at epoch: 5
# *************** Caco2_Wang ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.895  &1.023  &1.012  &-1.197
#
# Epoch:6, [Train] Loss: 0.144
# Epoch:6, [Valid] Loss: 0.060
# EarlyStopping counter: 1 out of 10
# Epoch:7, [Train] Loss: 0.132
# Epoch:7, [Valid] Loss: 0.062
# EarlyStopping counter: 2 out of 10
# Epoch:8, [Train] Loss: 0.137
# Epoch:8, [Valid] Loss: 0.052
# prev min loss 0.057, now loss 0.052 | save model at epoch: 8
# *************** Caco2_Wang ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.866  &0.944  &0.971  &-1.026
#
# Epoch:9, [Train] Loss: 0.125
# Epoch:9, [Valid] Loss: 0.058
# EarlyStopping counter: 1 out of 10
# Epoch:10, [Train] Loss: 0.136
# Epoch:10, [Valid] Loss: 0.057
# EarlyStopping counter: 2 out of 10
# Epoch:11, [Train] Loss: 0.138
# Epoch:11, [Valid] Loss: 0.057
# EarlyStopping counter: 3 out of 10
# Epoch:12, [Train] Loss: 0.128
# Epoch:12, [Valid] Loss: 0.054
# EarlyStopping counter: 4 out of 10
# Epoch:13, [Train] Loss: 0.120
# Epoch:13, [Valid] Loss: 0.056
# EarlyStopping counter: 5 out of 10
# Epoch:14, [Train] Loss: 0.123
# Epoch:14, [Valid] Loss: 0.053
# EarlyStopping counter: 6 out of 10
# Epoch:15, [Train] Loss: 0.116
# Epoch:15, [Valid] Loss: 0.062
# EarlyStopping counter: 7 out of 10
# Epoch:16, [Train] Loss: 0.122
# Epoch:16, [Valid] Loss: 0.053
# EarlyStopping counter: 8 out of 10
# Epoch:17, [Train] Loss: 0.130
# Epoch:17, [Valid] Loss: 0.055
# EarlyStopping counter: 9 out of 10
# Epoch:18, [Train] Loss: 0.128
# Found local copy...
# Loading...
# Done!
# Epoch:18, [Valid] Loss: 0.054
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 8, min loss: 0.0522
#
# *************** Lipophilicity_AstraZeneca ***************
# scaling train valid test data set for regression task
# --> preparing data loader for model type  GIN
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Epoch:0, [Train] Loss: 0.255
# Epoch:0, [Valid] Loss: 0.089
# prev min loss inf, now loss 0.089 | save model at epoch: 0
# *************** Lipophilicity_AstraZeneca ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 1.555  &3.208  &1.791  &-1.232
#
# Epoch:1, [Train] Loss: 0.150
# Epoch:1, [Valid] Loss: 0.063
# prev min loss 0.089, now loss 0.063 | save model at epoch: 1
# *************** Lipophilicity_AstraZeneca ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 1.291  &2.251  &1.500  &-0.566
#
# Epoch:2, [Train] Loss: 0.145
# Epoch:2, [Valid] Loss: 0.056
# prev min loss 0.063, now loss 0.056 | save model at epoch: 2
# *************** Lipophilicity_AstraZeneca ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 1.216  &2.017  &1.420  &-0.403
#
# Epoch:3, [Train] Loss: 0.139
# Epoch:3, [Valid] Loss: 0.054
# prev min loss 0.056, now loss 0.054 | save model at epoch: 3
# *************** Lipophilicity_AstraZeneca ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 1.195  &1.944  &1.394  &-0.353
#
# Epoch:4, [Train] Loss: 0.145
# Epoch:4, [Valid] Loss: 0.054
# EarlyStopping counter: 1 out of 10
# Epoch:5, [Train] Loss: 0.151
# Epoch:5, [Valid] Loss: 0.061
# EarlyStopping counter: 2 out of 10
# Epoch:6, [Train] Loss: 0.141
# Epoch:6, [Valid] Loss: 0.059
# EarlyStopping counter: 3 out of 10
# Epoch:7, [Train] Loss: 0.139
# Epoch:7, [Valid] Loss: 0.056
# EarlyStopping counter: 4 out of 10
# Epoch:8, [Train] Loss: 0.137
# Epoch:8, [Valid] Loss: 0.061
# EarlyStopping counter: 5 out of 10
# Epoch:9, [Train] Loss: 0.144
# Epoch:9, [Valid] Loss: 0.053
# prev min loss 0.054, now loss 0.053 | save model at epoch: 9
# *************** Lipophilicity_AstraZeneca ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 1.188  &1.897  &1.377  &-0.320
#
# Epoch:10, [Train] Loss: 0.150
# Epoch:10, [Valid] Loss: 0.061
# EarlyStopping counter: 1 out of 10
# Epoch:11, [Train] Loss: 0.141
# Epoch:11, [Valid] Loss: 0.059
# EarlyStopping counter: 2 out of 10
# Epoch:12, [Train] Loss: 0.145
# Epoch:12, [Valid] Loss: 0.056
# EarlyStopping counter: 3 out of 10
# Epoch:13, [Train] Loss: 0.141
# Epoch:13, [Valid] Loss: 0.056
# EarlyStopping counter: 4 out of 10
# Epoch:14, [Train] Loss: 0.142
# Epoch:14, [Valid] Loss: 0.070
# EarlyStopping counter: 5 out of 10
# Epoch:15, [Train] Loss: 0.138
# Epoch:15, [Valid] Loss: 0.061
# EarlyStopping counter: 6 out of 10
# Epoch:16, [Train] Loss: 0.136
# Epoch:16, [Valid] Loss: 0.063
# EarlyStopping counter: 7 out of 10
# Epoch:17, [Train] Loss: 0.140
# Epoch:17, [Valid] Loss: 0.048
# prev min loss 0.053, now loss 0.048 | save model at epoch: 17
# *************** Lipophilicity_AstraZeneca ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 1.151  &1.746  &1.321  &-0.215
#
# Epoch:18, [Train] Loss: 0.138
# Epoch:18, [Valid] Loss: 0.058
# EarlyStopping counter: 1 out of 10
# Epoch:19, [Train] Loss: 0.141
# Epoch:19, [Valid] Loss: 0.060
# EarlyStopping counter: 2 out of 10
# Epoch:20, [Train] Loss: 0.140
# Epoch:20, [Valid] Loss: 0.062
# EarlyStopping counter: 3 out of 10
# Epoch:21, [Train] Loss: 0.138
# Epoch:21, [Valid] Loss: 0.061
# EarlyStopping counter: 4 out of 10
# Epoch:22, [Train] Loss: 0.140
# Epoch:22, [Valid] Loss: 0.056
# EarlyStopping counter: 5 out of 10
# Epoch:23, [Train] Loss: 0.143
# Epoch:23, [Valid] Loss: 0.065
# EarlyStopping counter: 6 out of 10
# Epoch:24, [Train] Loss: 0.146
# Epoch:24, [Valid] Loss: 0.058
# EarlyStopping counter: 7 out of 10
# Epoch:25, [Train] Loss: 0.136
# Epoch:25, [Valid] Loss: 0.069
# EarlyStopping counter: 8 out of 10
# Epoch:26, [Train] Loss: 0.135
# Epoch:26, [Valid] Loss: 0.061
# EarlyStopping counter: 9 out of 10
# Epoch:27, [Train] Loss: 0.135
# Found local copy...
# Loading...
# Done!
# Epoch:27, [Valid] Loss: 0.061
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 17, min loss: 0.0485
#
# *************** HydrationFreeEnergy_FreeSolv ***************
# scaling train valid test data set for regression task
# --> preparing data loader for model type  GIN
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Epoch:0, [Train] Loss: 0.451
# Epoch:0, [Valid] Loss: 0.376
# prev min loss inf, now loss 0.376 | save model at epoch: 0
# *************** HydrationFreeEnergy_FreeSolv ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 17.389  &314.399  &17.731  &-25.667
#
# Epoch:1, [Train] Loss: 0.371
# Epoch:1, [Valid] Loss: 0.283
# prev min loss 0.376, now loss 0.283 | save model at epoch: 1
# *************** HydrationFreeEnergy_FreeSolv ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 14.959  &236.360  &15.374  &-19.048
#
# Epoch:2, [Train] Loss: 0.293
# Epoch:2, [Valid] Loss: 0.148
# prev min loss 0.283, now loss 0.148 | save model at epoch: 2
# *************** HydrationFreeEnergy_FreeSolv ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 10.478  &123.591  &11.117  &-9.483
#
# Epoch:3, [Train] Loss: 0.222
# Epoch:3, [Valid] Loss: 0.054
# prev min loss 0.148, now loss 0.054 | save model at epoch: 3
# *************** HydrationFreeEnergy_FreeSolv ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 5.515  &44.914  &6.702  &-2.810
#
# Epoch:4, [Train] Loss: 0.225
# Epoch:4, [Valid] Loss: 0.052
# prev min loss 0.054, now loss 0.052 | save model at epoch: 4
# *************** HydrationFreeEnergy_FreeSolv ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 5.643  &43.093  &6.565  &-2.655
#
# Epoch:5, [Train] Loss: 0.186
# Epoch:5, [Valid] Loss: 0.067
# EarlyStopping counter: 1 out of 10
# Epoch:6, [Train] Loss: 0.202
# Epoch:6, [Valid] Loss: 0.052
# EarlyStopping counter: 2 out of 10
# Epoch:7, [Train] Loss: 0.187
# Epoch:7, [Valid] Loss: 0.042
# prev min loss 0.052, now loss 0.042 | save model at epoch: 7
# *************** HydrationFreeEnergy_FreeSolv ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 5.454  &35.257  &5.938  &-1.990
#
# Epoch:8, [Train] Loss: 0.147
# Epoch:8, [Valid] Loss: 0.051
# EarlyStopping counter: 1 out of 10
# Epoch:9, [Train] Loss: 0.160
# Epoch:9, [Valid] Loss: 0.050
# EarlyStopping counter: 2 out of 10
# Epoch:10, [Train] Loss: 0.176
# Epoch:10, [Valid] Loss: 0.044
# EarlyStopping counter: 3 out of 10
# Epoch:11, [Train] Loss: 0.189
# Epoch:11, [Valid] Loss: 0.043
# EarlyStopping counter: 4 out of 10
# Epoch:12, [Train] Loss: 0.184
# Epoch:12, [Valid] Loss: 0.042
# prev min loss 0.042, now loss 0.042 | save model at epoch: 12
# *************** HydrationFreeEnergy_FreeSolv ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 5.546  &35.133  &5.927  &-1.980
#
# Epoch:13, [Train] Loss: 0.149
# Epoch:13, [Valid] Loss: 0.042
# EarlyStopping counter: 1 out of 10
# Epoch:14, [Train] Loss: 0.187
# Epoch:14, [Valid] Loss: 0.043
# EarlyStopping counter: 2 out of 10
# Epoch:15, [Train] Loss: 0.174
# Epoch:15, [Valid] Loss: 0.040
# prev min loss 0.042, now loss 0.040 | save model at epoch: 15
# *************** HydrationFreeEnergy_FreeSolv ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 5.385  &33.209  &5.763  &-1.817
#
# Epoch:16, [Train] Loss: 0.193
# Epoch:16, [Valid] Loss: 0.045
# EarlyStopping counter: 1 out of 10
# Epoch:17, [Train] Loss: 0.171
# Epoch:17, [Valid] Loss: 0.047
# EarlyStopping counter: 2 out of 10
# Epoch:18, [Train] Loss: 0.190
# Epoch:18, [Valid] Loss: 0.044
# EarlyStopping counter: 3 out of 10
# Epoch:19, [Train] Loss: 0.157
# Epoch:19, [Valid] Loss: 0.043
# EarlyStopping counter: 4 out of 10
# Epoch:20, [Train] Loss: 0.173
# Epoch:20, [Valid] Loss: 0.047
# EarlyStopping counter: 5 out of 10
# Epoch:21, [Train] Loss: 0.195
# Epoch:21, [Valid] Loss: 0.047
# EarlyStopping counter: 6 out of 10
# Epoch:22, [Train] Loss: 0.164
# Epoch:22, [Valid] Loss: 0.041
# EarlyStopping counter: 7 out of 10
# Epoch:23, [Train] Loss: 0.186
# Epoch:23, [Valid] Loss: 0.045
# EarlyStopping counter: 8 out of 10
# Epoch:24, [Train] Loss: 0.171
# Epoch:24, [Valid] Loss: 0.043
# EarlyStopping counter: 9 out of 10
# Epoch:25, [Train] Loss: 0.172
# Epoch:25, [Valid] Loss: 0.039
# prev min loss 0.040, now loss 0.039 | save model at epoch: 25
# *************** HydrationFreeEnergy_FreeSolv ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 5.408  &32.933  &5.739  &-1.793
#
# Epoch:26, [Train] Loss: 0.158
# Epoch:26, [Valid] Loss: 0.044
# EarlyStopping counter: 1 out of 10
# Epoch:27, [Train] Loss: 0.178
# Epoch:27, [Valid] Loss: 0.038
# prev min loss 0.039, now loss 0.038 | save model at epoch: 27
# *************** HydrationFreeEnergy_FreeSolv ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 5.325  &31.774  &5.637  &-1.695
#
# Epoch:28, [Train] Loss: 0.194
# Epoch:28, [Valid] Loss: 0.043
# EarlyStopping counter: 1 out of 10
# Epoch:29, [Train] Loss: 0.170
# Epoch:29, [Valid] Loss: 0.041
# EarlyStopping counter: 2 out of 10
# Epoch:30, [Train] Loss: 0.171
# Epoch:30, [Valid] Loss: 0.042
# EarlyStopping counter: 3 out of 10
# Epoch:31, [Train] Loss: 0.176
# Epoch:31, [Valid] Loss: 0.042
# EarlyStopping counter: 4 out of 10
# Epoch:32, [Train] Loss: 0.174
# Epoch:32, [Valid] Loss: 0.043
# EarlyStopping counter: 5 out of 10
# Epoch:33, [Train] Loss: 0.192
# Epoch:33, [Valid] Loss: 0.040
# EarlyStopping counter: 6 out of 10
# Epoch:34, [Train] Loss: 0.193
# Epoch:34, [Valid] Loss: 0.046
# EarlyStopping counter: 7 out of 10
# Epoch:35, [Train] Loss: 0.162
# Epoch:35, [Valid] Loss: 0.043
# EarlyStopping counter: 8 out of 10
# Epoch:36, [Train] Loss: 0.196
# Epoch:36, [Valid] Loss: 0.042
# EarlyStopping counter: 9 out of 10
# Found local copy...
# Loading...
# Done!
# Epoch:37, [Train] Loss: 0.164
# Epoch:37, [Valid] Loss: 0.043
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 27, min loss: 0.0380
#
# *************** Solubility_AqSolDB ***************
# scaling train valid test data set for regression task
# --> preparing data loader for model type  GIN
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Epoch:0, [Train] Loss: 0.192
# Epoch:0, [Valid] Loss: 0.048
# prev min loss inf, now loss 0.048 | save model at epoch: 0
# *************** Solubility_AqSolDB ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 3.018  &11.217  &3.349  &-1.114
#
# Epoch:1, [Train] Loss: 0.150
# Epoch:1, [Valid] Loss: 0.045
# prev min loss 0.048, now loss 0.045 | save model at epoch: 1
# *************** Solubility_AqSolDB ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 2.939  &10.525  &3.244  &-0.983
#
# Epoch:2, [Train] Loss: 0.153
# Epoch:2, [Valid] Loss: 0.052
# EarlyStopping counter: 1 out of 10
# Epoch:3, [Train] Loss: 0.150
# Epoch:3, [Valid] Loss: 0.043
# prev min loss 0.045, now loss 0.043 | save model at epoch: 3
# *************** Solubility_AqSolDB ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 2.859  &10.013  &3.164  &-0.887
#
# Epoch:4, [Train] Loss: 0.154
# Epoch:4, [Valid] Loss: 0.048
# EarlyStopping counter: 1 out of 10
# Epoch:5, [Train] Loss: 0.152
# Epoch:5, [Valid] Loss: 0.046
# EarlyStopping counter: 2 out of 10
# Epoch:6, [Train] Loss: 0.148
# Epoch:6, [Valid] Loss: 0.046
# EarlyStopping counter: 3 out of 10
# Epoch:7, [Train] Loss: 0.149
# Epoch:7, [Valid] Loss: 0.038
# prev min loss 0.043, now loss 0.038 | save model at epoch: 7
# *************** Solubility_AqSolDB ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 2.687  &8.969  &2.995  &-0.690
#
# Epoch:8, [Train] Loss: 0.148
# Epoch:8, [Valid] Loss: 0.041
# EarlyStopping counter: 1 out of 10
# Epoch:9, [Train] Loss: 0.155
# Epoch:9, [Valid] Loss: 0.047
# EarlyStopping counter: 2 out of 10
# Epoch:10, [Train] Loss: 0.151
# Epoch:10, [Valid] Loss: 0.043
# EarlyStopping counter: 3 out of 10
# Epoch:11, [Train] Loss: 0.152
# Epoch:11, [Valid] Loss: 0.036
# prev min loss 0.038, now loss 0.036 | save model at epoch: 11
# *************** Solubility_AqSolDB ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 2.619  &8.460  &2.909  &-0.594
#
# Epoch:12, [Train] Loss: 0.151
# Epoch:12, [Valid] Loss: 0.041
# EarlyStopping counter: 1 out of 10
# Epoch:13, [Train] Loss: 0.150
# Epoch:13, [Valid] Loss: 0.042
# EarlyStopping counter: 2 out of 10
# Epoch:14, [Train] Loss: 0.147
# Epoch:14, [Valid] Loss: 0.042
# EarlyStopping counter: 3 out of 10
# Epoch:15, [Train] Loss: 0.151
# Epoch:15, [Valid] Loss: 0.041
# EarlyStopping counter: 4 out of 10
# Epoch:16, [Train] Loss: 0.151
# Epoch:16, [Valid] Loss: 0.043
# EarlyStopping counter: 5 out of 10
# Epoch:17, [Train] Loss: 0.152
# Epoch:17, [Valid] Loss: 0.044
# EarlyStopping counter: 6 out of 10
# Epoch:18, [Train] Loss: 0.147
# Epoch:18, [Valid] Loss: 0.041
# EarlyStopping counter: 7 out of 10
# Epoch:19, [Train] Loss: 0.146
# Epoch:19, [Valid] Loss: 0.050
# EarlyStopping counter: 8 out of 10
# Epoch:20, [Train] Loss: 0.147
# Epoch:20, [Valid] Loss: 0.048
# EarlyStopping counter: 9 out of 10
# Epoch:21, [Train] Loss: 0.143
# ['lipophilicity_astrazeneca', 'solubility_aqsoldb', 'hydrationfreeenergy_freesolv', 'caco2_wang', 'pampa_ncats', 'approved_pampa_ncats', 'hia_hou', 'pgp_broccatelli', 'bioavailability_ma', 'vdss_lombardo', 'cyp2c19_veith', 'cyp2d6_veith', 'cyp3a4_veith', 'cyp1a2_veith', 'cyp2c9_veith', 'cyp2c9_substrate_carbonmangels', 'cyp2d6_substrate_carbonmangels', 'cyp3a4_substrate_carbonmangels', 'bbb_martins', 'ppbr_az', 'half_life_obach', 'clearance_hepatocyte_az', 'clearance_microsome_az']
# Downloading...
# Epoch:21, [Valid] Loss: 0.047
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 11, min loss: 0.0361
#
# *************** LD50_Zhu ***************
# 100%|██████████| 707k/707k [00:00<00:00, 7.36MiB/s]
# Loading...
# Done!
# scaling train valid test data set for regression task
# --> preparing data loader for model type  GIN
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Epoch:0, [Train] Loss: 0.030
# Epoch:0, [Valid] Loss: 0.014
# prev min loss inf, now loss 0.014 | save model at epoch: 0
# *************** LD50_Zhu ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.970  &1.565  &1.251  &-0.635
#
# Epoch:1, [Train] Loss: 0.029
# Epoch:1, [Valid] Loss: 0.014
# prev min loss 0.014, now loss 0.014 | save model at epoch: 1
# *************** LD50_Zhu ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.971  &1.508  &1.228  &-0.576
#
# Epoch:2, [Train] Loss: 0.028
# Epoch:2, [Valid] Loss: 0.013
# prev min loss 0.014, now loss 0.013 | save model at epoch: 2
# *************** LD50_Zhu ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.953  &1.431  &1.196  &-0.495
#
# Epoch:3, [Train] Loss: 0.028
# Epoch:3, [Valid] Loss: 0.012
# prev min loss 0.013, now loss 0.012 | save model at epoch: 3
# *************** LD50_Zhu ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.887  &1.282  &1.132  &-0.340
#
# Epoch:4, [Train] Loss: 0.029
# Epoch:4, [Valid] Loss: 0.012
# EarlyStopping counter: 1 out of 10
# Epoch:5, [Train] Loss: 0.029
# Epoch:5, [Valid] Loss: 0.012
# EarlyStopping counter: 2 out of 10
# Epoch:6, [Train] Loss: 0.028
# Epoch:6, [Valid] Loss: 0.011
# prev min loss 0.012, now loss 0.011 | save model at epoch: 6
# *************** LD50_Zhu ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.856  &1.192  &1.092  &-0.246
#
# Epoch:7, [Train] Loss: 0.028
# Epoch:7, [Valid] Loss: 0.013
# EarlyStopping counter: 1 out of 10
# Epoch:8, [Train] Loss: 0.028
# Epoch:8, [Valid] Loss: 0.012
# EarlyStopping counter: 2 out of 10
# Epoch:9, [Train] Loss: 0.029
# Epoch:9, [Valid] Loss: 0.012
# EarlyStopping counter: 3 out of 10
# Epoch:10, [Train] Loss: 0.029
# Epoch:10, [Valid] Loss: 0.012
# EarlyStopping counter: 4 out of 10
# Epoch:11, [Train] Loss: 0.029
# Epoch:11, [Valid] Loss: 0.012
# EarlyStopping counter: 5 out of 10
# Epoch:12, [Train] Loss: 0.028
# Epoch:12, [Valid] Loss: 0.013
# EarlyStopping counter: 6 out of 10
# Epoch:13, [Train] Loss: 0.027
# Epoch:13, [Valid] Loss: 0.012
# EarlyStopping counter: 7 out of 10
# Epoch:14, [Train] Loss: 0.029
# Epoch:14, [Valid] Loss: 0.011
# EarlyStopping counter: 8 out of 10
# Epoch:15, [Train] Loss: 0.027
# Epoch:15, [Valid] Loss: 0.011
# EarlyStopping counter: 9 out of 10
# Epoch:16, [Train] Loss: 0.028
# Epoch:16, [Valid] Loss: 0.013
# EarlyStopping counter: 10 out of 10
# early stop
# best epoch: 6, min loss: 0.0107

# %%
for name in names_reg[4:]:
    names = [name]
    IS_R = True
    trains, valids, tests = collect_data_10_17(names)
    trains, valids, tests, dict_scale = scale(trains, valids, tests)
    test_loader =get_loader(tests, names, test_params, model_type)
    model_name = f'{name}_{model_type}.pt'
    config = {'model_type': model_type, 'scale_dict': dict_scale,
              'in_dim': 256, 'hid_dims': [128, 64], 'out_dim': len(names),
              'prop_names': names, 'dropout': dropout, 'IS_R': IS_R,
              'lr': 3e-4, 'wd': 1e-5, 'patience': 10, 'model_path': model_name}
    models = PRED(**config)
    models.eval(test_loader, config['model_path'])
# Out:
# Found local copy...
# Loading...
# Done!
# *************** Caco2_Wang ***************
# scaling train valid test data set for regression task
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  Caco2_Wang_GIN.pt
# [Test] Loss: 0.049
# *************** Caco2_Wang ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.832  &0.888  &0.942  &-0.398
# Found local copy...
# Loading...
# Done!
# *************** Lipophilicity_AstraZeneca ***************
# scaling train valid test data set for regression task
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  Lipophilicity_AstraZeneca_GIN.pt
# [Test] Loss: 0.045
# *************** Lipophilicity_AstraZeneca ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 1.102  &1.630  &1.277  &-0.103
# Found local copy...
# Loading...
# Done!
# *************** HydrationFreeEnergy_FreeSolv ***************
# scaling train valid test data set for regression task
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  HydrationFreeEnergy_FreeSolv_GIN.pt
# [Test] Loss: 0.048
# *************** HydrationFreeEnergy_FreeSolv ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 5.988  &39.810  &6.309  &-1.435
# Found local copy...
# Loading...
# Done!
# *************** Solubility_AqSolDB ***************
# scaling train valid test data set for regression task
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  Solubility_AqSolDB_GIN.pt
# [Test] Loss: 0.036
# *************** Solubility_AqSolDB ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 2.638  &8.516  &2.918  &-0.569
# ['lipophilicity_astrazeneca', 'solubility_aqsoldb', 'hydrationfreeenergy_freesolv', 'caco2_wang', 'pampa_ncats', 'approved_pampa_ncats', 'hia_hou', 'pgp_broccatelli', 'bioavailability_ma', 'vdss_lombardo', 'cyp2c19_veith', 'cyp2d6_veith', 'cyp3a4_veith', 'cyp1a2_veith', 'cyp2c9_veith', 'cyp2c9_substrate_carbonmangels', 'cyp2d6_substrate_carbonmangels', 'cyp3a4_substrate_carbonmangels', 'bbb_martins', 'ppbr_az', 'half_life_obach', 'clearance_hepatocyte_az', 'clearance_microsome_az']
# Found local copy...
# Loading...
# Done!
# *************** LD50_Zhu ***************
# scaling train valid test data set for regression task
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  LD50_Zhu_GIN.pt
# [Test] Loss: 0.010
# *************** LD50_Zhu ***************
# Regression task True
# MAE,      MSE,      RMSE,      R2
# & 0.818  &1.071  &1.035  &-0.199

# %%
model_type = 'GIN'
dropout = 0.3
for name in names_cls:
    names = [name]
    IS_R = False
    trains, valids, tests = collect_data_10_17(names)
    # trains, valids, tests, dict_scale = scale(trains, valids, tests)
    train_loader = get_loader(trains, names, loader_params, model_type)
    valid_loader = get_loader(valids, names, loader_params, model_type)

    model_name = f'{name}_{model_type}.pt'
    # print(model_name)
    config = {'model_type': model_type,
              'in_dim': 256, 'hid_dims': [128, 64], 'out_dim': len(names),
              'prop_names': names, 'dropout': dropout, 'IS_R': IS_R,
              'lr': 3e-4, 'wd': 1e-5, 'patience': 10, 'model_path': model_name}

    models = PRED(**config)
    models.train(train_loader, valid_loader)

# %%
for name in names_cls:
    names = [name]
    IS_R = False
    trains, valids, tests = collect_data_10_17(names)
    # trains, valids, tests, dict_scale = scale(trains, valids, tests)
    test_loader = get_loader(tests, names, test_params, model_type)
    model_name = f'{name}_{model_type}.pt'
    config = {'model_type': model_type,
              'in_dim': 256, 'hid_dims': [128, 64], 'out_dim': len(names),
              'prop_names': names, 'dropout': dropout, 'IS_R': IS_R,
              'lr': 3e-4, 'wd': 1e-5, 'patience': 10, 'model_path': model_name}
    models = PRED(**config)
    models.eval(test_loader, config['model_path'])
# Out:
# Found local copy...
# Loading...
# Done!
# *************** BBB_Martins ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  BBB_Martins_GIN.pt
# Found local copy...
# Loading...
# Done!
# [Test] Loss: 0.325
# *************** BBB_Martins ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.862  &  0.779  &          0.878  &     0.947  &0.612  &0.911 &0.913 &   0.614 &   0.965
#
# *************** Bioavailability_Ma ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  Bioavailability_Ma_GIN.pt
# Found local copy...
# Loading...
# Done!
# [Test] Loss: 0.576
# *************** Bioavailability_Ma ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.711  &  0.574  &          0.739  &     0.911  &0.237  &0.816 &0.685 &   0.199 &   0.811
#
# *************** Pgp_Broccatelli ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  Pgp_Broccatelli_GIN.pt
# Found local copy...
# Loading...
# Done!
# [Test] Loss: 0.450
# *************** Pgp_Broccatelli ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.820  &  0.820  &          0.826  &     0.813  &0.826  &0.820 &0.888 &   0.639 &   0.909
#
# *************** HIA_Hou ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  HIA_Hou_GIN.pt
# Found local copy...
# Loading...
# Done!
# [Test] Loss: 0.115
# *************** HIA_Hou ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.948  &  0.906  &          0.969  &     0.969  &0.842  &0.969 &0.987 &   0.811 &   0.998
#
# *************** PAMPA_NCATS ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  PAMPA_NCATS_GIN.pt
# Found local copy...
# Loading...
# Done!
# [Test] Loss: 0.359
# *************** PAMPA_NCATS ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.865  &  0.635  &          0.883  &     0.968  &0.302  &0.924 &0.770 &   0.373 &   0.940
#
# *************** CYP2C19_Veith ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  CYP2C19_Veith_GIN.pt
# Found local copy...
# Loading...
# Done!
# [Test] Loss: 0.351
# *************** CYP2C19_Veith ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.857  &  0.857  &          0.837  &     0.856  &0.858  &0.846 &0.927 &   0.713 &   0.912
#
# *************** CYP2D6_Veith ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  CYP2D6_Veith_GIN.pt
# Found local copy...
# Loading...
# Done!
# [Test] Loss: 0.291
# *************** CYP2D6_Veith ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.888  &  0.763  &          0.770  &     0.564  &0.962  &0.651 &0.899 &   0.596 &   0.743
#
# *************** CYP3A4_Veith ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  CYP3A4_Veith_GIN.pt
# Found local copy...
# Loading...
# Done!
# [Test] Loss: 0.366
# *************** CYP3A4_Veith ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.838  &  0.835  &          0.794  &     0.820  &0.850  &0.807 &0.920 &   0.667 &   0.884
#
# *************** CYP1A2_Veith ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  CYP1A2_Veith_GIN.pt
# Found local copy...
# Loading...
# Done!
# [Test] Loss: 0.300
# *************** CYP1A2_Veith ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.876  &  0.875  &          0.873  &     0.863  &0.888  &0.868 &0.947 &   0.751 &   0.943
#
# *************** CYP2C9_Veith ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  CYP2C9_Veith_GIN.pt
# Found local copy...
# Loading...
# Done!
# [Test] Loss: 0.318
# *************** CYP2C9_Veith ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.864  &  0.846  &          0.802  &     0.792  &0.900  &0.797 &0.934 &   0.694 &   0.864
#
# *************** CYP2C9_Substrate_CarbonMangels ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  CYP2C9_Substrate_CarbonMangels_GIN.pt
# Found local copy...
# Loading...
# Done!
# [Test] Loss: 0.511
# *************** CYP2C9_Substrate_CarbonMangels ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.776  &  0.486  &          0.000  &     0.000  &0.972  &  nan &0.605 &  -0.076 &   0.258
#
# *************** CYP2D6_Substrate_CarbonMangels ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  CYP2D6_Substrate_CarbonMangels_GIN.pt
# Found local copy...
# Loading...
# Done!
# [Test] Loss: 0.585
# *************** CYP2D6_Substrate_CarbonMangels ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.707  &  0.708  &          0.423  &     0.710  &0.706  &0.530 &0.766 &   0.360 &   0.456
#
# *************** CYP3A4_Substrate_CarbonMangels ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  CYP3A4_Substrate_CarbonMangels_GIN.pt
# ['lipophilicity_astrazeneca', 'solubility_aqsoldb', 'hydrationfreeenergy_freesolv', 'caco2_wang', 'pampa_ncats', 'approved_pampa_ncats', 'hia_hou', 'pgp_broccatelli', 'bioavailability_ma', 'vdss_lombardo', 'cyp2c19_veith', 'cyp2d6_veith', 'cyp3a4_veith', 'cyp1a2_veith', 'cyp2c9_veith', 'cyp2c9_substrate_carbonmangels', 'cyp2d6_substrate_carbonmangels', 'cyp3a4_substrate_carbonmangels', 'bbb_martins', 'ppbr_az', 'half_life_obach', 'clearance_hepatocyte_az', 'clearance_microsome_az']
# Found local copy...
# Loading...
# Done!
# [Test] Loss: 0.692
# *************** CYP3A4_Substrate_CarbonMangels ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.590  &  0.590  &          0.571  &     0.716  &0.463  &0.636 &0.615 &   0.185 &   0.579
#
# *************** hERG_Karim ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  hERG_Karim_GIN.pt
# ['lipophilicity_astrazeneca', 'solubility_aqsoldb', 'hydrationfreeenergy_freesolv', 'caco2_wang', 'pampa_ncats', 'approved_pampa_ncats', 'hia_hou', 'pgp_broccatelli', 'bioavailability_ma', 'vdss_lombardo', 'cyp2c19_veith', 'cyp2d6_veith', 'cyp3a4_veith', 'cyp1a2_veith', 'cyp2c9_veith', 'cyp2c9_substrate_carbonmangels', 'cyp2d6_substrate_carbonmangels', 'cyp3a4_substrate_carbonmangels', 'bbb_martins', 'ppbr_az', 'half_life_obach', 'clearance_hepatocyte_az', 'clearance_microsome_az']
# Found local copy...
# Loading...
# Done!
# [Test] Loss: 0.442
# *************** hERG_Karim ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.789  &  0.789  &          0.806  &     0.760  &0.818  &0.783 &0.878 &   0.579 &   0.886
#
# *************** AMES ***************
# --> preparing data loader for model type  GIN
# model type:  GIN
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# Downloading gin_supervised_contextpred_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_contextpred.pth...
# Pretrained model loaded
# load pretrained model from  AMES_GIN.pt
# [Test] Loss: 0.413
# *************** AMES ***************
# Regression task False
# Accuracy, weighted accuracy, precision, recall/SE, SP,     F1,     AUC,     MCC,     AP
# & 0.819  &  0.814  &          0.816  &     0.865  &0.763  &0.839 &0.893 &   0.633 &   0.906

# %%
# function ClickConnect(){

#     console.log("Working");
#     document.querySelector("#comments > span").click()
# }
# setInterval(ClickConnect,5000)
# Out:
#   File "<ipython-input-286-fbd348a0686a>", line 1
#     function ClickConnect(){
#              ^
# SyntaxError: invalid syntax

# %%
model = Classifier(**config)
cuda = torch.cuda.is_available()

if cuda: model = model.cuda(); device = 'cuda'
else: device = 'cpu'
from torchsummary import summary
batch_size = 128
summary(model, (batch_size, config['in_dim']))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1             [-1, 128, 128]          21,504
#             Linear-2              [-1, 128, 64]           8,256
#             Linear-3              [-1, 128, 32]           2,080
#             Linear-4              [-1, 128, 16]             528
#             Linear-5               [-1, 128, 5]              85
#            Dropout-6               [-1, 128, 5]               0
# ================================================================
# Total params: 32,453
# Trainable params: 32,453
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.08
# Forward/backward pass size (MB): 0.24
# Params size (MB): 0.12
# Estimated Total Size (MB): 0.45
# ----------------------------------------------------------------

# %%
model = Classifier(**config)
cuda = torch.cuda.is_available()

if cuda: model = model.cuda(); device = 'cuda'
else: device = 'cpu'
from torchsummary import summary
batch_size = 128
summary(model, (batch_size, config['in_dim']))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1             [-1, 128, 128]          21,504
#             Linear-2              [-1, 128, 64]           8,256
#             Linear-3              [-1, 128, 32]           2,080
#             Linear-4              [-1, 128, 16]             528
#             Linear-5               [-1, 128, 1]              17
#            Dropout-6               [-1, 128, 1]               0
# ================================================================
# Total params: 32,385
# Trainable params: 32,385
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.08
# Forward/backward pass size (MB): 0.24
# Params size (MB): 0.12
# Estimated Total Size (MB): 0.44
# ----------------------------------------------------------------

# %%
train_loss_dict = {}
valid_loss_dict = {}

epochs = 1000
best_epoch = 0

optimizer = torch.optim.AdamW(params=model.parameters(), lr=lr, weight_decay=wd)


from torchsummary import summary
summary(model, (batch_size, config['in_dim']))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1             [-1, 128, 128]          21,504
#             Linear-2              [-1, 128, 64]           8,256
#             Linear-3              [-1, 128, 32]           2,080
#             Linear-4              [-1, 128, 16]             528
#             Linear-5               [-1, 128, 1]              17
#            Dropout-6               [-1, 128, 1]               0
# ================================================================
# Total params: 32,385
# Trainable params: 32,385
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.08
# Forward/backward pass size (MB): 0.24
# Params size (MB): 0.12
# Estimated Total Size (MB): 0.44
# ----------------------------------------------------------------
